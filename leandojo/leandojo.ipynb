# %%
import json
from pathlib import Path

DST_DIR = Path("./leandojo_benchmark_4")

corpus_path = DST_DIR / 'corpus.jsonl'
lines = list(corpus_path.open())
file_in_corpus = json.loads(lines[2000])
file_in_corpus.keys()
# Out:
# dict_keys(['path', 'imports', 'premises'])

# %%
import os

ELAN_PATH = os.path.join(os.environ['HOME'], '.elan', 'bin')
os.environ['PATH'] = ELAN_PATH + ':' + os.environ['PATH']

# %%
data_path = DST_DIR / "random/"
split = "test"

from lean_dojo import LeanGitRepo, Theorem, Pos

data = json.load(open(os.path.join(data_path, f"{split}.json")))

theorems = []
positions = []

for t in data:
    repo = LeanGitRepo(t["url"], t["commit"])
    theorems.append(Theorem(repo, t["file_path"], t["full_name"]))
    positions.append(Pos(*t["start"]))

# %%
import hashlib

theorems_and_positions = list(zip(theorems, positions))
theorems_and_positions.sort(
        key=lambda x: hashlib.md5(
            f"{x[0].file_path}:{x[0].full_name}".encode()
        ).hexdigest()
    )
theorems, positions = zip(*theorems_and_positions)
theorems, positions = list(theorems), list(positions)

# %%
metadata = json.load(open(os.path.join(data_path, "../metadata.json")))
repo = LeanGitRepo(metadata["from_repo"]["url"], metadata["from_repo"]["commit"])

# %%
import torch
from typing import Union, List
from transformers import AutoTokenizer, AutoModelForTextEncoding, AutoModelForSeq2SeqLM

tokenizer = AutoTokenizer.from_pretrained("kaiyuy/leandojo-lean4-retriever-byt5-small", device_map='cuda')
model = AutoModelForTextEncoding.from_pretrained("kaiyuy/leandojo-lean4-retriever-byt5-small", device_map='cuda')

@torch.no_grad()
def encode(s: Union[str, List[str]]) -> torch.Tensor:
    """Encode texts into feature vectors."""
    if isinstance(s, str):
        s = [s]
        should_squeeze = True
    else:
        should_squeeze = False
    tokenized_s = tokenizer(s, return_tensors="pt", padding=True)
    hidden_state = model(tokenized_s.input_ids.cuda()).last_hidden_state
    lens = tokenized_s.attention_mask.sum(dim=1)
    features = (hidden_state * tokenized_s.attention_mask.unsqueeze(2).cuda()).sum(dim=1) / lens.unsqueeze(1).cuda()
    if should_squeeze:
      features = features.squeeze()
    return features

@torch.no_grad()
def retrieve(state: str, premises: List[str], k: int) -> List[str]:
    """Retrieve the top-k premises given a state."""
    state_emb = encode(state)
    premise_embs = encode(premises)
    scores = (state_emb @ premise_embs.T)
    topk = scores.topk(k).indices.tolist()
    return [premises[i] for i in topk]
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
from search_utils import *

corpus = Corpus(DST_DIR / "corpus.jsonl")
corpus_embeddings = torch.zeros(
    len(corpus.all_premises),
    1472,
    dtype=torch.float32,
    device=torch.device("cuda"),
)
corpus_embeddings.shape
# Out:
# 2024-06-25 23:05:21.043 | INFO     | search_utils:__init__:210 - Building the corpus from leandojo_benchmark_4/corpus.jsonl
# torch.Size([171581, 1472])

# %% [markdown]
# When running for the first time, compute the embeddings.

# %%
#from tqdm.auto import tqdm

#for i, premise in tqdm(enumerate(corpus.all_premises), total=len(corpus.all_premises)):
#    corpus_embeddings[i] = encode(premise.code).detach()
#torch.save(corpus_embeddings, DST_DIR / "corpus.pt")
#corpus_embeddings.size()

# %%
corpus_embedding = torch.load(DST_DIR / "corpus.pt", weights_only=True)

# %%
class RAGTacticGenerator:
    def __init__(self, k_premises=16):
        self.retriever = AutoModelForTextEncoding.from_pretrained("kaiyuy/leandojo-lean4-retriever-byt5-small", device_map='cuda')
        self.prover = AutoModelForSeq2SeqLM.from_pretrained("kaiyuy/leandojo-lean4-retriever-tacgen-byt5-small", device_map='cuda')
        self.tokenizer = AutoTokenizer.from_pretrained("kaiyuy/leandojo-lean4-retriever-tacgen-byt5-small", device_map='cuda')
        self.corpus = Corpus(DST_DIR / "corpus.jsonl")
        self.corpus_embedding = torch.load(DST_DIR / "corpus.pt", weights_only=True)
        self.k_premises = k_premises

    def generate(self, state, file_path, theorem_full_name, theorem_pos, num_samples):
        accessible_premises = self.corpus.get_accessible_premise_indexes(file_path, theorem_pos)
        accessible_premises = torch.topk(
            encode(state) @ self.corpus_embedding[accessible_premises].T,
            self.k_premises
        ).indices
        retrieved_premises = [self.corpus[premise].code for premise in accessible_premises]
        input = "\n\n".join(retrieved_premises + [state])
        tokenized_input = self.tokenizer(input, return_tensors="pt", max_length=2300, truncation=True)
        result = self.prover.generate(
            tokenized_input.input_ids.cuda(),
            max_length=1024,
            num_beams=num_samples,
            length_penalty=0.0,
            do_sample=False,
            num_return_sequences=num_samples,
            early_stopping=False,
            output_scores=True,
            return_dict_in_generate=True,
        )
        tactics = self.tokenizer.batch_decode(result['sequences'], skip_special_tokens=True)
        probs = result[1]
        return [(remove_marks(tac), prob) for tac, prob in zip(tactics, probs)]

# %%
prover = BestFirstSearchProver(
    tac_gen=RAGTacticGenerator(),
    timeout=180,
    num_sampled_tactics=16,
    debug=False
)
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# 2024-06-25 23:05:57.389 | INFO     | search_utils:__init__:210 - Building the corpus from leandojo_benchmark_4/corpus.jsonl

# %%
solved_count = 0
for i in range(0, 100):
    result = prover.search(theorems[i].repo, theorems[i], positions[i])
    if result is not None and result.status == Status.PROVED:
        solved_count += 1
print(f"Solved {solved_count} out of 100 theorems.")
# Out:
# 2024-06-26 09:15:33.047 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Order/Bounds/Basic.lean'), full_name='not_bddBelow_iff')
# 2024-06-26 09:17:56.022 | INFO     | search_utils:_best_first_search:455 - Found a proof!
# 2024-06-26 09:18:03.919 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Order/Bounds/Basic.lean'), full_name='not_bddBelow_iff'), status=<Status.PROVED: 'Proved'>, proof=['simp [BddBelow]', 'simp [Set.Nonempty, lowerBounds]'], actor_time=3.0101579762995243, environment_time=0.8463335484266281, total_time=3.8852586522698402, num_total_nodes=27, num_searched_nodes=3)
# 2024-06-26 09:18:03.922 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/MeasureTheory/Function/SimpleFuncDenseLp.lean'), full_name='MeasureTheory.Lp.simpleFunc.toLp_add')
# 2024-06-26 09:20:20.949 | INFO     | search_utils:_best_first_search:451 - Failed early!
# 2024-06-26 09:20:32.727 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/MeasureTheory/Function/SimpleFuncDenseLp.lean'), full_name='MeasureTheory.Lp.simpleFunc.toLp_add'), status=<Status.FAILED: 'Failed'>, proof=None, actor_time=1.2131105475127697, environment_time=0.17112893611192703, total_time=1.3891402930021286, num_total_nodes=15, num_searched_nodes=1)
# 2024-06-26 09:20:32.728 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/SetTheory/Ordinal/Principal.lean'), full_name='Ordinal.mul_omega')
# 2024-06-26 09:22:43.407 | INFO     | search_utils:_best_first_search:451 - Failed early!
# 2024-06-26 09:22:50.632 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/SetTheory/Ordinal/Principal.lean'), full_name='Ordinal.mul_omega'), status=<Status.FAILED: 'Failed'>, proof=None, actor_time=0.7745427004992962, environment_time=0.10807126387953758, total_time=0.8877705819904804, num_total_nodes=17, num_searched_nodes=1)
# 2024-06-26 09:22:50.635 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/LinearAlgebra/Reflection.lean'), full_name='Module.preReflection_preReflection')
# 2024-06-26 09:27:57.574 | INFO     | search_utils:_best_first_search:447 - Search timed out.
# 2024-06-26 09:28:11.022 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/LinearAlgebra/Reflection.lean'), full_name='Module.preReflection_preReflection'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=78.9464177377522, environment_time=103.59944284707308, total_time=183.12654652819037, num_total_nodes=389, num_searched_nodes=68)
# 2024-06-26 09:28:11.023 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Order/ConditionallyCompleteLattice/Basic.lean'), full_name='OrderIso.map_ciSup')
# 2024-06-26 09:33:19.677 | INFO     | search_utils:_best_first_search:447 - Search timed out.
# 2024-06-26 09:33:26.832 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Order/ConditionallyCompleteLattice/Basic.lean'), full_name='OrderIso.map_ciSup'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=151.7100290991366, environment_time=27.361234966665506, total_time=180.22449658438563, num_total_nodes=1206, num_searched_nodes=210)
# 2024-06-26 09:33:26.833 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/NumberTheory/LegendreSymbol/JacobiSymbol.lean'), full_name='jacobiSym.eq_zero_iff_not_coprime')
# 2024-06-26 09:38:51.963 | INFO     | search_utils:_best_first_search:447 - Search timed out.
# 2024-06-26 09:38:59.478 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/NumberTheory/LegendreSymbol/JacobiSymbol.lean'), full_name='jacobiSym.eq_zero_iff_not_coprime'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=67.6050756201148, environment_time=122.0072328671813, total_time=190.39273216575384, num_total_nodes=898, num_searched_nodes=91)
# 2024-06-26 09:38:59.479 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Order/Bounds/Basic.lean'), full_name='IsLeast.dual')
# 2024-06-26 09:41:20.786 | INFO     | search_utils:_best_first_search:455 - Found a proof!
# 2024-06-26 09:41:27.938 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Order/Bounds/Basic.lean'), full_name='IsLeast.dual'), status=<Status.PROVED: 'Proved'>, proof=['rcases h with ⟨b, hb⟩', 'exact ⟨b, hb⟩'], actor_time=2.2993193604052067, environment_time=0.17843827232718468, total_time=2.492513857781887, num_total_nodes=28, num_searched_nodes=3)
# 2024-06-26 09:41:27.939 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Probability/Distributions/Geometric.lean'), full_name='ProbabilityTheory.geometricPMFRealSum')
# 2024-06-26 09:46:37.398 | INFO     | search_utils:_best_first_search:447 - Search timed out.
# 2024-06-26 09:46:46.079 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Probability/Distributions/Geometric.lean'), full_name='ProbabilityTheory.geometricPMFRealSum'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=96.66809037700295, environment_time=83.34324001148343, total_time=180.9859930947423, num_total_nodes=798, num_searched_nodes=125)
# 2024-06-26 09:46:46.081 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Data/List/Sigma.lean'), full_name='List.NodupKeys.sublist')
# 2024-06-26 09:52:01.953 | INFO     | search_utils:_best_first_search:447 - Search timed out.
# 2024-06-26 09:52:10.365 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Data/List/Sigma.lean'), full_name='List.NodupKeys.sublist'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=120.67956924438477, environment_time=59.96020146459341, total_time=181.9376216493547, num_total_nodes=1746, num_searched_nodes=184)
# 2024-06-26 09:52:10.367 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Data/List/BigOperators/Basic.lean'), full_name='Commute.list_prod_right')
# 2024-06-26 09:57:23.771 | INFO     | search_utils:_best_first_search:447 - Search timed out.
# 2024-06-26 09:57:37.952 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Data/List/BigOperators/Basic.lean'), full_name='Commute.list_prod_right'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=136.76679883152246, environment_time=42.50985196605325, total_time=180.5323775522411, num_total_nodes=1704, num_searched_nodes=196)
# 2024-06-26 09:57:37.954 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Order/Hom/Lattice.lean'), full_name='LatticeHom.coe_toSupHom')
# 2024-06-26 09:59:49.126 | INFO     | search_utils:_best_first_search:455 - Found a proof!
# 2024-06-26 10:00:03.321 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Order/Hom/Lattice.lean'), full_name='LatticeHom.coe_toSupHom'), status=<Status.PROVED: 'Proved'>, proof=['constructor'], actor_time=0.6207648329436779, environment_time=0.002347756177186966, total_time=0.627855446189642, num_total_nodes=2, num_searched_nodes=1)
# 2024-06-26 10:00:03.322 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/SetTheory/Game/PGame.lean'), full_name='SetTheory.PGame.leftMoves_add_cases')
# 2024-06-26 10:02:18.136 | INFO     | search_utils:_best_first_search:451 - Failed early!
# 2024-06-26 10:02:25.304 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/SetTheory/Game/PGame.lean'), full_name='SetTheory.PGame.leftMoves_add_cases'), status=<Status.FAILED: 'Failed'>, proof=None, actor_time=1.6722177602350712, environment_time=0.3392610251903534, total_time=2.0261442065238953, num_total_nodes=35, num_searched_nodes=3)
# 2024-06-26 10:02:25.306 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Data/Finset/Basic.lean'), full_name='Finset.union_subset_left')
# 2024-06-26 10:07:55.344 | INFO     | search_utils:_best_first_search:447 - Search timed out.
# 2024-06-26 10:08:02.680 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Data/Finset/Basic.lean'), full_name='Finset.union_subset_left'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=145.99435357004404, environment_time=32.93141254410148, total_time=180.60974659398198, num_total_nodes=1588, num_searched_nodes=239)
# 2024-06-26 10:08:02.681 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Analysis/Analytic/Basic.lean'), full_name='HasFPowerSeriesOnBall.eventually_eq_zero')
# 2024-06-26 10:10:37.273 | INFO     | search_utils:_best_first_search:451 - Failed early!
# 2024-06-26 10:10:47.722 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Analysis/Analytic/Basic.lean'), full_name='HasFPowerSeriesOnBall.eventually_eq_zero'), status=<Status.FAILED: 'Failed'>, proof=None, actor_time=5.050155509263277, environment_time=0.603795949369669, total_time=5.679775405675173, num_total_nodes=72, num_searched_nodes=5)
# 2024-06-26 10:10:47.724 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/LinearAlgebra/Matrix/Symmetric.lean'), full_name='Matrix.IsSymm.smul')
# 2024-06-26 10:12:57.535 | INFO     | search_utils:_best_first_search:451 - Failed early!
# 2024-06-26 10:13:04.679 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/LinearAlgebra/Matrix/Symmetric.lean'), full_name='Matrix.IsSymm.smul'), status=<Status.FAILED: 'Failed'>, proof=None, actor_time=0.6530760154128075, environment_time=0.058479223400354385, total_time=0.7165487445890903, num_total_nodes=15, num_searched_nodes=1)
# 2024-06-26 10:13:04.680 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Order/UpperLower/Basic.lean'), full_name='isUpperSet_preimage_toDual_iff')
# 2024-06-26 10:15:29.560 | INFO     | search_utils:_best_first_search:455 - Found a proof!
# 2024-06-26 10:15:36.680 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Order/UpperLower/Basic.lean'), full_name='isUpperSet_preimage_toDual_iff'), status=<Status.PROVED: 'Proved'>, proof=['constructor', 'intro h', 'swap', 'intro h', "assumption'"], actor_time=8.73219845443964, environment_time=1.5239231027662754, total_time=10.335811108350754, num_total_nodes=135, num_searched_nodes=14)
# 2024-06-26 10:15:36.682 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Analysis/Calculus/FDeriv/Comp.lean'), full_name='DifferentiableOn.comp')
# 2024-06-26 10:20:44.276 | INFO     | search_utils:_best_first_search:447 - Search timed out.
# 2024-06-26 10:20:57.592 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Analysis/Calculus/FDeriv/Comp.lean'), full_name='DifferentiableOn.comp'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=146.11384055018425, environment_time=33.836028192192316, total_time=180.89960846677423, num_total_nodes=1138, num_searched_nodes=141)
# 2024-06-26 10:20:57.594 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/CategoryTheory/Limits/Shapes/BinaryProducts.lean'), full_name="CategoryTheory.Limits.prod.symmetry'")
# 2024-06-26 10:23:13.554 | INFO     | search_utils:_best_first_search:455 - Found a proof!
# 2024-06-26 10:23:20.629 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/CategoryTheory/Limits/Shapes/BinaryProducts.lean'), full_name="CategoryTheory.Limits.prod.symmetry'"), status=<Status.PROVED: 'Proved'>, proof=['simp'], actor_time=0.8285451792180538, environment_time=0.028582435101270676, total_time=0.8618611805140972, num_total_nodes=2, num_searched_nodes=1)
# 2024-06-26 10:23:20.630 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Geometry/Manifold/ContMDiff/Basic.lean'), full_name='smooth_const')
# 2024-06-26 10:26:08.063 | INFO     | search_utils:_best_first_search:434 - Ran out of nodes to search.
# 2024-06-26 10:26:15.165 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Geometry/Manifold/ContMDiff/Basic.lean'), full_name='smooth_const'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=27.03942232578993, environment_time=3.579523928463459, total_time=30.729379262775183, num_total_nodes=160, num_searched_nodes=20)
# 2024-06-26 10:26:15.166 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Topology/Algebra/Group/Basic.lean'), full_name='tendsto_inv')
# 2024-06-26 10:28:38.665 | INFO     | search_utils:_best_first_search:451 - Failed early!
# 2024-06-26 10:28:45.861 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Topology/Algebra/Group/Basic.lean'), full_name='tendsto_inv'), status=<Status.FAILED: 'Failed'>, proof=None, actor_time=1.03578569740057, environment_time=0.12969519570469856, total_time=1.1705200038850307, num_total_nodes=13, num_searched_nodes=1)
# 2024-06-26 10:28:45.864 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Data/Set/Function.lean'), full_name="Set.bijOn_of_subsingleton'")
# 2024-06-26 10:31:21.571 | WARNING  | search_utils:search:404 - Dojo crashed with Unexpected EOF when proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Data/Set/Function.lean'), full_name="Set.bijOn_of_subsingleton'")
# 2024-06-26 10:31:29.317 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Data/Set/Function.lean'), full_name="Set.bijOn_of_subsingleton'"), status=<Status.OPEN: 'Open'>, proof=None, actor_time=20.80965306609869, environment_time=4.218615375459194, total_time=24.175852552056313, num_total_nodes=257, num_searched_nodes=22)
# 2024-06-26 10:31:29.318 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/MeasureTheory/Integral/Bochner.lean'), full_name='MeasureTheory.integral_map_equiv')
# 2024-06-26 10:34:20.039 | INFO     | search_utils:_best_first_search:451 - Failed early!
# 2024-06-26 10:34:27.101 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/MeasureTheory/Integral/Bochner.lean'), full_name='MeasureTheory.integral_map_equiv'), status=<Status.FAILED: 'Failed'>, proof=None, actor_time=0.849507037550211, environment_time=0.12673227861523628, total_time=0.981068093329668, num_total_nodes=17, num_searched_nodes=1)
# 2024-06-26 10:34:27.103 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/MeasureTheory/MeasurableSpace/Defs.lean'), full_name='Set.Finite.measurableSet_biInter')
# 2024-06-26 10:36:35.679 | INFO     | search_utils:_best_first_search:451 - Failed early!
# 2024-06-26 10:36:42.887 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/MeasureTheory/MeasurableSpace/Defs.lean'), full_name='Set.Finite.measurableSet_biInter'), status=<Status.FAILED: 'Failed'>, proof=None, actor_time=1.4730640351772308, environment_time=0.36436911299824715, total_time=1.8480444997549057, num_total_nodes=25, num_searched_nodes=2)
# 2024-06-26 10:36:42.888 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/LinearAlgebra/QuadraticForm/Prod.lean'), full_name='QuadraticForm.Isometry.snd_comp_inl')
# 2024-06-26 10:39:00.317 | INFO     | search_utils:_best_first_search:451 - Failed early!
# 2024-06-26 10:39:07.413 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/LinearAlgebra/QuadraticForm/Prod.lean'), full_name='QuadraticForm.Isometry.snd_comp_inl'), status=<Status.FAILED: 'Failed'>, proof=None, actor_time=0.7181358635425568, environment_time=0.04985056072473526, total_time=0.7728510834276676, num_total_nodes=7, num_searched_nodes=1)
# 2024-06-26 10:39:07.414 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/MeasureTheory/Measure/Restrict.lean'), full_name='MeasureTheory.NullMeasurable.measure_preimage_eq_measure_restrict_preimage_of_ae_compl_eq_const')
# 2024-06-26 10:41:21.498 | INFO     | search_utils:_best_first_search:451 - Failed early!
# 2024-06-26 10:41:33.717 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/MeasureTheory/Measure/Restrict.lean'), full_name='MeasureTheory.NullMeasurable.measure_preimage_eq_measure_restrict_preimage_of_ae_compl_eq_const'), status=<Status.FAILED: 'Failed'>, proof=None, actor_time=1.3475385084748268, environment_time=0.6520390175282955, total_time=2.0047036819159985, num_total_nodes=14, num_searched_nodes=1)
# 2024-06-26 10:41:33.718 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Algebra/Module/Submodule/Basic.lean'), full_name='Submodule.mem_carrier')
# 2024-06-26 10:43:44.932 | INFO     | search_utils:_best_first_search:455 - Found a proof!
# 2024-06-26 10:43:52.004 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Algebra/Module/Submodule/Basic.lean'), full_name='Submodule.mem_carrier'), status=<Status.PROVED: 'Proved'>, proof=['simp'], actor_time=0.5451038628816605, environment_time=0.01208900660276413, total_time=0.5619008578360081, num_total_nodes=2, num_searched_nodes=1)
# 2024-06-26 10:43:52.006 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Data/Polynomial/Reverse.lean'), full_name='Polynomial.coeff_one_reverse')
# 2024-06-26 10:49:04.651 | INFO     | search_utils:_best_first_search:447 - Search timed out.
# 2024-06-26 10:49:18.173 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Data/Polynomial/Reverse.lean'), full_name='Polynomial.coeff_one_reverse'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=125.84441883862019, environment_time=54.04698756709695, total_time=181.0028197132051, num_total_nodes=1170, num_searched_nodes=174)
# 2024-06-26 10:49:18.174 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/LinearAlgebra/QuadraticForm/Basic.lean'), full_name='QuadraticForm.associated_left_inverse')
# 2024-06-26 10:54:39.620 | INFO     | search_utils:_best_first_search:447 - Search timed out.
# 2024-06-26 10:54:46.725 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/LinearAlgebra/QuadraticForm/Basic.lean'), full_name='QuadraticForm.associated_left_inverse'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=104.58635369315743, environment_time=75.57270764559507, total_time=181.08941566571593, num_total_nodes=1159, num_searched_nodes=155)
# 2024-06-26 10:54:46.727 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Topology/Algebra/Module/FiniteDimension.lean'), full_name='LinearEquiv.coe_toContinuousLinearEquiv_symm')
# 2024-06-26 10:57:07.632 | INFO     | search_utils:_best_first_search:451 - Failed early!
# 2024-06-26 10:57:17.150 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Topology/Algebra/Module/FiniteDimension.lean'), full_name='LinearEquiv.coe_toContinuousLinearEquiv_symm'), status=<Status.FAILED: 'Failed'>, proof=None, actor_time=0.8114250861108303, environment_time=0.0699751190841198, total_time=0.8862250596284866, num_total_nodes=14, num_searched_nodes=1)
# 2024-06-26 10:57:17.152 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Algebra/BigOperators/Intervals.lean'), full_name='Finset.prod_Ico_reflect')
# 2024-06-26 10:59:30.690 | INFO     | search_utils:_best_first_search:451 - Failed early!
# 2024-06-26 10:59:37.983 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Algebra/BigOperators/Intervals.lean'), full_name='Finset.prod_Ico_reflect'), status=<Status.FAILED: 'Failed'>, proof=None, actor_time=0.8639527969062328, environment_time=0.19896561279892921, total_time=1.068247240036726, num_total_nodes=15, num_searched_nodes=1)
# 2024-06-26 10:59:37.986 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Order/Filter/Basic.lean'), full_name='Filter.Tendsto.neBot')
# 2024-06-26 11:02:22.257 | INFO     | search_utils:_best_first_search:455 - Found a proof!
# 2024-06-26 11:02:32.093 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Order/Filter/Basic.lean'), full_name='Filter.Tendsto.neBot'), status=<Status.PROVED: 'Proved'>, proof=['rw [Filter.neBot_iff] at hx ⊢', 'rintro rfl', 'simp at hx', 'simp [Filter.Tendsto, hx] at h'], actor_time=10.704067066311836, environment_time=4.441571939736605, total_time=15.260800987482071, num_total_nodes=183, num_searched_nodes=17)
# 2024-06-26 11:02:32.094 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Data/List/Dedup.lean'), full_name='List.dedup_subset')
# 2024-06-26 11:04:43.217 | INFO     | search_utils:_best_first_search:455 - Found a proof!
# 2024-06-26 11:04:50.351 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Data/List/Dedup.lean'), full_name='List.dedup_subset'), status=<Status.PROVED: 'Proved'>, proof=['intro l', 'intro x hx', 'simpa using hx'], actor_time=1.5883842147886753, environment_time=0.3774419464170933, total_time=1.981585782021284, num_total_nodes=24, num_searched_nodes=3)
# 2024-06-26 11:04:50.352 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Algebra/Order/Monovary.lean'), full_name='antivary_iff_forall_mul_nonpos')
# 2024-06-26 11:10:09.039 | INFO     | search_utils:_best_first_search:447 - Search timed out.
# 2024-06-26 11:10:16.236 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Algebra/Order/Monovary.lean'), full_name='antivary_iff_forall_mul_nonpos'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=126.39907833561301, environment_time=53.5860995054245, total_time=181.09725004807115, num_total_nodes=1658, num_searched_nodes=165)
# 2024-06-26 11:10:16.237 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Analysis/SpecialFunctions/Trigonometric/Inverse.lean'), full_name='Real.arccos_of_le_neg_one')
# 2024-06-26 11:12:29.944 | INFO     | search_utils:_best_first_search:455 - Found a proof!
# 2024-06-26 11:12:37.055 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Analysis/SpecialFunctions/Trigonometric/Inverse.lean'), full_name='Real.arccos_of_le_neg_one'), status=<Status.PROVED: 'Proved'>, proof=['simp [hx]'], actor_time=0.7604857683181763, environment_time=0.07338827848434448, total_time=0.8386955410242081, num_total_nodes=4, num_searched_nodes=1)
# 2024-06-26 11:12:37.057 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Data/Finset/Basic.lean'), full_name='Finset.exists_list_nodup_eq')
# 2024-06-26 11:15:09.236 | INFO     | search_utils:_best_first_search:451 - Failed early!
# 2024-06-26 11:15:16.583 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Data/Finset/Basic.lean'), full_name='Finset.exists_list_nodup_eq'), status=<Status.FAILED: 'Failed'>, proof=None, actor_time=0.7874806858599186, environment_time=0.12842677533626556, total_time=0.9210517778992653, num_total_nodes=14, num_searched_nodes=1)
# 2024-06-26 11:15:16.584 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Data/Set/Image.lean'), full_name='Set.range_diff_image_subset')
# 2024-06-26 11:17:24.450 | INFO     | search_utils:_best_first_search:451 - Failed early!
# 2024-06-26 11:17:36.495 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Data/Set/Image.lean'), full_name='Set.range_diff_image_subset'), status=<Status.FAILED: 'Failed'>, proof=None, actor_time=0.5381057970225811, environment_time=0.044220082461833954, total_time=0.5871924050152302, num_total_nodes=14, num_searched_nodes=1)
# 2024-06-26 11:17:36.496 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Algebra/IsPrimePow.lean'), full_name='isPrimePow_nat_iff')
# 2024-06-26 11:22:46.816 | INFO     | search_utils:_best_first_search:447 - Search timed out.
# 2024-06-26 11:22:55.090 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Algebra/IsPrimePow.lean'), full_name='isPrimePow_nat_iff'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=94.9330972135067, environment_time=84.55527080968022, total_time=180.4051257893443, num_total_nodes=867, num_searched_nodes=101)
# 2024-06-26 11:22:55.091 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/MeasureTheory/Measure/Restrict.lean'), full_name='MeasureTheory.Measure.restrict_eq_self')
# 2024-06-26 11:25:59.219 | INFO     | search_utils:_best_first_search:434 - Ran out of nodes to search.
# 2024-06-26 11:26:06.399 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/MeasureTheory/Measure/Restrict.lean'), full_name='MeasureTheory.Measure.restrict_eq_self'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=38.87125229090452, environment_time=8.029092025011778, total_time=47.11589598283172, num_total_nodes=292, num_searched_nodes=35)
# 2024-06-26 11:26:06.400 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Algebra/DirectLimit.lean'), full_name='AddCommGroup.DirectLimit.congr_symm_apply_of')
# 2024-06-26 11:28:25.909 | INFO     | search_utils:_best_first_search:451 - Failed early!
# 2024-06-26 11:28:40.320 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Algebra/DirectLimit.lean'), full_name='AddCommGroup.DirectLimit.congr_symm_apply_of'), status=<Status.FAILED: 'Failed'>, proof=None, actor_time=0.7232449091970921, environment_time=0.18735307827591896, total_time=0.9156194850802422, num_total_nodes=6, num_searched_nodes=1)
# 2024-06-26 11:28:40.321 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Algebra/Order/Ring/WithTop.lean'), full_name="WithTop.distrib'")
# 2024-06-26 11:33:52.636 | INFO     | search_utils:_best_first_search:447 - Search timed out.
# 2024-06-26 11:34:00.553 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Algebra/Order/Ring/WithTop.lean'), full_name="WithTop.distrib'"), status=<Status.OPEN: 'Open'>, proof=None, actor_time=148.3538165949285, environment_time=31.080515332520008, total_time=180.85459210723639, num_total_nodes=1177, num_searched_nodes=168)
# 2024-06-26 11:34:00.554 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Analysis/SpecialFunctions/Log/Basic.lean'), full_name='Real.continuousAt_log_iff')
# 2024-06-26 11:39:15.606 | INFO     | search_utils:_best_first_search:447 - Search timed out.
# 2024-06-26 11:39:23.032 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Analysis/SpecialFunctions/Log/Basic.lean'), full_name='Real.continuousAt_log_iff'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=144.41942873597145, environment_time=35.33931724354625, total_time=181.07284491881728, num_total_nodes=1524, num_searched_nodes=160)
# 2024-06-26 11:39:23.035 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Analysis/Normed/Group/Basic.lean'), full_name="ContinuousWithinAt.nnnorm'")
# 2024-06-26 11:41:48.063 | INFO     | search_utils:_best_first_search:451 - Failed early!
# 2024-06-26 11:41:58.581 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Analysis/Normed/Group/Basic.lean'), full_name="ContinuousWithinAt.nnnorm'"), status=<Status.FAILED: 'Failed'>, proof=None, actor_time=0.9299568310379982, environment_time=0.052862752228975296, total_time=0.9877833500504494, num_total_nodes=6, num_searched_nodes=1)
# 2024-06-26 11:41:58.582 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Algebra/GradedMonoid.lean'), full_name='GradedMonoid.mk_zero_pow')
# 2024-06-26 11:44:08.293 | INFO     | search_utils:_best_first_search:451 - Failed early!
# 2024-06-26 11:44:16.745 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Algebra/GradedMonoid.lean'), full_name='GradedMonoid.mk_zero_pow'), status=<Status.FAILED: 'Failed'>, proof=None, actor_time=0.9499791674315929, environment_time=0.06605798751115799, total_time=1.0241880528628826, num_total_nodes=13, num_searched_nodes=1)
# 2024-06-26 11:44:16.748 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Algebra/Homology/HomotopyCategory/HomComplex.lean'), full_name='CochainComplex.HomComplex.Cochain.comp_assoc_of_first_is_zero_cochain')
# 2024-06-26 11:49:35.907 | INFO     | search_utils:_best_first_search:447 - Search timed out.
# 2024-06-26 11:49:43.404 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Algebra/Homology/HomotopyCategory/HomComplex.lean'), full_name='CochainComplex.HomComplex.Cochain.comp_assoc_of_first_is_zero_cochain'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=141.3917130753398, environment_time=37.66575920954347, total_time=180.0045284293592, num_total_nodes=1085, num_searched_nodes=156)
# 2024-06-26 11:49:43.406 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/MeasureTheory/Function/SimpleFunc.lean'), full_name='MeasureTheory.SimpleFunc.approx_apply')
# 2024-06-26 11:55:00.311 | INFO     | search_utils:_best_first_search:447 - Search timed out.
# 2024-06-26 11:55:07.631 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/MeasureTheory/Function/SimpleFunc.lean'), full_name='MeasureTheory.SimpleFunc.approx_apply'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=145.5587013848126, environment_time=33.818173967301846, total_time=180.3313762769103, num_total_nodes=947, num_searched_nodes=154)
# 2024-06-26 11:55:07.632 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Topology/PartialHomeomorph.lean'), full_name='PartialHomeomorph.isOpen_image_symm_of_subset_target')
# 2024-06-26 11:57:24.839 | INFO     | search_utils:_best_first_search:434 - Ran out of nodes to search.
# 2024-06-26 11:57:32.830 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Topology/PartialHomeomorph.lean'), full_name='PartialHomeomorph.isOpen_image_symm_of_subset_target'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=2.63044760748744, environment_time=0.4342771805822849, total_time=3.0857539996504784, num_total_nodes=55, num_searched_nodes=4)
# 2024-06-26 11:57:32.831 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Computability/TuringMachine.lean'), full_name='Turing.ListBlank.tail_mk')
# 2024-06-26 11:59:50.561 | INFO     | search_utils:_best_first_search:455 - Found a proof!
# 2024-06-26 11:59:57.944 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Computability/TuringMachine.lean'), full_name='Turing.ListBlank.tail_mk'), status=<Status.PROVED: 'Proved'>, proof=['constructor'], actor_time=0.6083103530108929, environment_time=0.008931726217269897, total_time=0.6220329366624355, num_total_nodes=3, num_searched_nodes=1)
# 2024-06-26 11:59:57.947 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/MeasureTheory/Function/L1Space.lean'), full_name='MeasureTheory.L1.dist_def')
# 2024-06-26 12:02:18.147 | INFO     | search_utils:_best_first_search:451 - Failed early!
# 2024-06-26 12:02:30.240 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/MeasureTheory/Function/L1Space.lean'), full_name='MeasureTheory.L1.dist_def'), status=<Status.FAILED: 'Failed'>, proof=None, actor_time=0.668348778039217, environment_time=0.15865226089954376, total_time=0.8323098868131638, num_total_nodes=9, num_searched_nodes=1)
# 2024-06-26 12:02:30.241 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Algebra/Order/Field/Basic.lean'), full_name='inv_lt_of_inv_lt')
# 2024-06-26 12:07:42.149 | INFO     | search_utils:_best_first_search:447 - Search timed out.
# 2024-06-26 12:07:51.104 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Algebra/Order/Field/Basic.lean'), full_name='inv_lt_of_inv_lt'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=143.11374113708735, environment_time=35.91512715816498, total_time=180.65941712260246, num_total_nodes=1811, num_searched_nodes=195)
# 2024-06-26 12:07:51.105 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Topology/Algebra/InfiniteSum/Basic.lean'), full_name='hasSum_extend_zero')
# 2024-06-26 12:10:03.624 | INFO     | search_utils:_best_first_search:451 - Failed early!
# 2024-06-26 12:10:10.777 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Topology/Algebra/InfiniteSum/Basic.lean'), full_name='hasSum_extend_zero'), status=<Status.FAILED: 'Failed'>, proof=None, actor_time=0.9048323221504688, environment_time=0.050933290272951126, total_time=0.9606480374932289, num_total_nodes=9, num_searched_nodes=1)
# 2024-06-26 12:10:10.778 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/CategoryTheory/MorphismProperty.lean'), full_name='CategoryTheory.MorphismProperty.StableUnderBaseChange.unop')
# 2024-06-26 12:12:24.634 | INFO     | search_utils:_best_first_search:451 - Failed early!
# 2024-06-26 12:12:31.803 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/CategoryTheory/MorphismProperty.lean'), full_name='CategoryTheory.MorphismProperty.StableUnderBaseChange.unop'), status=<Status.FAILED: 'Failed'>, proof=None, actor_time=2.24458122625947, environment_time=0.011687103658914566, total_time=2.2609822414815426, num_total_nodes=17, num_searched_nodes=1)
# 2024-06-26 12:12:31.805 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Order/SymmDiff.lean'), full_name='symmDiff_left_comm')
# 2024-06-26 12:14:39.531 | INFO     | search_utils:_best_first_search:451 - Failed early!
# ...
# 2024-06-26 14:04:22.046 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/CategoryTheory/Comma/Arrow.lean'), full_name='CategoryTheory.Arrow.isIso_of_isIso_left_of_isIso_right')
# 2024-06-26 14:06:36.769 | WARNING  | search_utils:search:426 - EOF
# 2024-06-26 14:06:36.772 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/RingTheory/DedekindDomain/Ideal.lean'), full_name='irreducible_pow_sup_of_le')
# 2024-06-26 14:12:57.878 | INFO     | search_utils:_best_first_search:447 - Search timed out.
# 2024-06-26 14:13:05.884 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/RingTheory/DedekindDomain/Ideal.lean'), full_name='irreducible_pow_sup_of_le'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=3.5430734008550644, environment_time=152.5520153902471, total_time=239.99333311617374, num_total_nodes=62, num_searched_nodes=4)
# 2024-06-26 14:13:05.885 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/GroupTheory/Subgroup/Basic.lean'), full_name='Subgroup.zpow_mem')
# 2024-06-26 14:15:29.925 | INFO     | search_utils:_best_first_search:451 - Failed early!
# 2024-06-26 14:15:37.146 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/GroupTheory/Subgroup/Basic.lean'), full_name='Subgroup.zpow_mem'), status=<Status.FAILED: 'Failed'>, proof=None, actor_time=0.7430997528135777, environment_time=0.06641438603401184, total_time=0.814277395606041, num_total_nodes=5, num_searched_nodes=1)
# 2024-06-26 14:15:37.147 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Analysis/Normed/Group/Basic.lean'), full_name="pi_nnnorm_const'")
# 2024-06-26 14:18:53.216 | INFO     | search_utils:_best_first_search:434 - Ran out of nodes to search.
# 2024-06-26 14:19:01.087 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Analysis/Normed/Group/Basic.lean'), full_name="pi_nnnorm_const'"), status=<Status.OPEN: 'Open'>, proof=None, actor_time=25.994414158165455, environment_time=27.350920297205448, total_time=53.52089378610253, num_total_nodes=153, num_searched_nodes=23)
# 2024-06-26 14:19:01.089 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Topology/Gluing.lean'), full_name='TopCat.GlueData.rel_equiv')
# 2024-06-26 14:24:10.787 | INFO     | search_utils:_best_first_search:447 - Search timed out.
# 2024-06-26 14:24:19.510 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Topology/Gluing.lean'), full_name='TopCat.GlueData.rel_equiv'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=111.92883933335543, environment_time=67.19730405509472, total_time=180.45098473504186, num_total_nodes=1516, num_searched_nodes=156)
# 2024-06-26 14:24:19.511 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('.lake/packages/std/Std/Data/String/Lemmas.lean'), full_name='Substring.ValidFor.all')
# 2024-06-26 14:26:36.873 | WARNING  | search_utils:search:426 - EOF
# 2024-06-26 14:26:36.880 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Data/Set/Sups.lean'), full_name='Set.infs_subset_right')
# 2024-06-26 14:28:59.093 | INFO     | search_utils:_best_first_search:455 - Found a proof!
# 2024-06-26 14:29:07.644 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Data/Set/Sups.lean'), full_name='Set.infs_subset_right'), status=<Status.PROVED: 'Proved'>, proof=['intro', 'simp_rw [Set.subset_def]', 'aesop'], actor_time=10.371368195861578, environment_time=2.580975864082575, total_time=13.049278624355793, num_total_nodes=121, num_searched_nodes=11)
# 2024-06-26 14:29:07.645 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/MeasureTheory/MeasurableSpace/Basic.lean'), full_name='MeasurableEquiv.symm_mk')
# 2024-06-26 14:31:21.319 | INFO     | search_utils:_best_first_search:455 - Found a proof!
# 2024-06-26 14:31:28.425 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/MeasureTheory/MeasurableSpace/Basic.lean'), full_name='MeasurableEquiv.symm_mk'), status=<Status.PROVED: 'Proved'>, proof=['rfl'], actor_time=0.480912696570158, environment_time=0.004226598888635635, total_time=0.48966990783810616, num_total_nodes=2, num_searched_nodes=1)
# 2024-06-26 14:31:28.426 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/LinearAlgebra/Dual.lean'), full_name='Module.forall_dual_apply_eq_zero_iff')
# 2024-06-26 14:36:47.443 | INFO     | search_utils:_best_first_search:447 - Search timed out.
# 2024-06-26 14:36:54.845 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/LinearAlgebra/Dual.lean'), full_name='Module.forall_dual_apply_eq_zero_iff'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=142.50169756636024, environment_time=36.071747969836, total_time=180.0358259230852, num_total_nodes=1480, num_searched_nodes=225)
# 2024-06-26 14:36:54.848 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Order/Filter/Basic.lean'), full_name='Filter.EventuallyLE.compl')
# 2024-06-26 14:39:23.242 | INFO     | search_utils:_best_first_search:455 - Found a proof!
# 2024-06-26 14:39:30.901 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Order/Filter/Basic.lean'), full_name='Filter.EventuallyLE.compl'), status=<Status.PROVED: 'Proved'>, proof=['rw [Filter.EventuallyLE]', 'filter_upwards [h] with x hx', 'simp', 'intro h', 'exact hx.trans h'], actor_time=7.794390022754669, environment_time=1.6935190670192242, total_time=9.559156954288483, num_total_nodes=153, num_searched_nodes=13)
# 2024-06-26 14:39:30.904 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Algebra/Homology/HomotopyCategory/MappingCone.lean'), full_name='CochainComplex.mappingCone.ext_to')
# 2024-06-26 14:41:44.439 | INFO     | search_utils:_best_first_search:451 - Failed early!
# 2024-06-26 14:41:52.137 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Algebra/Homology/HomotopyCategory/MappingCone.lean'), full_name='CochainComplex.mappingCone.ext_to'), status=<Status.FAILED: 'Failed'>, proof=None, actor_time=0.7216025851666927, environment_time=0.0844990722835064, total_time=0.8111194856464863, num_total_nodes=13, num_searched_nodes=1)
# 2024-06-26 14:41:52.138 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Topology/MetricSpace/Dilation.lean'), full_name='Dilation.ediam_image')
# 2024-06-26 14:46:52.557 | INFO     | search_utils:_best_first_search:447 - Search timed out.
# 2024-06-26 14:47:06.895 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Topology/MetricSpace/Dilation.lean'), full_name='Dilation.ediam_image'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=40.18790451809764, environment_time=139.47457619011402, total_time=180.02743997052312, num_total_nodes=305, num_searched_nodes=42)
# 2024-06-26 14:47:06.897 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Data/Nat/Digits.lean'), full_name='Nat.sum_le_ofDigits')
# 2024-06-26 14:52:20.612 | INFO     | search_utils:_best_first_search:447 - Search timed out.
# 2024-06-26 14:52:29.280 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Data/Nat/Digits.lean'), full_name='Nat.sum_le_ofDigits'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=133.30924304574728, environment_time=45.8787244297564, total_time=180.6694214232266, num_total_nodes=1603, num_searched_nodes=253)
# 2024-06-26 14:52:29.281 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Algebra/ContinuedFractions/Translations.lean'), full_name='GeneralizedContinuedFraction.first_denominator_eq')
# 2024-06-26 14:54:36.058 | INFO     | search_utils:_best_first_search:451 - Failed early!
# 2024-06-26 14:54:48.095 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Algebra/ContinuedFractions/Translations.lean'), full_name='GeneralizedContinuedFraction.first_denominator_eq'), status=<Status.FAILED: 'Failed'>, proof=None, actor_time=0.6372012309730053, environment_time=0.03950585052371025, total_time=0.6816507428884506, num_total_nodes=11, num_searched_nodes=1)
# 2024-06-26 14:54:48.096 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Order/Lattice.lean'), full_name='inf_eq_right')
# 2024-06-26 14:57:35.610 | WARNING  | search_utils:search:404 - Dojo crashed with Unexpected EOF when proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Order/Lattice.lean'), full_name='inf_eq_right')
# 2024-06-26 14:57:43.165 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Order/Lattice.lean'), full_name='inf_eq_right'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=30.551082719117403, environment_time=4.192159507423639, total_time=34.14459325000644, num_total_nodes=412, num_searched_nodes=42)
# 2024-06-26 14:57:43.166 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Analysis/SpecialFunctions/Trigonometric/Deriv.lean'), full_name='Real.sinh_lt_self_iff')
# 2024-06-26 15:03:04.251 | INFO     | search_utils:_best_first_search:447 - Search timed out.
# 2024-06-26 15:03:11.617 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Analysis/SpecialFunctions/Trigonometric/Deriv.lean'), full_name='Real.sinh_lt_self_iff'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=125.3952765725553, environment_time=53.912288915365934, total_time=180.60853371024132, num_total_nodes=1482, num_searched_nodes=160)
# 2024-06-26 15:03:11.618 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Data/Set/UnionLift.lean'), full_name='Set.iUnionLift_const')
# 2024-06-26 15:08:30.184 | INFO     | search_utils:_best_first_search:447 - Search timed out.
# 2024-06-26 15:08:38.832 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Data/Set/UnionLift.lean'), full_name='Set.iUnionLift_const'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=112.26322359591722, environment_time=67.57569696381688, total_time=180.65908743441105, num_total_nodes=949, num_searched_nodes=86)
# 2024-06-26 15:08:38.834 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/NumberTheory/LucasLehmer.lean'), full_name='LucasLehmer.X.mul_fst')
# 2024-06-26 15:10:52.837 | INFO     | search_utils:_best_first_search:455 - Found a proof!
# 2024-06-26 15:11:00.105 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/NumberTheory/LucasLehmer.lean'), full_name='LucasLehmer.X.mul_fst'), status=<Status.PROVED: 'Proved'>, proof=['rfl'], actor_time=0.42845607176423073, environment_time=0.41672708466649055, total_time=0.8504180610179901, num_total_nodes=5, num_searched_nodes=1)
# Solved 24 out of 100 theorems.

# %%
prover = BestFirstSearchProver(
    tac_gen=RAGTacticGenerator(0),
    timeout=180,
    num_sampled_tactics=16,
    debug=False
)
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# 2024-06-26 15:34:32.279 | INFO     | search_utils:__init__:210 - Building the corpus from leandojo_benchmark_4/corpus.jsonl

# %%
solved_count = 0
for i in range(0, 100):
    result = prover.search(theorems[i].repo, theorems[i], positions[i])
    if result.status == Status.PROVED:
        solved_count += 1
print(f"Solved {solved_count} out of 100 theorems.")
# Out:
# 2024-06-26 15:11:33.325 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Order/Bounds/Basic.lean'), full_name='not_bddBelow_iff')
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 3
#       1 solved_count = 0
#       2 for i in range(0, 100):
# ----> 3     result = prover.search(theorems[i].repo, theorems[i], positions[i])
#       4     if result.status == Status.PROVED:
#       5         solved_count += 1
#
# File ~/basic-rag/leandojo/search_utils.py:402, in BestFirstSearchProver.search(self, repo, thm, pos)
#     400 with torch.no_grad():
#     401     try:
# --> 402         self._best_first_search()
#     403     except DojoCrashError as ex:
#     404         logger.warning(f"Dojo crashed with {ex} when proving {thm}")
#
# File ~/basic-rag/leandojo/search_utils.py:438, in BestFirstSearchProver._best_first_search(self)
#     435     break
#     437 try:
# --> 438     self._step()
#     439 except DojoHardTimeoutError:
#     440     assert time.monotonic() - time_start >= self.timeout
#
# File ~/basic-rag/leandojo/search_utils.py:479, in BestFirstSearchProver._step(self)
#     477 else:
#     478     ts = search_node.state.unsolved_tactic_state
# --> 479 suggestions = self._generate_tactics(ts)
#     481 # Try all tactics in order of descending logprob, and collect the results. Any
#     482 # new nodes are added to `self.nodes`, and edges are added to the result node.
#     483 results = []
#
# File ~/basic-rag/leandojo/search_utils.py:509, in BestFirstSearchProver._generate_tactics(self, ts)
#     505 t0 = time.monotonic()
#     507 path = str(self.theorem.file_path)
# --> 509 suggestions = self.tac_gen.generate(
#     510     state=ts,
#     511     file_path=path,
#     512     theorem_full_name=self.theorem.full_name,
#     513     theorem_pos=self.posision,
#     514     num_samples=self.num_sampled_tactics,
#     515 )
#     517 self.actor_time += time.monotonic() - t0
#     519 logger.debug(f"Tactic suggestions: {suggestions}")
#
# Cell In[9], line 18, in RAGTacticGenerator.generate(self, state, file_path, theorem_full_name, theorem_pos, num_samples)
#      16 input = "\n\n".join(retrieved_premises + [state])
#      17 tokenized_input = self.tokenizer(input, return_tensors="pt", max_length=2300, truncation=True)
# ---> 18 result = self.prover.generate(
#      19     tokenized_input.input_ids.cuda(),
#      20     max_length=1024,
#      21     num_beams=num_samples,
#      22     length_penalty=0.0,
#      23     do_sample=False,
#      24     num_return_sequences=num_samples,
#      25     early_stopping=False,
#      26     output_scores=True,
#      27     return_dict_in_generate=True,
#      28 )
#      29 tactics = self.tokenizer.batch_decode(result['sequences'], skip_special_tokens=True)
#      30 probs = result[1]
#
# File ~/miniconda3/envs/rag-test/lib/python3.11/site-packages/torch/utils/_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# File ~/miniconda3/envs/rag-test/lib/python3.11/site-packages/transformers/generation/utils.py:1776, in GenerationMixin.generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, **kwargs)
#    1771 prepared_logits_warper = (
#    1772     self._get_logits_warper(generation_config) if generation_config.do_sample else None
#    1773 )
#    1775 # 12. prepare beam search scorer
# -> 1776 beam_scorer = BeamSearchScorer(
#    1777     batch_size=batch_size,
#    1778     num_beams=generation_config.num_beams,
#    1779     device=inputs_tensor.device,
#    1780     length_penalty=generation_config.length_penalty,
#    1781     do_early_stopping=generation_config.early_stopping,
#    1782     num_beam_hyps_to_keep=generation_config.num_return_sequences,
#    1783     max_length=generation_config.max_length,
#    1784 )
#    1786 # 13. interleave input_ids with `num_beams` additional sequences per batch
#    1787 input_ids, model_kwargs = self._expand_inputs_for_generation(
#    1788     input_ids=input_ids,
#    1789     expand_size=generation_config.num_beams,
#    1790     is_encoder_decoder=self.config.is_encoder_decoder,
#    1791     **model_kwargs,
#    1792 )
#
# File ~/miniconda3/envs/rag-test/lib/python3.11/site-packages/transformers/generation/beam_search.py:200, in BeamSearchScorer.__init__(self, batch_size, num_beams, device, length_penalty, do_early_stopping, num_beam_hyps_to_keep, num_beam_groups, max_length)
#     195 self._done = torch.tensor(
#     196     [False for _ in range(batch_size * self.num_beam_groups)], dtype=torch.bool, device=self.device
#     197 )
#     199 if not isinstance(num_beams, int) or num_beams <= 1:
# --> 200     raise ValueError(
#     201         f"`num_beams` has to be an integer strictly greater than 1, but is {num_beams}. For `num_beams` == 1,"
#     202         " one should make use of `greedy_search` instead."
#     203     )
#     205 if not isinstance(num_beam_groups, int) or (num_beam_groups > num_beams) or (num_beams % num_beam_groups != 0):
#     206     raise ValueError(
#     207         "`num_beam_groups` has to be an integer smaller or equal than `num_beams` and `num_beams` has to be"
#     208         f" divisible by `num_beam_groups`, but is {num_beam_groups} with `num_beams` being {num_beams}."
#     209     )
#
# ValueError: `num_beams` has to be an integer strictly greater than 1, but is 0. For `num_beams` == 1, one should make use of `greedy_search` instead.
