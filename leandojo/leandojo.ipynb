# %%
import json
from pathlib import Path

DST_DIR = Path("./leandojo_benchmark_4")

corpus_path = DST_DIR / 'corpus.jsonl'
lines = list(corpus_path.open())
file_in_corpus = json.loads(lines[2000])
file_in_corpus.keys()
# Out:
# dict_keys(['path', 'imports', 'premises'])

# %%
import os

ELAN_PATH = os.path.join(os.environ['HOME'], '.elan', 'bin')
os.environ['PATH'] = ELAN_PATH + ':' + os.environ['PATH']

# %%
data_path = DST_DIR / "random/"
split = "test"

from lean_dojo import LeanGitRepo, Theorem, Pos

data = json.load(open(os.path.join(data_path, f"{split}.json")))

theorems = []
positions = []

for t in data:
    repo = LeanGitRepo(t["url"], t["commit"])
    theorems.append(Theorem(repo, t["file_path"], t["full_name"]))
    positions.append(Pos(*t["start"]))

# %%
import hashlib

theorems_and_positions = list(zip(theorems, positions))
theorems_and_positions.sort(
        key=lambda x: hashlib.md5(
            f"{x[0].file_path}:{x[0].full_name}".encode()
        ).hexdigest()
    )
theorems, positions = zip(*theorems_and_positions)
theorems, positions = list(theorems), list(positions)

# %%
metadata = json.load(open(os.path.join(data_path, "../metadata.json")))
repo = LeanGitRepo(metadata["from_repo"]["url"], metadata["from_repo"]["commit"])

# %%
import torch
from typing import Union, List
from transformers import AutoTokenizer, AutoModelForTextEncoding, AutoModelForSeq2SeqLM

tokenizer = AutoTokenizer.from_pretrained("kaiyuy/leandojo-lean4-retriever-byt5-small", device_map='cuda')
model = AutoModelForTextEncoding.from_pretrained("kaiyuy/leandojo-lean4-retriever-byt5-small", device_map='cuda')

@torch.no_grad()
def encode(s: Union[str, List[str]]) -> torch.Tensor:
    """Encode texts into feature vectors."""
    if isinstance(s, str):
        s = [s]
        should_squeeze = True
    else:
        should_squeeze = False
    tokenized_s = tokenizer(s, return_tensors="pt", padding=True)
    hidden_state = model(tokenized_s.input_ids.cuda()).last_hidden_state
    lens = tokenized_s.attention_mask.sum(dim=1)
    features = (hidden_state * tokenized_s.attention_mask.unsqueeze(2).cuda()).sum(dim=1) / lens.unsqueeze(1).cuda()
    if should_squeeze:
      features = features.squeeze()
    return features

@torch.no_grad()
def retrieve(state: str, premises: List[str], k: int) -> List[str]:
    """Retrieve the top-k premises given a state."""
    state_emb = encode(state)
    premise_embs = encode(premises)
    scores = (state_emb @ premise_embs.T)
    topk = scores.topk(k).indices.tolist()
    return [premises[i] for i in topk]
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
from search_utils import *

corpus = Corpus(DST_DIR / "corpus.jsonl")
corpus_embeddings = torch.zeros(
    len(corpus.all_premises),
    1472,
    dtype=torch.float32,
    device=torch.device("cuda"),
)
corpus_embeddings.shape
# Out:
# 2024-06-27 14:59:49.501 | INFO     | search_utils:__init__:210 - Building the corpus from leandojo_benchmark_4/corpus.jsonl
# torch.Size([171581, 1472])

# %% [markdown]
# When running for the first time, compute the embeddings.

# %%
#from tqdm.auto import tqdm

#for i, premise in tqdm(enumerate(corpus.all_premises), total=len(corpus.all_premises)):
#    corpus_embeddings[i] = encode(premise.code).detach()
#torch.save(corpus_embeddings, DST_DIR / "corpus.pt")
#corpus_embeddings.size()

# %%
corpus_embedding = torch.load(DST_DIR / "corpus.pt", weights_only=True)

# %%
class RAGTacticGenerator:
    def __init__(self, k_premises=16):
        self.retriever = AutoModelForTextEncoding.from_pretrained("kaiyuy/leandojo-lean4-retriever-byt5-small", device_map='cuda')
        self.prover = AutoModelForSeq2SeqLM.from_pretrained("kaiyuy/leandojo-lean4-retriever-tacgen-byt5-small", device_map='cuda')
        self.tokenizer = AutoTokenizer.from_pretrained("kaiyuy/leandojo-lean4-retriever-tacgen-byt5-small", device_map='cuda')
        self.corpus = Corpus(DST_DIR / "corpus.jsonl")
        self.corpus_embedding = torch.load(DST_DIR / "corpus.pt", weights_only=True)
        self.k_premises = k_premises

    def generate(self, state, file_path, theorem_full_name, theorem_pos, num_samples):
        accessible_premises = self.corpus.get_accessible_premise_indexes(file_path, theorem_pos)
        accessible_premises = torch.topk(
            encode(state) @ self.corpus_embedding[accessible_premises].T,
            self.k_premises
        ).indices
        retrieved_premises = [self.corpus[premise].code for premise in accessible_premises]
        input = "\n\n".join(retrieved_premises + [state])
        tokenized_input = self.tokenizer(input, return_tensors="pt", max_length=2300, truncation=True)
        result = self.prover.generate(
            tokenized_input.input_ids.cuda(),
            max_length=1024,
            num_beams=num_samples,
            length_penalty=0.0,
            do_sample=False,
            num_return_sequences=num_samples,
            early_stopping=False,
            output_scores=True,
            return_dict_in_generate=True,
        )
        tactics = self.tokenizer.batch_decode(result['sequences'], skip_special_tokens=True)
        probs = result[1]
        return [(remove_marks(tac), prob) for tac, prob in zip(tactics, probs)]

# %%
prover = BestFirstSearchProver(
    tac_gen=RAGTacticGenerator(),
    timeout=180,
    num_sampled_tactics=16,
    debug=False
)
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# 2024-06-27 15:00:13.474 | INFO     | search_utils:__init__:210 - Building the corpus from leandojo_benchmark_4/corpus.jsonl

# %%
solved_count = 0
for i in range(0, 100):
    result = prover.search(theorems[i].repo, theorems[i], positions[i])
    if result is not None and result.status == Status.PROVED:
        solved_count += 1
print(f"Solved {solved_count} out of 100 theorems.")
# Out:
# 2024-06-27 15:00:36.288 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Order/Bounds/Basic.lean'), full_name='not_bddBelow_iff')
# 2024-06-27 15:03:10.433 | INFO     | search_utils:_best_first_search:455 - Found a proof!
# 2024-06-27 15:03:25.390 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Order/Bounds/Basic.lean'), full_name='not_bddBelow_iff'), status=<Status.PROVED: 'Proved'>, proof=['simp [BddBelow]', 'simp [Set.Nonempty, lowerBounds]'], actor_time=2.4297626949846745, environment_time=0.769526518881321, total_time=3.223170902580023, num_total_nodes=27, num_searched_nodes=3)
# 2024-06-27 15:03:25.392 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/MeasureTheory/Function/SimpleFuncDenseLp.lean'), full_name='MeasureTheory.Lp.simpleFunc.toLp_add')
# 2024-06-27 15:06:02.173 | INFO     | search_utils:_best_first_search:451 - Failed early!
# 2024-06-27 15:06:11.747 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/MeasureTheory/Function/SimpleFuncDenseLp.lean'), full_name='MeasureTheory.Lp.simpleFunc.toLp_add'), status=<Status.FAILED: 'Failed'>, proof=None, actor_time=1.1955574117600918, environment_time=0.17129742726683617, total_time=1.3723702989518642, num_total_nodes=15, num_searched_nodes=1)
# 2024-06-27 15:06:11.748 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/SetTheory/Ordinal/Principal.lean'), full_name='Ordinal.mul_omega')
# 2024-06-27 15:08:46.445 | INFO     | search_utils:_best_first_search:451 - Failed early!
# 2024-06-27 15:08:55.197 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/SetTheory/Ordinal/Principal.lean'), full_name='Ordinal.mul_omega'), status=<Status.FAILED: 'Failed'>, proof=None, actor_time=0.7859006859362125, environment_time=0.10682544112205505, total_time=0.8981186337769032, num_total_nodes=17, num_searched_nodes=1)
# 2024-06-27 15:08:55.198 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/LinearAlgebra/Reflection.lean'), full_name='Module.preReflection_preReflection')
# 2024-06-27 15:14:24.208 | INFO     | search_utils:_best_first_search:447 - Search timed out.
# 2024-06-27 15:14:32.197 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/LinearAlgebra/Reflection.lean'), full_name='Module.preReflection_preReflection'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=80.20784416049719, environment_time=99.40493866056204, total_time=180.23660618439317, num_total_nodes=380, num_searched_nodes=66)
# 2024-06-27 15:14:32.199 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Order/ConditionallyCompleteLattice/Basic.lean'), full_name='OrderIso.map_ciSup')
# 2024-06-27 15:20:11.275 | INFO     | search_utils:_best_first_search:447 - Search timed out.
# 2024-06-27 15:20:19.312 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Order/ConditionallyCompleteLattice/Basic.lean'), full_name='OrderIso.map_ciSup'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=156.22211076691747, environment_time=23.01477513462305, total_time=180.63833831250668, num_total_nodes=991, num_searched_nodes=173)
# 2024-06-27 15:20:19.313 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/NumberTheory/LegendreSymbol/JacobiSymbol.lean'), full_name='jacobiSym.eq_zero_iff_not_coprime')
# 2024-06-27 15:26:06.920 | INFO     | search_utils:_best_first_search:447 - Search timed out.
# 2024-06-27 15:26:14.931 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/NumberTheory/LegendreSymbol/JacobiSymbol.lean'), full_name='jacobiSym.eq_zero_iff_not_coprime'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=69.01497835665941, environment_time=121.34832092747092, total_time=191.20891626551747, num_total_nodes=898, num_searched_nodes=91)
# 2024-06-27 15:26:14.932 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Order/Bounds/Basic.lean'), full_name='IsLeast.dual')
# 2024-06-27 15:28:44.604 | INFO     | search_utils:_best_first_search:455 - Found a proof!
# 2024-06-27 15:28:59.273 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Order/Bounds/Basic.lean'), full_name='IsLeast.dual'), status=<Status.PROVED: 'Proved'>, proof=['rcases h with ⟨b, hb⟩', 'exact ⟨b, hb⟩'], actor_time=2.33433648198843, environment_time=0.20344935357570648, total_time=2.553216192871332, num_total_nodes=28, num_searched_nodes=3)
# 2024-06-27 15:28:59.274 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Probability/Distributions/Geometric.lean'), full_name='ProbabilityTheory.geometricPMFRealSum')
# 2024-06-27 15:34:25.454 | INFO     | search_utils:_best_first_search:447 - Search timed out.
# 2024-06-27 15:34:33.895 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Probability/Distributions/Geometric.lean'), full_name='ProbabilityTheory.geometricPMFRealSum'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=96.17471627146006, environment_time=82.9718423075974, total_time=180.13555900007486, num_total_nodes=812, num_searched_nodes=128)
# 2024-06-27 15:34:33.897 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Data/List/Sigma.lean'), full_name='List.NodupKeys.sublist')
# 2024-06-27 15:40:10.181 | INFO     | search_utils:_best_first_search:447 - Search timed out.
# 2024-06-27 15:40:18.495 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Data/List/Sigma.lean'), full_name='List.NodupKeys.sublist'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=121.1353775896132, environment_time=59.66103608161211, total_time=182.14194817841053, num_total_nodes=1746, num_searched_nodes=184)
# 2024-06-27 15:40:18.497 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Data/List/BigOperators/Basic.lean'), full_name='Commute.list_prod_right')
# 2024-06-27 15:45:48.398 | INFO     | search_utils:_best_first_search:447 - Search timed out.
# 2024-06-27 15:46:02.341 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Data/List/BigOperators/Basic.lean'), full_name='Commute.list_prod_right'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=138.14296293258667, environment_time=41.668691135942936, total_time=181.12769651785493, num_total_nodes=1713, num_searched_nodes=197)
# 2024-06-27 15:46:02.343 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Order/Hom/Lattice.lean'), full_name='LatticeHom.coe_toSupHom')
# 2024-06-27 15:48:29.381 | INFO     | search_utils:_best_first_search:455 - Found a proof!
# 2024-06-27 15:48:40.271 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Order/Hom/Lattice.lean'), full_name='LatticeHom.coe_toSupHom'), status=<Status.PROVED: 'Proved'>, proof=['constructor'], actor_time=0.6474925838410854, environment_time=0.008138366043567657, total_time=0.6606776230037212, num_total_nodes=2, num_searched_nodes=1)
# 2024-06-27 15:48:40.274 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/SetTheory/Game/PGame.lean'), full_name='SetTheory.PGame.leftMoves_add_cases')
# 2024-06-27 15:51:20.050 | INFO     | search_utils:_best_first_search:451 - Failed early!
# 2024-06-27 15:51:29.700 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/SetTheory/Game/PGame.lean'), full_name='SetTheory.PGame.leftMoves_add_cases'), status=<Status.FAILED: 'Failed'>, proof=None, actor_time=1.6985579505562782, environment_time=0.3626217246055603, total_time=2.076524280011654, num_total_nodes=35, num_searched_nodes=3)
# 2024-06-27 15:51:29.702 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Data/Finset/Basic.lean'), full_name='Finset.union_subset_left')
# 2024-06-27 15:57:11.892 | INFO     | search_utils:_best_first_search:447 - Search timed out.
# 2024-06-27 15:57:18.915 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Data/Finset/Basic.lean'), full_name='Finset.union_subset_left'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=142.2350523993373, environment_time=36.31859089061618, total_time=180.0713226981461, num_total_nodes=1702, num_searched_nodes=268)
# 2024-06-27 15:57:18.917 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Analysis/Analytic/Basic.lean'), full_name='HasFPowerSeriesOnBall.eventually_eq_zero')
# 2024-06-27 16:00:05.691 | INFO     | search_utils:_best_first_search:451 - Failed early!
# 2024-06-27 16:00:21.409 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Analysis/Analytic/Basic.lean'), full_name='HasFPowerSeriesOnBall.eventually_eq_zero'), status=<Status.FAILED: 'Failed'>, proof=None, actor_time=5.0671511851251125, environment_time=0.5431948862969875, total_time=5.636596158146858, num_total_nodes=72, num_searched_nodes=5)
# 2024-06-27 16:00:21.410 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/LinearAlgebra/Matrix/Symmetric.lean'), full_name='Matrix.IsSymm.smul')
# 2024-06-27 16:02:48.412 | INFO     | search_utils:_best_first_search:451 - Failed early!
# 2024-06-27 16:02:55.362 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/LinearAlgebra/Matrix/Symmetric.lean'), full_name='Matrix.IsSymm.smul'), status=<Status.FAILED: 'Failed'>, proof=None, actor_time=0.6610484011471272, environment_time=0.05927058309316635, total_time=0.7255625203251839, num_total_nodes=15, num_searched_nodes=1)
# 2024-06-27 16:02:55.364 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Order/UpperLower/Basic.lean'), full_name='isUpperSet_preimage_toDual_iff')
# 2024-06-27 16:05:37.006 | INFO     | search_utils:_best_first_search:455 - Found a proof!
# 2024-06-27 16:05:47.323 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Order/UpperLower/Basic.lean'), full_name='isUpperSet_preimage_toDual_iff'), status=<Status.PROVED: 'Proved'>, proof=['constructor', 'intro h', 'swap', 'intro h', "assumption'"], actor_time=8.786910992115736, environment_time=1.4435692802071571, total_time=10.311824757605791, num_total_nodes=135, num_searched_nodes=14)
# 2024-06-27 16:05:47.324 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Analysis/Calculus/FDeriv/Comp.lean'), full_name='DifferentiableOn.comp')
# 2024-06-27 16:11:16.611 | INFO     | search_utils:_best_first_search:447 - Search timed out.
# 2024-06-27 16:11:30.843 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Analysis/Calculus/FDeriv/Comp.lean'), full_name='DifferentiableOn.comp'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=145.8216876834631, environment_time=33.90772017464042, total_time=180.7212213985622, num_total_nodes=1136, num_searched_nodes=140)
# 2024-06-27 16:11:30.844 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/CategoryTheory/Limits/Shapes/BinaryProducts.lean'), full_name="CategoryTheory.Limits.prod.symmetry'")
# 2024-06-27 16:14:07.519 | INFO     | search_utils:_best_first_search:455 - Found a proof!
# 2024-06-27 16:14:14.643 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/CategoryTheory/Limits/Shapes/BinaryProducts.lean'), full_name="CategoryTheory.Limits.prod.symmetry'"), status=<Status.PROVED: 'Proved'>, proof=['simp'], actor_time=0.8518911525607109, environment_time=0.029037311673164368, total_time=0.885827723890543, num_total_nodes=2, num_searched_nodes=1)
# 2024-06-27 16:14:14.644 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Geometry/Manifold/ContMDiff/Basic.lean'), full_name='smooth_const')
# 2024-06-27 16:17:23.709 | INFO     | search_utils:_best_first_search:434 - Ran out of nodes to search.
# 2024-06-27 16:17:30.693 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Geometry/Manifold/ContMDiff/Basic.lean'), full_name='smooth_const'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=27.01860849186778, environment_time=3.5827844254672527, total_time=30.71351144090295, num_total_nodes=160, num_searched_nodes=20)
# 2024-06-27 16:17:30.694 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Topology/Algebra/Group/Basic.lean'), full_name='tendsto_inv')
# 2024-06-27 16:19:58.419 | INFO     | search_utils:_best_first_search:451 - Failed early!
# 2024-06-27 16:20:05.426 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Topology/Algebra/Group/Basic.lean'), full_name='tendsto_inv'), status=<Status.FAILED: 'Failed'>, proof=None, actor_time=0.7862310595810413, environment_time=0.1011858843266964, total_time=0.8931344263255596, num_total_nodes=13, num_searched_nodes=1)
# 2024-06-27 16:20:05.429 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Data/Set/Function.lean'), full_name="Set.bijOn_of_subsingleton'")
# 2024-06-27 16:23:03.989 | WARNING  | search_utils:search:404 - Dojo crashed with Unexpected EOF when proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Data/Set/Function.lean'), full_name="Set.bijOn_of_subsingleton'")
# 2024-06-27 16:23:11.192 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Data/Set/Function.lean'), full_name="Set.bijOn_of_subsingleton'"), status=<Status.OPEN: 'Open'>, proof=None, actor_time=16.172195065766573, environment_time=4.213470593094826, total_time=19.53179483860731, num_total_nodes=257, num_searched_nodes=22)
# 2024-06-27 16:23:11.193 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/MeasureTheory/Integral/Bochner.lean'), full_name='MeasureTheory.integral_map_equiv')
# 2024-06-27 16:26:16.257 | INFO     | search_utils:_best_first_search:451 - Failed early!
# 2024-06-27 16:26:23.268 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/MeasureTheory/Integral/Bochner.lean'), full_name='MeasureTheory.integral_map_equiv'), status=<Status.FAILED: 'Failed'>, proof=None, actor_time=0.837798360735178, environment_time=0.1260368376970291, total_time=0.9692058935761452, num_total_nodes=17, num_searched_nodes=1)
# 2024-06-27 16:26:23.270 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/MeasureTheory/MeasurableSpace/Defs.lean'), full_name='Set.Finite.measurableSet_biInter')
# 2024-06-27 16:28:54.366 | INFO     | search_utils:_best_first_search:451 - Failed early!
# 2024-06-27 16:29:01.429 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/MeasureTheory/MeasurableSpace/Defs.lean'), full_name='Set.Finite.measurableSet_biInter'), status=<Status.FAILED: 'Failed'>, proof=None, actor_time=1.4750600792467594, environment_time=0.3374767452478409, total_time=1.823241788893938, num_total_nodes=25, num_searched_nodes=2)
# 2024-06-27 16:29:01.430 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/LinearAlgebra/QuadraticForm/Prod.lean'), full_name='QuadraticForm.Isometry.snd_comp_inl')
# 2024-06-27 16:31:34.567 | INFO     | search_utils:_best_first_search:451 - Failed early!
# 2024-06-27 16:31:41.527 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/LinearAlgebra/QuadraticForm/Prod.lean'), full_name='QuadraticForm.Isometry.snd_comp_inl'), status=<Status.FAILED: 'Failed'>, proof=None, actor_time=0.7171725630760193, environment_time=0.02664801850914955, total_time=0.7488379366695881, num_total_nodes=7, num_searched_nodes=1)
# 2024-06-27 16:31:41.528 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/MeasureTheory/Measure/Restrict.lean'), full_name='MeasureTheory.NullMeasurable.measure_preimage_eq_measure_restrict_preimage_of_ae_compl_eq_const')
# 2024-06-27 16:34:19.852 | INFO     | search_utils:_best_first_search:451 - Failed early!
# 2024-06-27 16:34:27.316 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/MeasureTheory/Measure/Restrict.lean'), full_name='MeasureTheory.NullMeasurable.measure_preimage_eq_measure_restrict_preimage_of_ae_compl_eq_const'), status=<Status.FAILED: 'Failed'>, proof=None, actor_time=1.3497149646282196, environment_time=0.6502008028328419, total_time=2.0050172321498394, num_total_nodes=14, num_searched_nodes=1)
# 2024-06-27 16:34:27.316 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Algebra/Module/Submodule/Basic.lean'), full_name='Submodule.mem_carrier')
# 2024-06-27 16:36:54.162 | INFO     | search_utils:_best_first_search:455 - Found a proof!
# 2024-06-27 16:37:01.202 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Algebra/Module/Submodule/Basic.lean'), full_name='Submodule.mem_carrier'), status=<Status.PROVED: 'Proved'>, proof=['simp'], actor_time=0.5563346892595291, environment_time=0.012193277478218079, total_time=0.5734693855047226, num_total_nodes=2, num_searched_nodes=1)
# 2024-06-27 16:37:01.203 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Data/Polynomial/Reverse.lean'), full_name='Polynomial.coeff_one_reverse')
# 2024-06-27 16:42:31.530 | INFO     | search_utils:_best_first_search:447 - Search timed out.
# 2024-06-27 16:42:40.089 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Data/Polynomial/Reverse.lean'), full_name='Polynomial.coeff_one_reverse'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=126.70020319893956, environment_time=52.81983178853989, total_time=180.66102096810937, num_total_nodes=1179, num_searched_nodes=176)
# 2024-06-27 16:42:40.091 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/LinearAlgebra/QuadraticForm/Basic.lean'), full_name='QuadraticForm.associated_left_inverse')
# 2024-06-27 16:48:19.738 | INFO     | search_utils:_best_first_search:447 - Search timed out.
# 2024-06-27 16:48:33.402 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/LinearAlgebra/QuadraticForm/Basic.lean'), full_name='QuadraticForm.associated_left_inverse'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=106.3860455751419, environment_time=73.36207279935479, total_time=180.76533832028508, num_total_nodes=1141, num_searched_nodes=151)
# 2024-06-27 16:48:33.403 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Topology/Algebra/Module/FiniteDimension.lean'), full_name='LinearEquiv.coe_toContinuousLinearEquiv_symm')
# 2024-06-27 16:51:08.018 | INFO     | search_utils:_best_first_search:451 - Failed early!
# 2024-06-27 16:51:16.212 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Topology/Algebra/Module/FiniteDimension.lean'), full_name='LinearEquiv.coe_toContinuousLinearEquiv_symm'), status=<Status.FAILED: 'Failed'>, proof=None, actor_time=0.8131637759506702, environment_time=0.06691417098045349, total_time=0.8851713351905346, num_total_nodes=14, num_searched_nodes=1)
# 2024-06-27 16:51:16.213 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Algebra/BigOperators/Intervals.lean'), full_name='Finset.prod_Ico_reflect')
# 2024-06-27 16:53:47.699 | INFO     | search_utils:_best_first_search:451 - Failed early!
# 2024-06-27 16:54:02.175 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Algebra/BigOperators/Intervals.lean'), full_name='Finset.prod_Ico_reflect'), status=<Status.FAILED: 'Failed'>, proof=None, actor_time=0.8717322275042534, environment_time=0.1980736404657364, total_time=1.075191292911768, num_total_nodes=15, num_searched_nodes=1)
# 2024-06-27 16:54:02.177 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Order/Filter/Basic.lean'), full_name='Filter.Tendsto.neBot')
# 2024-06-27 16:56:58.066 | INFO     | search_utils:_best_first_search:455 - Found a proof!
# 2024-06-27 16:57:06.101 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Order/Filter/Basic.lean'), full_name='Filter.Tendsto.neBot'), status=<Status.PROVED: 'Proved'>, proof=['rw [Filter.neBot_iff] at hx ⊢', 'rintro rfl', 'simp at hx', 'simp [Filter.Tendsto, hx] at h'], actor_time=10.781816624104977, environment_time=4.357039276510477, total_time=15.259430438280106, num_total_nodes=183, num_searched_nodes=17)
# 2024-06-27 16:57:06.103 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Data/List/Dedup.lean'), full_name='List.dedup_subset')
# 2024-06-27 16:59:40.138 | INFO     | search_utils:_best_first_search:455 - Found a proof!
# 2024-06-27 16:59:47.126 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Data/List/Dedup.lean'), full_name='List.dedup_subset'), status=<Status.PROVED: 'Proved'>, proof=['intro l', 'intro x hx', 'simpa using hx'], actor_time=1.6069788821041584, environment_time=0.40232135728001595, total_time=2.025728203356266, num_total_nodes=24, num_searched_nodes=3)
# 2024-06-27 16:59:47.126 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Algebra/Order/Monovary.lean'), full_name='antivary_iff_forall_mul_nonpos')
# 2024-06-27 17:05:22.575 | INFO     | search_utils:_best_first_search:447 - Search timed out.
# 2024-06-27 17:05:31.016 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Algebra/Order/Monovary.lean'), full_name='antivary_iff_forall_mul_nonpos'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=129.86681924015284, environment_time=49.28614082187414, total_time=180.4250211007893, num_total_nodes=1499, num_searched_nodes=149)
# 2024-06-27 17:05:31.017 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Analysis/SpecialFunctions/Trigonometric/Inverse.lean'), full_name='Real.arccos_of_le_neg_one')
# 2024-06-27 17:07:56.716 | INFO     | search_utils:_best_first_search:455 - Found a proof!
# 2024-06-27 17:08:08.371 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Analysis/SpecialFunctions/Trigonometric/Inverse.lean'), full_name='Real.arccos_of_le_neg_one'), status=<Status.PROVED: 'Proved'>, proof=['simp [hx]'], actor_time=0.7543538957834244, environment_time=0.07476872578263283, total_time=0.8341347984969616, num_total_nodes=4, num_searched_nodes=1)
# 2024-06-27 17:08:08.373 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Data/Finset/Basic.lean'), full_name='Finset.exists_list_nodup_eq')
# 2024-06-27 17:10:57.358 | INFO     | search_utils:_best_first_search:451 - Failed early!
# 2024-06-27 17:11:04.425 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Data/Finset/Basic.lean'), full_name='Finset.exists_list_nodup_eq'), status=<Status.FAILED: 'Failed'>, proof=None, actor_time=0.7792752124369144, environment_time=0.13017193600535393, total_time=0.9144809693098068, num_total_nodes=14, num_searched_nodes=1)
# 2024-06-27 17:11:04.427 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Data/Set/Image.lean'), full_name='Set.range_diff_image_subset')
# 2024-06-27 17:13:36.291 | INFO     | search_utils:_best_first_search:451 - Failed early!
# 2024-06-27 17:13:47.302 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Data/Set/Image.lean'), full_name='Set.range_diff_image_subset'), status=<Status.FAILED: 'Failed'>, proof=None, actor_time=0.5330113209784031, environment_time=0.05736585333943367, total_time=0.5952844247221947, num_total_nodes=14, num_searched_nodes=1)
# 2024-06-27 17:13:47.304 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Algebra/IsPrimePow.lean'), full_name='isPrimePow_nat_iff')
# 2024-06-27 17:19:12.657 | INFO     | search_utils:_best_first_search:447 - Search timed out.
# 2024-06-27 17:19:21.015 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Algebra/IsPrimePow.lean'), full_name='isPrimePow_nat_iff'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=95.95058616250753, environment_time=84.20545504242182, total_time=181.07373178377748, num_total_nodes=899, num_searched_nodes=104)
# 2024-06-27 17:19:21.018 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/MeasureTheory/Measure/Restrict.lean'), full_name='MeasureTheory.Measure.restrict_eq_self')
# 2024-06-27 17:22:50.113 | INFO     | search_utils:_best_first_search:434 - Ran out of nodes to search.
# 2024-06-27 17:22:58.410 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/MeasureTheory/Measure/Restrict.lean'), full_name='MeasureTheory.Measure.restrict_eq_self'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=46.48526764288545, environment_time=8.089538533240557, total_time=54.86587245762348, num_total_nodes=292, num_searched_nodes=35)
# 2024-06-27 17:22:58.410 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Algebra/DirectLimit.lean'), full_name='AddCommGroup.DirectLimit.congr_symm_apply_of')
# 2024-06-27 17:25:50.463 | INFO     | search_utils:_best_first_search:451 - Failed early!
# 2024-06-27 17:26:04.811 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Algebra/DirectLimit.lean'), full_name='AddCommGroup.DirectLimit.congr_symm_apply_of'), status=<Status.FAILED: 'Failed'>, proof=None, actor_time=0.7126944772899151, environment_time=0.17112742364406586, total_time=0.8889097534120083, num_total_nodes=6, num_searched_nodes=1)
# 2024-06-27 17:26:04.812 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Algebra/Order/Ring/WithTop.lean'), full_name="WithTop.distrib'")
# 2024-06-27 17:31:35.961 | INFO     | search_utils:_best_first_search:447 - Search timed out.
# 2024-06-27 17:31:43.039 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Algebra/Order/Ring/WithTop.lean'), full_name="WithTop.distrib'"), status=<Status.OPEN: 'Open'>, proof=None, actor_time=141.73626216873527, environment_time=37.8700278326869, total_time=180.7952105924487, num_total_nodes=1522, num_searched_nodes=212)
# 2024-06-27 17:31:43.040 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Analysis/SpecialFunctions/Log/Basic.lean'), full_name='Real.continuousAt_log_iff')
# 2024-06-27 17:37:18.742 | INFO     | search_utils:_best_first_search:447 - Search timed out.
# 2024-06-27 17:37:25.734 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Analysis/SpecialFunctions/Log/Basic.lean'), full_name='Real.continuousAt_log_iff'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=141.71122654154897, environment_time=38.064036037772894, total_time=180.88180555030704, num_total_nodes=1733, num_searched_nodes=183)
# 2024-06-27 17:37:25.737 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Analysis/Normed/Group/Basic.lean'), full_name="ContinuousWithinAt.nnnorm'")
# 2024-06-27 17:40:05.491 | INFO     | search_utils:_best_first_search:451 - Failed early!
# 2024-06-27 17:40:12.987 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Analysis/Normed/Group/Basic.lean'), full_name="ContinuousWithinAt.nnnorm'"), status=<Status.FAILED: 'Failed'>, proof=None, actor_time=0.8101436123251915, environment_time=0.056722451001405716, total_time=0.8718888312578201, num_total_nodes=6, num_searched_nodes=1)
# 2024-06-27 17:40:12.989 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Algebra/GradedMonoid.lean'), full_name='GradedMonoid.mk_zero_pow')
# 2024-06-27 17:42:40.363 | INFO     | search_utils:_best_first_search:451 - Failed early!
# 2024-06-27 17:42:47.376 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Algebra/GradedMonoid.lean'), full_name='GradedMonoid.mk_zero_pow'), status=<Status.FAILED: 'Failed'>, proof=None, actor_time=0.7272864282131195, environment_time=0.057140834629535675, total_time=0.789552953094244, num_total_nodes=13, num_searched_nodes=1)
# 2024-06-27 17:42:47.378 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Algebra/Homology/HomotopyCategory/HomComplex.lean'), full_name='CochainComplex.HomComplex.Cochain.comp_assoc_of_first_is_zero_cochain')
# 2024-06-27 17:48:17.477 | INFO     | search_utils:_best_first_search:447 - Search timed out.
# 2024-06-27 17:48:24.455 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Algebra/Homology/HomotopyCategory/HomComplex.lean'), full_name='CochainComplex.HomComplex.Cochain.comp_assoc_of_first_is_zero_cochain'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=142.01079615205526, environment_time=37.83494686335325, total_time=180.7978172712028, num_total_nodes=1096, num_searched_nodes=159)
# 2024-06-27 17:48:24.456 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/MeasureTheory/Function/SimpleFunc.lean'), full_name='MeasureTheory.SimpleFunc.approx_apply')
# 2024-06-27 17:53:50.191 | INFO     | search_utils:_best_first_search:447 - Search timed out.
# 2024-06-27 17:53:57.280 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/MeasureTheory/Function/SimpleFunc.lean'), full_name='MeasureTheory.SimpleFunc.approx_apply'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=141.6160696260631, environment_time=37.46847966685891, total_time=180.11356230825186, num_total_nodes=934, num_searched_nodes=152)
# 2024-06-27 17:53:57.283 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Topology/PartialHomeomorph.lean'), full_name='PartialHomeomorph.isOpen_image_symm_of_subset_target')
# 2024-06-27 17:56:34.810 | INFO     | search_utils:_best_first_search:434 - Ran out of nodes to search.
# 2024-06-27 17:56:41.898 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Topology/PartialHomeomorph.lean'), full_name='PartialHomeomorph.isOpen_image_symm_of_subset_target'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=2.637653201818466, environment_time=0.4522325471043587, total_time=3.110562264919281, num_total_nodes=55, num_searched_nodes=4)
# 2024-06-27 17:56:41.900 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Computability/TuringMachine.lean'), full_name='Turing.ListBlank.tail_mk')
# 2024-06-27 17:59:15.848 | INFO     | search_utils:_best_first_search:455 - Found a proof!
# 2024-06-27 17:59:22.806 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Computability/TuringMachine.lean'), full_name='Turing.ListBlank.tail_mk'), status=<Status.PROVED: 'Proved'>, proof=['constructor'], actor_time=0.6018213778734207, environment_time=0.0048766545951366425, total_time=0.6115944869816303, num_total_nodes=3, num_searched_nodes=1)
# 2024-06-27 17:59:22.808 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/MeasureTheory/Function/L1Space.lean'), full_name='MeasureTheory.L1.dist_def')
# 2024-06-27 18:02:08.049 | INFO     | search_utils:_best_first_search:451 - Failed early!
# 2024-06-27 18:02:15.013 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/MeasureTheory/Function/L1Space.lean'), full_name='MeasureTheory.L1.dist_def'), status=<Status.FAILED: 'Failed'>, proof=None, actor_time=0.6741993725299835, environment_time=0.15453501045703888, total_time=0.8337963335216045, num_total_nodes=9, num_searched_nodes=1)
# 2024-06-27 18:02:15.016 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Algebra/Order/Field/Basic.lean'), full_name='inv_lt_of_inv_lt')
# 2024-06-27 18:07:42.077 | INFO     | search_utils:_best_first_search:447 - Search timed out.
# 2024-06-27 18:07:53.763 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Algebra/Order/Field/Basic.lean'), full_name='inv_lt_of_inv_lt'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=136.64999061450362, environment_time=42.05565043911338, total_time=180.06354273855686, num_total_nodes=2152, num_searched_nodes=233)
# 2024-06-27 18:07:53.764 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Topology/Algebra/InfiniteSum/Basic.lean'), full_name='hasSum_extend_zero')
# 2024-06-27 18:10:18.886 | INFO     | search_utils:_best_first_search:451 - Failed early!
# 2024-06-27 18:10:26.004 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Topology/Algebra/InfiniteSum/Basic.lean'), full_name='hasSum_extend_zero'), status=<Status.FAILED: 'Failed'>, proof=None, actor_time=0.9169937297701836, environment_time=0.06009364873170853, total_time=0.9821923561394215, num_total_nodes=9, num_searched_nodes=1)
# 2024-06-27 18:10:26.006 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/CategoryTheory/MorphismProperty.lean'), full_name='CategoryTheory.MorphismProperty.StableUnderBaseChange.unop')
# 2024-06-27 18:13:00.836 | INFO     | search_utils:_best_first_search:451 - Failed early!
# 2024-06-27 18:13:08.414 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/CategoryTheory/MorphismProperty.lean'), full_name='CategoryTheory.MorphismProperty.StableUnderBaseChange.unop'), status=<Status.FAILED: 'Failed'>, proof=None, actor_time=2.2864255271852016, environment_time=0.025637120008468628, total_time=2.3175157010555267, num_total_nodes=17, num_searched_nodes=1)
# 2024-06-27 18:13:08.417 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Order/SymmDiff.lean'), full_name='symmDiff_left_comm')
# 2024-06-27 18:15:36.564 | INFO     | search_utils:_best_first_search:451 - Failed early!
# ...
# 2024-06-27 20:14:28.448 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/CategoryTheory/Comma/Arrow.lean'), full_name='CategoryTheory.Arrow.isIso_of_isIso_left_of_isIso_right')
# 2024-06-27 20:16:59.172 | WARNING  | search_utils:search:426 - EOF
# 2024-06-27 20:16:59.175 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/RingTheory/DedekindDomain/Ideal.lean'), full_name='irreducible_pow_sup_of_le')
# 2024-06-27 20:23:39.952 | INFO     | search_utils:_best_first_search:447 - Search timed out.
# 2024-06-27 20:23:54.183 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/RingTheory/DedekindDomain/Ideal.lean'), full_name='irreducible_pow_sup_of_le'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=3.6529866345226765, environment_time=151.5235186778009, total_time=239.9903130196035, num_total_nodes=62, num_searched_nodes=4)
# 2024-06-27 20:23:54.184 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/GroupTheory/Subgroup/Basic.lean'), full_name='Subgroup.zpow_mem')
# 2024-06-27 20:26:37.717 | INFO     | search_utils:_best_first_search:451 - Failed early!
# 2024-06-27 20:26:44.744 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/GroupTheory/Subgroup/Basic.lean'), full_name='Subgroup.zpow_mem'), status=<Status.FAILED: 'Failed'>, proof=None, actor_time=0.7434082739055157, environment_time=0.0694550909101963, total_time=0.8177868239581585, num_total_nodes=5, num_searched_nodes=1)
# 2024-06-27 20:26:44.746 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Analysis/Normed/Group/Basic.lean'), full_name="pi_nnnorm_const'")
# 2024-06-27 20:30:24.004 | INFO     | search_utils:_best_first_search:434 - Ran out of nodes to search.
# 2024-06-27 20:30:32.421 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Analysis/Normed/Group/Basic.lean'), full_name="pi_nnnorm_const'"), status=<Status.OPEN: 'Open'>, proof=None, actor_time=26.119364105165005, environment_time=26.576163824647665, total_time=52.87558323889971, num_total_nodes=153, num_searched_nodes=23)
# 2024-06-27 20:30:32.423 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Topology/Gluing.lean'), full_name='TopCat.GlueData.rel_equiv')
# 2024-06-27 20:36:04.437 | INFO     | search_utils:_best_first_search:447 - Search timed out.
# 2024-06-27 20:36:18.020 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Topology/Gluing.lean'), full_name='TopCat.GlueData.rel_equiv'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=110.4284773170948, environment_time=69.4917712174356, total_time=181.2094788774848, num_total_nodes=1559, num_searched_nodes=161)
# 2024-06-27 20:36:18.021 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('.lake/packages/std/Std/Data/String/Lemmas.lean'), full_name='Substring.ValidFor.all')
# 2024-06-27 20:38:52.854 | WARNING  | search_utils:search:426 - EOF
# 2024-06-27 20:38:52.871 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Data/Set/Sups.lean'), full_name='Set.infs_subset_right')
# 2024-06-27 20:41:34.453 | INFO     | search_utils:_best_first_search:455 - Found a proof!
# 2024-06-27 20:41:41.843 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Data/Set/Sups.lean'), full_name='Set.infs_subset_right'), status=<Status.PROVED: 'Proved'>, proof=['intro', 'simp_rw [Set.subset_def]', 'aesop'], actor_time=12.720658633857965, environment_time=2.478165950626135, total_time=15.264851227402687, num_total_nodes=121, num_searched_nodes=11)
# 2024-06-27 20:41:41.845 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/MeasureTheory/MeasurableSpace/Basic.lean'), full_name='MeasurableEquiv.symm_mk')
# 2024-06-27 20:44:17.008 | INFO     | search_utils:_best_first_search:455 - Found a proof!
# 2024-06-27 20:44:25.856 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/MeasureTheory/MeasurableSpace/Basic.lean'), full_name='MeasurableEquiv.symm_mk'), status=<Status.PROVED: 'Proved'>, proof=['rfl'], actor_time=0.4897063300013542, environment_time=0.004435304552316666, total_time=0.49887000024318695, num_total_nodes=2, num_searched_nodes=1)
# 2024-06-27 20:44:25.857 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/LinearAlgebra/Dual.lean'), full_name='Module.forall_dual_apply_eq_zero_iff')
# 2024-06-27 20:50:00.878 | INFO     | search_utils:_best_first_search:447 - Search timed out.
# 2024-06-27 20:50:12.503 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/LinearAlgebra/Dual.lean'), full_name='Module.forall_dual_apply_eq_zero_iff'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=140.16683080792427, environment_time=38.502250857651234, total_time=180.04222482815385, num_total_nodes=1597, num_searched_nodes=246)
# 2024-06-27 20:50:12.504 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Order/Filter/Basic.lean'), full_name='Filter.EventuallyLE.compl')
# 2024-06-27 20:53:05.986 | INFO     | search_utils:_best_first_search:455 - Found a proof!
# 2024-06-27 20:53:13.093 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Order/Filter/Basic.lean'), full_name='Filter.EventuallyLE.compl'), status=<Status.PROVED: 'Proved'>, proof=['rw [Filter.EventuallyLE]', 'filter_upwards [h] with x hx', 'simp', 'intro h', 'exact hx.trans h'], actor_time=7.8571109883487225, environment_time=1.6675867065787315, total_time=9.5966402515769, num_total_nodes=153, num_searched_nodes=13)
# 2024-06-27 20:53:13.094 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Algebra/Homology/HomotopyCategory/MappingCone.lean'), full_name='CochainComplex.mappingCone.ext_to')
# 2024-06-27 20:55:44.040 | INFO     | search_utils:_best_first_search:451 - Failed early!
# 2024-06-27 20:55:55.617 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Algebra/Homology/HomotopyCategory/MappingCone.lean'), full_name='CochainComplex.mappingCone.ext_to'), status=<Status.FAILED: 'Failed'>, proof=None, actor_time=0.7196985669434071, environment_time=0.0881546102464199, total_time=0.8130246736109257, num_total_nodes=13, num_searched_nodes=1)
# 2024-06-27 20:55:55.618 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Topology/MetricSpace/Dilation.lean'), full_name='Dilation.ediam_image')
# 2024-06-27 21:01:22.682 | INFO     | search_utils:_best_first_search:447 - Search timed out.
# 2024-06-27 21:01:31.046 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Topology/MetricSpace/Dilation.lean'), full_name='Dilation.ediam_image'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=41.697330962866545, environment_time=137.9551995843649, total_time=180.02400500699878, num_total_nodes=311, num_searched_nodes=43)
# 2024-06-27 21:01:31.048 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Data/Nat/Digits.lean'), full_name='Nat.sum_le_ofDigits')
# 2024-06-27 21:07:08.019 | INFO     | search_utils:_best_first_search:447 - Search timed out.
# 2024-06-27 21:07:15.107 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Data/Nat/Digits.lean'), full_name='Nat.sum_le_ofDigits'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=133.31407349929214, environment_time=45.62870581448078, total_time=180.46027247980237, num_total_nodes=1618, num_searched_nodes=255)
# 2024-06-27 21:07:15.109 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Algebra/ContinuedFractions/Translations.lean'), full_name='GeneralizedContinuedFraction.first_denominator_eq')
# 2024-06-27 21:09:44.635 | INFO     | search_utils:_best_first_search:451 - Failed early!
# 2024-06-27 21:09:54.106 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Algebra/ContinuedFractions/Translations.lean'), full_name='GeneralizedContinuedFraction.first_denominator_eq'), status=<Status.FAILED: 'Failed'>, proof=None, actor_time=0.6250592619180679, environment_time=0.040816087275743484, total_time=0.670924223959446, num_total_nodes=11, num_searched_nodes=1)
# 2024-06-27 21:09:54.107 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Order/Lattice.lean'), full_name='inf_eq_right')
# 2024-06-27 21:12:59.276 | WARNING  | search_utils:search:404 - Dojo crashed with Unexpected EOF when proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Order/Lattice.lean'), full_name='inf_eq_right')
# 2024-06-27 21:13:06.388 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Order/Lattice.lean'), full_name='inf_eq_right'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=30.52084196358919, environment_time=4.238878075033426, total_time=34.17959211394191, num_total_nodes=412, num_searched_nodes=42)
# 2024-06-27 21:13:06.389 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Analysis/SpecialFunctions/Trigonometric/Deriv.lean'), full_name='Real.sinh_lt_self_iff')
# 2024-06-27 21:18:53.099 | INFO     | search_utils:_best_first_search:447 - Search timed out.
# 2024-06-27 21:19:01.458 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Analysis/SpecialFunctions/Trigonometric/Deriv.lean'), full_name='Real.sinh_lt_self_iff'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=125.5937353298068, environment_time=53.52021162584424, total_time=180.44724731519818, num_total_nodes=1495, num_searched_nodes=162)
# 2024-06-27 21:19:01.459 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Data/Set/UnionLift.lean'), full_name='Set.iUnionLift_const')
# 2024-06-27 21:24:27.785 | INFO     | search_utils:_best_first_search:447 - Search timed out.
# 2024-06-27 21:24:41.446 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Data/Set/UnionLift.lean'), full_name='Set.iUnionLift_const'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=112.01681428030133, environment_time=68.54428941383958, total_time=181.3078882098198, num_total_nodes=1078, num_searched_nodes=99)
# 2024-06-27 21:24:41.448 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/NumberTheory/LucasLehmer.lean'), full_name='LucasLehmer.X.mul_fst')
# 2024-06-27 21:27:03.052 | INFO     | search_utils:_best_first_search:455 - Found a proof!
# 2024-06-27 21:27:10.141 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/NumberTheory/LucasLehmer.lean'), full_name='LucasLehmer.X.mul_fst'), status=<Status.PROVED: 'Proved'>, proof=['rfl'], actor_time=0.4312765337526798, environment_time=0.42109737917780876, total_time=0.8576088771224022, num_total_nodes=5, num_searched_nodes=1)
# Solved 24 out of 100 theorems.

# %%
prover = BestFirstSearchProver(
    tac_gen=RAGTacticGenerator(0),
    timeout=180,
    num_sampled_tactics=16,
    debug=False
)
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# 2024-06-27 21:27:21.769 | INFO     | search_utils:__init__:210 - Building the corpus from leandojo_benchmark_4/corpus.jsonl

# %%
solved_count = 0
for i in range(0, 100):
    result = prover.search(theorems[i].repo, theorems[i], positions[i])
    if result is not None and result.status == Status.PROVED:
        solved_count += 1
print(f"Solved {solved_count} out of 100 theorems.")
# Out:
# 2024-06-27 21:27:43.110 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Order/Bounds/Basic.lean'), full_name='not_bddBelow_iff')
# 2024-06-27 21:30:25.492 | INFO     | search_utils:_best_first_search:455 - Found a proof!
# 2024-06-27 21:30:32.739 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Order/Bounds/Basic.lean'), full_name='not_bddBelow_iff'), status=<Status.PROVED: 'Proved'>, proof=['simp [BddBelow, BddBelow]', 'simp [Set.Nonempty, lowerBounds]'], actor_time=4.457783788442612, environment_time=1.1962122023105621, total_time=5.68161154165864, num_total_nodes=41, num_searched_nodes=5)
# 2024-06-27 21:30:32.742 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/MeasureTheory/Function/SimpleFuncDenseLp.lean'), full_name='MeasureTheory.Lp.simpleFunc.toLp_add')
# 2024-06-27 21:33:05.318 | INFO     | search_utils:_best_first_search:455 - Found a proof!
# 2024-06-27 21:33:15.275 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/MeasureTheory/Function/SimpleFuncDenseLp.lean'), full_name='MeasureTheory.Lp.simpleFunc.toLp_add'), status=<Status.PROVED: 'Proved'>, proof=['rfl'], actor_time=0.38586215302348137, environment_time=0.1720719076693058, total_time=0.5632046200335026, num_total_nodes=6, num_searched_nodes=1)
# 2024-06-27 21:33:15.278 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/SetTheory/Ordinal/Principal.lean'), full_name='Ordinal.mul_omega')
# 2024-06-27 21:35:53.115 | INFO     | search_utils:_best_first_search:434 - Ran out of nodes to search.
# 2024-06-27 21:36:00.244 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/SetTheory/Ordinal/Principal.lean'), full_name='Ordinal.mul_omega'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=1.70632728561759, environment_time=0.9723581001162529, total_time=2.695100348442793, num_total_nodes=43, num_searched_nodes=3)
# 2024-06-27 21:36:00.246 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/LinearAlgebra/Reflection.lean'), full_name='Module.preReflection_preReflection')
# 2024-06-27 21:41:29.353 | INFO     | search_utils:_best_first_search:447 - Search timed out.
# 2024-06-27 21:41:37.562 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/LinearAlgebra/Reflection.lean'), full_name='Module.preReflection_preReflection'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=52.906348805874586, environment_time=128.15846613794565, total_time=181.64594491943717, num_total_nodes=350, num_searched_nodes=70)
# 2024-06-27 21:41:37.563 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Order/ConditionallyCompleteLattice/Basic.lean'), full_name='OrderIso.map_ciSup')
# 2024-06-27 21:44:16.262 | INFO     | search_utils:_best_first_search:451 - Failed early!
# 2024-06-27 21:44:23.212 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Order/ConditionallyCompleteLattice/Basic.lean'), full_name='OrderIso.map_ciSup'), status=<Status.FAILED: 'Failed'>, proof=None, actor_time=0.8992007598280907, environment_time=0.37408918142318726, total_time=1.2836060784757137, num_total_nodes=14, num_searched_nodes=2)
# 2024-06-27 21:44:23.213 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/NumberTheory/LegendreSymbol/JacobiSymbol.lean'), full_name='jacobiSym.eq_zero_iff_not_coprime')
# 2024-06-27 21:49:57.898 | INFO     | search_utils:_best_first_search:447 - Search timed out.
# 2024-06-27 21:50:06.292 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/NumberTheory/LegendreSymbol/JacobiSymbol.lean'), full_name='jacobiSym.eq_zero_iff_not_coprime'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=124.9574442282319, environment_time=54.275288220494986, total_time=180.57600654289126, num_total_nodes=1610, num_searched_nodes=157)
# 2024-06-27 21:50:06.294 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Order/Bounds/Basic.lean'), full_name='IsLeast.dual')
# 2024-06-27 21:52:48.656 | INFO     | search_utils:_best_first_search:455 - Found a proof!
# 2024-06-27 21:52:55.569 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Order/Bounds/Basic.lean'), full_name='IsLeast.dual'), status=<Status.PROVED: 'Proved'>, proof=['constructor', 'simp only [Set.mem_preimage, Set.mem_def]', 'exact h.1', 'intro b hb', 'rw [Set.mem_preimage] at hb', 'exact h.2 hb'], actor_time=10.370444685220718, environment_time=1.2695000804960728, total_time=11.70954716950655, num_total_nodes=117, num_searched_nodes=13)
# 2024-06-27 21:52:55.571 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Probability/Distributions/Geometric.lean'), full_name='ProbabilityTheory.geometricPMFRealSum')
# 2024-06-27 21:58:23.075 | INFO     | search_utils:_best_first_search:447 - Search timed out.
# 2024-06-27 21:58:30.336 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Probability/Distributions/Geometric.lean'), full_name='ProbabilityTheory.geometricPMFRealSum'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=119.1363562233746, environment_time=60.33323822170496, total_time=180.81954713910818, num_total_nodes=1384, num_searched_nodes=156)
# 2024-06-27 21:58:30.337 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Data/List/Sigma.lean'), full_name='List.NodupKeys.sublist')
# 2024-06-27 22:04:04.175 | INFO     | search_utils:_best_first_search:447 - Search timed out.
# 2024-06-27 22:04:12.376 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Data/List/Sigma.lean'), full_name='List.NodupKeys.sublist'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=89.29990778118372, environment_time=89.64712636172771, total_time=180.16767305508256, num_total_nodes=1200, num_searched_nodes=148)
# 2024-06-27 22:04:12.379 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Data/List/BigOperators/Basic.lean'), full_name='Commute.list_prod_right')
# 2024-06-27 22:07:43.459 | INFO     | search_utils:_best_first_search:455 - Found a proof!
# 2024-06-27 22:07:57.122 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Data/List/BigOperators/Basic.lean'), full_name='Commute.list_prod_right'), status=<Status.PROVED: 'Proved'>, proof=["induction' l with y l ihl", 'simpa using h y', 'simp only [List.forall_mem_cons] at h', 'simp [h.1, ihl h.2]'], actor_time=54.59824765101075, environment_time=15.870666783303022, total_time=71.16176318004727, num_total_nodes=621, num_searched_nodes=80)
# 2024-06-27 22:07:57.123 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Order/Hom/Lattice.lean'), full_name='LatticeHom.coe_toSupHom')
# 2024-06-27 22:10:29.910 | INFO     | search_utils:_best_first_search:455 - Found a proof!
# 2024-06-27 22:10:36.803 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Order/Hom/Lattice.lean'), full_name='LatticeHom.coe_toSupHom'), status=<Status.PROVED: 'Proved'>, proof=['rfl'], actor_time=0.25456995517015457, environment_time=0.004923656582832336, total_time=0.2644112855195999, num_total_nodes=2, num_searched_nodes=1)
# 2024-06-27 22:10:36.804 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/SetTheory/Game/PGame.lean'), full_name='SetTheory.PGame.leftMoves_add_cases')
# 2024-06-27 22:13:14.361 | INFO     | search_utils:_best_first_search:451 - Failed early!
# 2024-06-27 22:13:23.789 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/SetTheory/Game/PGame.lean'), full_name='SetTheory.PGame.leftMoves_add_cases'), status=<Status.FAILED: 'Failed'>, proof=None, actor_time=0.37495264410972595, environment_time=0.10935674980282784, total_time=0.48950036987662315, num_total_nodes=8, num_searched_nodes=1)
# 2024-06-27 22:13:23.790 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Data/Finset/Basic.lean'), full_name='Finset.union_subset_left')
# 2024-06-27 22:16:10.290 | INFO     | search_utils:_best_first_search:455 - Found a proof!
# 2024-06-27 22:16:17.223 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Data/Finset/Basic.lean'), full_name='Finset.union_subset_left'), status=<Status.PROVED: 'Proved'>, proof=['intro x hx', 'by_contra H', 'apply H', 'exact h (Finset.mem_union_left _ hx)'], actor_time=3.6627836860716343, environment_time=1.38417199999094, total_time=5.089415192604065, num_total_nodes=87, num_searched_nodes=8)
# 2024-06-27 22:16:17.224 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Analysis/Analytic/Basic.lean'), full_name='HasFPowerSeriesOnBall.eventually_eq_zero')
# 2024-06-27 22:21:59.886 | INFO     | search_utils:_best_first_search:447 - Search timed out.
# 2024-06-27 22:22:12.544 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Analysis/Analytic/Basic.lean'), full_name='HasFPowerSeriesOnBall.eventually_eq_zero'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=134.38148784264922, environment_time=44.581267323344946, total_time=180.0166451483965, num_total_nodes=1030, num_searched_nodes=116)
# 2024-06-27 22:22:12.546 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/LinearAlgebra/Matrix/Symmetric.lean'), full_name='Matrix.IsSymm.smul')
# 2024-06-27 22:24:47.502 | INFO     | search_utils:_best_first_search:455 - Found a proof!
# 2024-06-27 22:24:54.426 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/LinearAlgebra/Matrix/Symmetric.lean'), full_name='Matrix.IsSymm.smul'), status=<Status.PROVED: 'Proved'>, proof=['simp_rw [Matrix.IsSymm] at h ⊢', 'simp [h]'], actor_time=1.4798974432051182, environment_time=0.4692264199256897, total_time=1.9653627537190914, num_total_nodes=25, num_searched_nodes=3)
# 2024-06-27 22:24:54.428 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Order/UpperLower/Basic.lean'), full_name='isUpperSet_preimage_toDual_iff')
# 2024-06-27 22:27:28.423 | INFO     | search_utils:_best_first_search:455 - Found a proof!
# 2024-06-27 22:27:35.362 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Order/UpperLower/Basic.lean'), full_name='isUpperSet_preimage_toDual_iff'), status=<Status.PROVED: 'Proved'>, proof=['rfl'], actor_time=0.6311908401548862, environment_time=0.007366310805082321, total_time=0.6435016691684723, num_total_nodes=2, num_searched_nodes=1)
# 2024-06-27 22:27:35.366 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Analysis/Calculus/FDeriv/Comp.lean'), full_name='DifferentiableOn.comp')
# 2024-06-27 22:30:08.604 | INFO     | search_utils:_best_first_search:451 - Failed early!
# 2024-06-27 22:30:20.423 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Analysis/Calculus/FDeriv/Comp.lean'), full_name='DifferentiableOn.comp'), status=<Status.FAILED: 'Failed'>, proof=None, actor_time=6.758829776197672, environment_time=1.4001207947731018, total_time=8.207720771431923, num_total_nodes=84, num_searched_nodes=9)
# 2024-06-27 22:30:20.424 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/CategoryTheory/Limits/Shapes/BinaryProducts.lean'), full_name="CategoryTheory.Limits.prod.symmetry'")
# 2024-06-27 22:32:57.563 | INFO     | search_utils:_best_first_search:455 - Found a proof!
# 2024-06-27 22:33:06.782 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/CategoryTheory/Limits/Shapes/BinaryProducts.lean'), full_name="CategoryTheory.Limits.prod.symmetry'"), status=<Status.PROVED: 'Proved'>, proof=['simp'], actor_time=0.8625656291842461, environment_time=0.031787991523742676, total_time=0.8992626704275608, num_total_nodes=2, num_searched_nodes=1)
# 2024-06-27 22:33:06.784 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Geometry/Manifold/ContMDiff/Basic.lean'), full_name='smooth_const')
# 2024-06-27 22:35:45.535 | INFO     | search_utils:_best_first_search:455 - Found a proof!
# 2024-06-27 22:35:54.843 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Geometry/Manifold/ContMDiff/Basic.lean'), full_name='smooth_const'), status=<Status.PROVED: 'Proved'>, proof=['simp only [Smooth]', 'exact contMDiff_const'], actor_time=3.132216554135084, environment_time=0.9567958153784275, total_time=4.117709711194038, num_total_nodes=42, num_searched_nodes=5)
# 2024-06-27 22:35:54.845 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Topology/Algebra/Group/Basic.lean'), full_name='tendsto_inv')
# 2024-06-27 22:38:39.223 | INFO     | search_utils:_best_first_search:434 - Ran out of nodes to search.
# 2024-06-27 22:38:46.281 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Topology/Algebra/Group/Basic.lean'), full_name='tendsto_inv'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=13.234413877129555, environment_time=1.758248619735241, total_time=15.100987501442432, num_total_nodes=132, num_searched_nodes=20)
# 2024-06-27 22:38:46.282 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Data/Set/Function.lean'), full_name="Set.bijOn_of_subsingleton'")
# 2024-06-27 22:44:22.060 | INFO     | search_utils:_best_first_search:447 - Search timed out.
# 2024-06-27 22:44:29.626 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Data/Set/Function.lean'), full_name="Set.bijOn_of_subsingleton'"), status=<Status.OPEN: 'Open'>, proof=None, actor_time=127.43954303488135, environment_time=54.04651936516166, total_time=182.28582241013646, num_total_nodes=913, num_searched_nodes=101)
# 2024-06-27 22:44:29.627 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/MeasureTheory/Integral/Bochner.lean'), full_name='MeasureTheory.integral_map_equiv')
# 2024-06-27 22:50:36.885 | INFO     | search_utils:_best_first_search:447 - Search timed out.
# 2024-06-27 22:50:43.926 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/MeasureTheory/Integral/Bochner.lean'), full_name='MeasureTheory.integral_map_equiv'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=144.104828864336, environment_time=35.821152202785015, total_time=180.60448828339577, num_total_nodes=723, num_searched_nodes=109)
# 2024-06-27 22:50:43.927 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/MeasureTheory/MeasurableSpace/Defs.lean'), full_name='Set.Finite.measurableSet_biInter')
# 2024-06-27 22:53:18.229 | INFO     | search_utils:_best_first_search:455 - Found a proof!
# 2024-06-27 22:53:31.111 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/MeasureTheory/MeasurableSpace/Defs.lean'), full_name='Set.Finite.measurableSet_biInter'), status=<Status.PROVED: 'Proved'>, proof=['haveI := hs.fintype', 'rw [Set.biInter_eq_iInter]', "refine' MeasurableSet.iInter fun b => _", 'exact h b b.2'], actor_time=5.7562481462955475, environment_time=0.813287541270256, total_time=6.619010157883167, num_total_nodes=37, num_searched_nodes=6)
# 2024-06-27 22:53:31.112 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/LinearAlgebra/QuadraticForm/Prod.lean'), full_name='QuadraticForm.Isometry.snd_comp_inl')
# 2024-06-27 22:56:00.246 | INFO     | search_utils:_best_first_search:455 - Found a proof!
# 2024-06-27 22:56:07.224 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/LinearAlgebra/QuadraticForm/Prod.lean'), full_name='QuadraticForm.Isometry.snd_comp_inl'), status=<Status.PROVED: 'Proved'>, proof=['rfl'], actor_time=1.0898102894425392, environment_time=0.02243262156844139, total_time=1.1172668151557446, num_total_nodes=4, num_searched_nodes=1)
# 2024-06-27 22:56:07.226 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/MeasureTheory/Measure/Restrict.lean'), full_name='MeasureTheory.NullMeasurable.measure_preimage_eq_measure_restrict_preimage_of_ae_compl_eq_const')
# 2024-06-27 23:01:43.212 | INFO     | search_utils:_best_first_search:447 - Search timed out.
# 2024-06-27 23:01:51.360 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/MeasureTheory/Measure/Restrict.lean'), full_name='MeasureTheory.NullMeasurable.measure_preimage_eq_measure_restrict_preimage_of_ae_compl_eq_const'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=110.84127857908607, environment_time=71.8130028322339, total_time=184.37955616787076, num_total_nodes=1834, num_searched_nodes=213)
# 2024-06-27 23:01:51.361 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Algebra/Module/Submodule/Basic.lean'), full_name='Submodule.mem_carrier')
# 2024-06-27 23:04:21.852 | INFO     | search_utils:_best_first_search:455 - Found a proof!
# 2024-06-27 23:04:28.838 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Algebra/Module/Submodule/Basic.lean'), full_name='Submodule.mem_carrier'), status=<Status.PROVED: 'Proved'>, proof=['simp'], actor_time=0.6218098625540733, environment_time=0.009230047464370728, total_time=0.6359168626368046, num_total_nodes=2, num_searched_nodes=1)
# 2024-06-27 23:04:28.840 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Data/Polynomial/Reverse.lean'), full_name='Polynomial.coeff_one_reverse')
# 2024-06-27 23:10:03.869 | INFO     | search_utils:_best_first_search:447 - Search timed out.
# 2024-06-27 23:10:12.490 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Data/Polynomial/Reverse.lean'), full_name='Polynomial.coeff_one_reverse'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=112.5791373513639, environment_time=66.91268968954682, total_time=180.5551253221929, num_total_nodes=1018, num_searched_nodes=155)
# 2024-06-27 23:10:12.492 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/LinearAlgebra/QuadraticForm/Basic.lean'), full_name='QuadraticForm.associated_left_inverse')
# 2024-06-27 23:15:16.854 | INFO     | search_utils:_best_first_search:455 - Found a proof!
# 2024-06-27 23:15:23.925 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/LinearAlgebra/QuadraticForm/Basic.lean'), full_name='QuadraticForm.associated_left_inverse'), status=<Status.PROVED: 'Proved'>, proof=['ext', 'simp', 'abel', 'rw [← h]', 'simp', 'abel', 'simp'], actor_time=94.66248583048582, environment_time=45.55634381622076, total_time=140.658483594656, num_total_nodes=559, num_searched_nodes=69)
# 2024-06-27 23:15:23.928 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Topology/Algebra/Module/FiniteDimension.lean'), full_name='LinearEquiv.coe_toContinuousLinearEquiv_symm')
# 2024-06-27 23:18:05.664 | INFO     | search_utils:_best_first_search:455 - Found a proof!
# 2024-06-27 23:18:12.741 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Topology/Algebra/Module/FiniteDimension.lean'), full_name='LinearEquiv.coe_toContinuousLinearEquiv_symm'), status=<Status.PROVED: 'Proved'>, proof=['rfl'], actor_time=0.6934242956340313, environment_time=0.012275271117687225, total_time=0.7106595821678638, num_total_nodes=2, num_searched_nodes=1)
# 2024-06-27 23:18:12.743 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Algebra/BigOperators/Intervals.lean'), full_name='Finset.prod_Ico_reflect')
# 2024-06-27 23:23:36.556 | INFO     | search_utils:_best_first_search:447 - Search timed out.
# 2024-06-27 23:23:45.260 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Algebra/BigOperators/Intervals.lean'), full_name='Finset.prod_Ico_reflect'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=98.79353177547455, environment_time=79.72137780115008, total_time=180.05909940600395, num_total_nodes=1285, num_searched_nodes=174)
# 2024-06-27 23:23:45.262 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Order/Filter/Basic.lean'), full_name='Filter.Tendsto.neBot')
# 2024-06-27 23:27:25.141 | INFO     | search_utils:_best_first_search:455 - Found a proof!
# 2024-06-27 23:27:33.475 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Order/Filter/Basic.lean'), full_name='Filter.Tendsto.neBot'), status=<Status.PROVED: 'Proved'>, proof=['rw [neBot_iff]', 'contrapose! h', 'simp [h, Filter.Tendsto]', 'exact hx.ne'], actor_time=39.79592666774988, environment_time=12.62637485936284, total_time=53.02945901826024, num_total_nodes=605, num_searched_nodes=73)
# 2024-06-27 23:27:33.477 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Data/List/Dedup.lean'), full_name='List.dedup_subset')
# 2024-06-27 23:30:06.990 | INFO     | search_utils:_best_first_search:455 - Found a proof!
# 2024-06-27 23:30:14.146 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Data/List/Dedup.lean'), full_name='List.dedup_subset'), status=<Status.PROVED: 'Proved'>, proof=['intro l hl', 'simp'], actor_time=1.4649413228034973, environment_time=0.2113029882311821, total_time=1.6927346996963024, num_total_nodes=28, num_searched_nodes=3)
# 2024-06-27 23:30:14.147 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Algebra/Order/Monovary.lean'), full_name='antivary_iff_forall_mul_nonpos')
# 2024-06-27 23:35:46.862 | INFO     | search_utils:_best_first_search:447 - Search timed out.
# 2024-06-27 23:36:02.158 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Algebra/Order/Monovary.lean'), full_name='antivary_iff_forall_mul_nonpos'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=131.34269507229328, environment_time=47.72059468924999, total_time=180.28579156845808, num_total_nodes=1798, num_searched_nodes=210)
# 2024-06-27 23:36:02.160 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Analysis/SpecialFunctions/Trigonometric/Inverse.lean'), full_name='Real.arccos_of_le_neg_one')
# 2024-06-27 23:38:37.050 | INFO     | search_utils:_best_first_search:455 - Found a proof!
# 2024-06-27 23:38:44.015 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Analysis/SpecialFunctions/Trigonometric/Inverse.lean'), full_name='Real.arccos_of_le_neg_one'), status=<Status.PROVED: 'Proved'>, proof=['simp', 'exact hx'], actor_time=0.9498021639883518, environment_time=0.11249379441142082, total_time=1.0727862678468227, num_total_nodes=11, num_searched_nodes=2)
# 2024-06-27 23:38:44.016 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Data/Finset/Basic.lean'), full_name='Finset.exists_list_nodup_eq')
# 2024-06-27 23:42:32.071 | INFO     | search_utils:_best_first_search:455 - Found a proof!
# 2024-06-27 23:42:39.090 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Data/Finset/Basic.lean'), full_name='Finset.exists_list_nodup_eq'), status=<Status.PROVED: 'Proved'>, proof=["refine' ⟨_, _, _⟩", 'swap', 'rotate_left', 'exact s.toList', 'swap', 'simp only [Finset.nodup_toList]', 'simp'], actor_time=41.05068011209369, environment_time=13.980040661990643, total_time=55.485461454838514, num_total_nodes=394, num_searched_nodes=81)
# 2024-06-27 23:42:39.092 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Data/Set/Image.lean'), full_name='Set.range_diff_image_subset')
# 2024-06-27 23:45:13.600 | INFO     | search_utils:_best_first_search:455 - Found a proof!
# 2024-06-27 23:45:25.639 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Data/Set/Image.lean'), full_name='Set.range_diff_image_subset'), status=<Status.PROVED: 'Proved'>, proof=['rw [Set.diff_subset_iff]', 'simp [Set.range_subset_iff]'], actor_time=2.252494517713785, environment_time=0.5648344494402409, total_time=2.8391712456941605, num_total_nodes=36, num_searched_nodes=4)
# 2024-06-27 23:45:25.641 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Algebra/IsPrimePow.lean'), full_name='isPrimePow_nat_iff')
# 2024-06-27 23:50:51.960 | INFO     | search_utils:_best_first_search:447 - Search timed out.
# 2024-06-27 23:51:00.642 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Algebra/IsPrimePow.lean'), full_name='isPrimePow_nat_iff'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=96.55354192852974, environment_time=82.83418291062117, total_time=180.56437825411558, num_total_nodes=993, num_searched_nodes=136)
# 2024-06-27 23:51:00.644 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/MeasureTheory/Measure/Restrict.lean'), full_name='MeasureTheory.Measure.restrict_eq_self')
# 2024-06-27 23:56:29.247 | INFO     | search_utils:_best_first_search:447 - Search timed out.
# 2024-06-27 23:56:36.322 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/MeasureTheory/Measure/Restrict.lean'), full_name='MeasureTheory.Measure.restrict_eq_self'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=148.6692402921617, environment_time=30.354562152177095, total_time=180.16608280315995, num_total_nodes=1353, num_searched_nodes=199)
# 2024-06-27 23:56:36.323 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Algebra/DirectLimit.lean'), full_name='AddCommGroup.DirectLimit.congr_symm_apply_of')
# 2024-06-27 23:59:21.720 | INFO     | search_utils:_best_first_search:451 - Failed early!
# 2024-06-27 23:59:34.294 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Algebra/DirectLimit.lean'), full_name='AddCommGroup.DirectLimit.congr_symm_apply_of'), status=<Status.FAILED: 'Failed'>, proof=None, actor_time=0.5282799936830997, environment_time=1.657589115202427, total_time=2.191204160451889, num_total_nodes=11, num_searched_nodes=1)
# 2024-06-27 23:59:34.295 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Algebra/Order/Ring/WithTop.lean'), full_name="WithTop.distrib'")
# 2024-06-28 00:02:06.551 | INFO     | search_utils:_best_first_search:451 - Failed early!
# 2024-06-28 00:02:13.575 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Algebra/Order/Ring/WithTop.lean'), full_name="WithTop.distrib'"), status=<Status.FAILED: 'Failed'>, proof=None, actor_time=0.7791535891592503, environment_time=0.057259514927864075, total_time=0.8416196741163731, num_total_nodes=14, num_searched_nodes=1)
# 2024-06-28 00:02:13.578 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Analysis/SpecialFunctions/Log/Basic.lean'), full_name='Real.continuousAt_log_iff')
# 2024-06-28 00:07:40.770 | INFO     | search_utils:_best_first_search:447 - Search timed out.
# 2024-06-28 00:07:47.845 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Analysis/SpecialFunctions/Log/Basic.lean'), full_name='Real.continuousAt_log_iff'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=128.73401655256748, environment_time=50.152003176510334, total_time=180.26153469085693, num_total_nodes=2147, num_searched_nodes=222)
# 2024-06-28 00:07:47.846 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Analysis/Normed/Group/Basic.lean'), full_name="ContinuousWithinAt.nnnorm'")
# 2024-06-28 00:10:23.714 | INFO     | search_utils:_best_first_search:451 - Failed early!
# 2024-06-28 00:10:30.763 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Analysis/Normed/Group/Basic.lean'), full_name="ContinuousWithinAt.nnnorm'"), status=<Status.FAILED: 'Failed'>, proof=None, actor_time=2.4161436930298805, environment_time=0.8810486681759357, total_time=3.3186603151261806, num_total_nodes=46, num_searched_nodes=4)
# 2024-06-28 00:10:30.766 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Algebra/GradedMonoid.lean'), full_name='GradedMonoid.mk_zero_pow')
# 2024-06-28 00:15:59.579 | INFO     | search_utils:_best_first_search:447 - Search timed out.
# 2024-06-28 00:16:08.361 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Algebra/GradedMonoid.lean'), full_name='GradedMonoid.mk_zero_pow'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=113.16770291700959, environment_time=65.0399075448513, total_time=180.25699162855744, num_total_nodes=1717, num_searched_nodes=224)
# 2024-06-28 00:16:08.364 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Algebra/Homology/HomotopyCategory/HomComplex.lean'), full_name='CochainComplex.HomComplex.Cochain.comp_assoc_of_first_is_zero_cochain')
# 2024-06-28 00:20:53.986 | INFO     | search_utils:_best_first_search:455 - Found a proof!
# 2024-06-28 00:21:02.497 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Algebra/Homology/HomotopyCategory/HomComplex.lean'), full_name='CochainComplex.HomComplex.Cochain.comp_assoc_of_first_is_zero_cochain'), status=<Status.PROVED: 'Proved'>, proof=['ext p q hpq', 'simp [CochainComplex.HomComplex.Cochain.comp]', 'congr 3', 'all_goals aesop'], actor_time=90.24151780456305, environment_time=39.213592410087585, total_time=130.16604102402925, num_total_nodes=699, num_searched_nodes=98)
# 2024-06-28 00:21:02.500 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/MeasureTheory/Function/SimpleFunc.lean'), full_name='MeasureTheory.SimpleFunc.approx_apply')
# 2024-06-28 00:23:41.090 | INFO     | search_utils:_best_first_search:451 - Failed early!
# 2024-06-28 00:23:48.108 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/MeasureTheory/Function/SimpleFunc.lean'), full_name='MeasureTheory.SimpleFunc.approx_apply'), status=<Status.FAILED: 'Failed'>, proof=None, actor_time=0.664088387042284, environment_time=0.06818072125315666, total_time=0.7372836098074913, num_total_nodes=8, num_searched_nodes=1)
# 2024-06-28 00:23:48.110 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Topology/PartialHomeomorph.lean'), full_name='PartialHomeomorph.isOpen_image_symm_of_subset_target')
# 2024-06-28 00:29:08.453 | INFO     | search_utils:_best_first_search:447 - Search timed out.
# 2024-06-28 00:29:16.731 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Topology/PartialHomeomorph.lean'), full_name='PartialHomeomorph.isOpen_image_symm_of_subset_target'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=147.50883132964373, environment_time=31.550174079835415, total_time=180.33571859821677, num_total_nodes=1634, num_searched_nodes=195)
# 2024-06-28 00:29:16.733 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Computability/TuringMachine.lean'), full_name='Turing.ListBlank.tail_mk')
# 2024-06-28 00:31:53.110 | INFO     | search_utils:_best_first_search:455 - Found a proof!
# 2024-06-28 00:32:00.136 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Computability/TuringMachine.lean'), full_name='Turing.ListBlank.tail_mk'), status=<Status.PROVED: 'Proved'>, proof=['rfl'], actor_time=0.3831683099269867, environment_time=0.003950323909521103, total_time=0.3920459672808647, num_total_nodes=2, num_searched_nodes=1)
# 2024-06-28 00:32:00.137 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/MeasureTheory/Function/L1Space.lean'), full_name='MeasureTheory.L1.dist_def')
# 2024-06-28 00:37:02.672 | INFO     | search_utils:_best_first_search:455 - Found a proof!
# 2024-06-28 00:37:11.264 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/MeasureTheory/Function/L1Space.lean'), full_name='MeasureTheory.L1.dist_def'), status=<Status.PROVED: 'Proved'>, proof=['simp [dist_edist]', 'congr 1', 'rw [MeasureTheory.Lp.edist_def]', 'simp [MeasureTheory.snorm]', "simp [MeasureTheory.snorm']", 'congr with a', 'rw [edist_eq_coe_nnnorm_sub]'], actor_time=105.24430707842112, environment_time=33.82728920131922, total_time=140.1257230564952, num_total_nodes=841, num_searched_nodes=121)
# 2024-06-28 00:37:11.265 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Algebra/Order/Field/Basic.lean'), full_name='inv_lt_of_inv_lt')
# 2024-06-28 00:42:45.013 | INFO     | search_utils:_best_first_search:447 - Search timed out.
# 2024-06-28 00:42:53.534 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Algebra/Order/Field/Basic.lean'), full_name='inv_lt_of_inv_lt'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=135.64681800454855, environment_time=42.63251115381718, total_time=180.63994078710675, num_total_nodes=1871, num_searched_nodes=280)
# 2024-06-28 00:42:53.535 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Topology/Algebra/InfiniteSum/Basic.lean'), full_name='hasSum_extend_zero')
# 2024-06-28 00:45:30.263 | INFO     | search_utils:_best_first_search:434 - Ran out of nodes to search.
# 2024-06-28 00:45:39.138 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Topology/Algebra/InfiniteSum/Basic.lean'), full_name='hasSum_extend_zero'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=6.306156910955906, environment_time=1.248174637556076, total_time=7.601438160985708, num_total_nodes=102, num_searched_nodes=9)
# 2024-06-28 00:45:39.139 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/CategoryTheory/MorphismProperty.lean'), full_name='CategoryTheory.MorphismProperty.StableUnderBaseChange.unop')
# 2024-06-28 00:51:16.556 | INFO     | search_utils:_best_first_search:447 - Search timed out.
# 2024-06-28 00:51:24.902 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/CategoryTheory/MorphismProperty.lean'), full_name='CategoryTheory.MorphismProperty.StableUnderBaseChange.unop'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=136.85398500040174, environment_time=44.62805017828941, total_time=182.78837109729648, num_total_nodes=1650, num_searched_nodes=146)
# 2024-06-28 00:51:24.903 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Order/SymmDiff.lean'), full_name='symmDiff_left_comm')
# 2024-06-28 00:53:59.666 | INFO     | search_utils:_best_first_search:455 - Found a proof!
# 2024-06-28 00:54:06.698 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Order/SymmDiff.lean'), full_name='symmDiff_left_comm'), status=<Status.PROVED: 'Proved'>, proof=['ac_rfl'], actor_time=0.5138098634779453, environment_time=0.027870483696460724, total_time=0.5466424375772476, num_total_nodes=3, num_searched_nodes=1)
# 2024-06-28 00:54:06.698 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/CategoryTheory/Types.lean'), full_name='CategoryTheory.hom_inv_id_apply')
# 2024-06-28 00:56:32.268 | INFO     | search_utils:_best_first_search:451 - Failed early!
# 2024-06-28 00:56:39.383 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/CategoryTheory/Types.lean'), full_name='CategoryTheory.hom_inv_id_apply'), status=<Status.FAILED: 'Failed'>, proof=None, actor_time=0.3145005814731121, environment_time=0.05491376668214798, total_time=0.3745906390249729, num_total_nodes=12, num_searched_nodes=1)
# 2024-06-28 00:56:39.385 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/RingTheory/Polynomial/Basic.lean'), full_name='Polynomial.exists_irreducible_of_natDegree_pos')
# 2024-06-28 01:02:17.923 | INFO     | search_utils:_best_first_search:447 - Search timed out.
# 2024-06-28 01:02:24.983 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/RingTheory/Polynomial/Basic.lean'), full_name='Polynomial.exists_irreducible_of_natDegree_pos'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=137.31098383292556, environment_time=41.94792293384671, total_time=180.58673688024282, num_total_nodes=1993, num_searched_nodes=229)
# 2024-06-28 01:02:24.984 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/ModelTheory/Algebra/Ring/Basic.lean'), full_name='FirstOrder.Ring.realize_one')
# 2024-06-28 01:04:48.250 | INFO     | search_utils:_best_first_search:455 - Found a proof!
# 2024-06-28 01:04:59.988 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/ModelTheory/Algebra/Ring/Basic.lean'), full_name='FirstOrder.Ring.realize_one'), status=<Status.PROVED: 'Proved'>, proof=['simp [Term.realize]'], actor_time=0.3947497680783272, environment_time=0.06642220914363861, total_time=0.46634862944483757, num_total_nodes=8, num_searched_nodes=1)
# 2024-06-28 01:04:59.989 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Combinatorics/Schnirelmann.lean'), full_name='exists_of_schnirelmannDensity_eq_zero')
# 2024-06-28 01:10:30.917 | INFO     | search_utils:_best_first_search:447 - Search timed out.
# 2024-06-28 01:10:39.535 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Combinatorics/Schnirelmann.lean'), full_name='exists_of_schnirelmannDensity_eq_zero'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=109.88004957139492, environment_time=68.86189201101661, total_time=180.27315970137715, num_total_nodes=1393, num_searched_nodes=171)
# 2024-06-28 01:10:39.538 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Algebra/Order/Sub/Defs.lean'), full_name='AddLECancellable.tsub_eq_of_eq_add_rev')
# 2024-06-28 01:13:09.940 | INFO     | search_utils:_best_first_search:434 - Ran out of nodes to search.
# 2024-06-28 01:13:22.977 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Algebra/Order/Sub/Defs.lean'), full_name='AddLECancellable.tsub_eq_of_eq_add_rev'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=0.8367631658911705, environment_time=0.1320783793926239, total_time=0.9790667481720448, num_total_nodes=27, num_searched_nodes=2)
# 2024-06-28 01:13:22.978 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Algebra/AddTorsor.lean'), full_name='vadd_right_cancel_iff')
# 2024-06-28 01:18:52.927 | INFO     | search_utils:_best_first_search:447 - Search timed out.
# 2024-06-28 01:19:01.428 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Algebra/AddTorsor.lean'), full_name='vadd_right_cancel_iff'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=33.82889998704195, environment_time=146.01082871481776, total_time=180.19012819603086, num_total_nodes=376, num_searched_nodes=53)
# 2024-06-28 01:19:01.430 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Data/Finset/Image.lean'), full_name='Finset.map_perm')
# 2024-06-28 01:21:45.558 | INFO     | search_utils:_best_first_search:434 - Ran out of nodes to search.
# 2024-06-28 01:21:52.651 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Data/Finset/Image.lean'), full_name='Finset.map_perm'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=6.910877823829651, environment_time=1.1423638425767422, total_time=8.106016550213099, num_total_nodes=89, num_searched_nodes=10)
# 2024-06-28 01:21:52.652 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/GroupTheory/SpecificGroups/Coxeter.lean'), full_name='CoxeterGroup.of_apply')
# 2024-06-28 01:24:20.177 | INFO     | search_utils:_best_first_search:455 - Found a proof!
# 2024-06-28 01:24:27.162 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/GroupTheory/SpecificGroups/Coxeter.lean'), full_name='CoxeterGroup.of_apply'), status=<Status.PROVED: 'Proved'>, proof=['rfl'], actor_time=0.5443793199956417, environment_time=0.003533061593770981, total_time=0.5528275296092033, num_total_nodes=2, num_searched_nodes=1)
# 2024-06-28 01:24:27.164 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/SetTheory/ZFC/Basic.lean'), full_name='PSet.Resp.Equiv.euc')
# 2024-06-28 01:27:04.242 | WARNING  | search_utils:search:426 - EOF
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 4
#       2 for i in range(0, 100):
#       3     result = prover.search(theorems[i].repo, theorems[i], positions[i])
# ----> 4     if result.status == Status.PROVED:
#       5         solved_count += 1
#       6 print(f"Solved {solved_count} out of 100 theorems.")
#
# AttributeError: 'NoneType' object has no attribute 'status'
