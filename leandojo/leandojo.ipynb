# %%
import json
from pathlib import Path
import os

from lean_dojo import LeanGitRepo, Theorem, Pos

# Configure the path to the benchmark data
DST_DIR = Path("./leandojo_benchmark_4")

corpus_path = DST_DIR / 'corpus.jsonl'
lines = list(corpus_path.open())
file_in_corpus = json.loads(lines[2000])
file_in_corpus.keys()

ELAN_PATH = os.path.join(os.environ['HOME'], '.elan', 'bin')
os.environ['PATH'] = ELAN_PATH + ':' + os.environ['PATH']

data_path = DST_DIR / "random/"
split = "test"

# Load the data
data = json.load(open(os.path.join(data_path, f"{split}.json")))

theorems = []
positions = []

for t in data:
    repo = LeanGitRepo(t["url"], t["commit"])
    theorems.append(Theorem(repo, t["file_path"], t["full_name"]))
    positions.append(Pos(*t["start"]))
# Out:
# dict_keys(['path', 'imports', 'premises'])

# %%
import hashlib

theorems_and_positions = list(zip(theorems, positions))
theorems_and_positions.sort(
        key=lambda x: hashlib.md5(
            f"{x[0].file_path}:{x[0].full_name}".encode()
        ).hexdigest()
    )
theorems, positions = zip(*theorems_and_positions)
theorems, positions = list(theorems), list(positions)

# %%
metadata = json.load(open(os.path.join(data_path, "../metadata.json")))
repo = LeanGitRepo(metadata["from_repo"]["url"], metadata["from_repo"]["commit"])

# %%
import torch
from typing import Union, List
from transformers import AutoTokenizer, AutoModelForTextEncoding, AutoModelForSeq2SeqLM

tokenizer = AutoTokenizer.from_pretrained("kaiyuy/leandojo-lean4-retriever-byt5-small", device_map='cuda')
model = AutoModelForTextEncoding.from_pretrained("kaiyuy/leandojo-lean4-retriever-byt5-small", device_map='cuda')

@torch.no_grad()
def encode(s: Union[str, List[str]]) -> torch.Tensor:
    """Encode texts into feature vectors."""
    if isinstance(s, str):
        s = [s]
        should_squeeze = True
    else:
        should_squeeze = False
    tokenized_s = tokenizer(s, return_tensors="pt", padding=True)
    hidden_state = model(tokenized_s.input_ids.cuda()).last_hidden_state
    lens = tokenized_s.attention_mask.sum(dim=1)
    features = (hidden_state * tokenized_s.attention_mask.unsqueeze(2).cuda()).sum(dim=1) / lens.unsqueeze(1).cuda()
    if should_squeeze:
      features = features.squeeze()
    return features

@torch.no_grad()
def retrieve(state: str, premises: List[str], k: int) -> List[str]:
    """Retrieve the top-k premises given a state."""
    state_emb = encode(state)
    premise_embs = encode(premises)
    scores = (state_emb @ premise_embs.T)
    topk = scores.topk(k).indices.tolist()
    return [premises[i] for i in topk]
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
from search_utils import *

corpus = Corpus(DST_DIR / "corpus.jsonl")
corpus_embeddings = torch.zeros(
    len(corpus.all_premises),
    1472,
    dtype=torch.float32,
    device=torch.device("cuda"),
)
corpus_embeddings.shape
# Out:
# 2024-06-28 13:11:58.675 | INFO     | search_utils:__init__:210 - Building the corpus from leandojo_benchmark_4/corpus.jsonl
# torch.Size([171581, 1472])

# %% [markdown]
# When running for the first time, compute the embeddings.

# %%
#from tqdm.auto import tqdm

#for i, premise in tqdm(enumerate(corpus.all_premises), total=len(corpus.all_premises)):
#    corpus_embeddings[i] = encode(premise.code).detach()
#torch.save(corpus_embeddings, DST_DIR / "corpus.pt")
#corpus_embeddings.size()

# %%
corpus_embedding = torch.load(DST_DIR / "corpus.pt", weights_only=True)

# %%
class RAGTacticGenerator:
    def __init__(self, k_premises=16):
        self.retriever = AutoModelForTextEncoding.from_pretrained("kaiyuy/leandojo-lean4-retriever-byt5-small", device_map='cuda')
        self.prover = AutoModelForSeq2SeqLM.from_pretrained("kaiyuy/leandojo-lean4-retriever-tacgen-byt5-small", device_map='cuda')
        self.tokenizer = AutoTokenizer.from_pretrained("kaiyuy/leandojo-lean4-retriever-tacgen-byt5-small", device_map='cuda')
        self.corpus = Corpus(DST_DIR / "corpus.jsonl")
        self.corpus_embedding = torch.load(DST_DIR / "corpus.pt", weights_only=True)
        self.k_premises = k_premises

    def generate(self, state, file_path, theorem_full_name, theorem_pos, num_samples):
        accessible_premises = self.corpus.get_accessible_premise_indexes(file_path, theorem_pos)
        accessible_premises = torch.topk(
            encode(state) @ self.corpus_embedding[accessible_premises].T,
            self.k_premises
        ).indices
        retrieved_premises = [self.corpus[premise].code for premise in accessible_premises]
        input = "\n\n".join(retrieved_premises + [state])
        tokenized_input = self.tokenizer(input, return_tensors="pt", max_length=2300, truncation=True)
        result = self.prover.generate(
            tokenized_input.input_ids.cuda(),
            max_length=1024,
            num_beams=num_samples,
            length_penalty=0.0,
            do_sample=False,
            num_return_sequences=num_samples,
            early_stopping=False,
            output_scores=True,
            return_dict_in_generate=True,
        )
        tactics = self.tokenizer.batch_decode(result['sequences'], skip_special_tokens=True)
        probs = result[1]
        return [(remove_marks(tac), prob) for tac, prob in zip(tactics, probs)]

# %%
prover = BestFirstSearchProver(
    tac_gen=RAGTacticGenerator(),
    timeout=180,
    num_sampled_tactics=16,
    debug=False
)
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# 2024-06-28 13:12:22.849 | INFO     | search_utils:__init__:210 - Building the corpus from leandojo_benchmark_4/corpus.jsonl

# %%
solved_count = 0
for i in range(0, 100):
    result = prover.search(theorems[i].repo, theorems[i], positions[i])
    if result is not None and result.status == Status.PROVED:
        solved_count += 1
print(f"Solved {solved_count} out of 100 theorems.")
# Out:
# 2024-06-28 13:12:44.815 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Order/Bounds/Basic.lean'), full_name='not_bddBelow_iff')
# 2024-06-28 13:14:57.029 | INFO     | search_utils:_best_first_search:455 - Found a proof!
# 2024-06-28 13:15:10.934 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Order/Bounds/Basic.lean'), full_name='not_bddBelow_iff'), status=<Status.PROVED: 'Proved'>, proof=['simp [BddBelow]', 'simp [Set.Nonempty, lowerBounds]'], actor_time=2.4163001105189323, environment_time=0.7816500924527645, total_time=3.2230362743139267, num_total_nodes=27, num_searched_nodes=3)
# 2024-06-28 13:15:10.935 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/MeasureTheory/Function/SimpleFuncDenseLp.lean'), full_name='MeasureTheory.Lp.simpleFunc.toLp_add')
# 2024-06-28 13:17:25.809 | INFO     | search_utils:_best_first_search:451 - Failed early!
# 2024-06-28 13:17:35.843 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/MeasureTheory/Function/SimpleFuncDenseLp.lean'), full_name='MeasureTheory.Lp.simpleFunc.toLp_add'), status=<Status.FAILED: 'Failed'>, proof=None, actor_time=1.1860543936491013, environment_time=0.17060870304703712, total_time=1.3618533574044704, num_total_nodes=15, num_searched_nodes=1)
# 2024-06-28 13:17:35.844 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/SetTheory/Ordinal/Principal.lean'), full_name='Ordinal.mul_omega')
# 2024-06-28 13:19:47.460 | INFO     | search_utils:_best_first_search:451 - Failed early!
# 2024-06-28 13:19:58.114 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/SetTheory/Ordinal/Principal.lean'), full_name='Ordinal.mul_omega'), status=<Status.FAILED: 'Failed'>, proof=None, actor_time=0.7755839750170708, environment_time=0.10865050926804543, total_time=0.8896981440484524, num_total_nodes=17, num_searched_nodes=1)
# 2024-06-28 13:19:58.115 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/LinearAlgebra/Reflection.lean'), full_name='Module.preReflection_preReflection')
# 2024-06-28 13:25:01.502 | INFO     | search_utils:_best_first_search:447 - Search timed out.
# 2024-06-28 13:25:09.236 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/LinearAlgebra/Reflection.lean'), full_name='Module.preReflection_preReflection'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=79.35549866780639, environment_time=100.44279656559229, total_time=180.38291764259338, num_total_nodes=380, num_searched_nodes=66)
# 2024-06-28 13:25:09.237 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Order/ConditionallyCompleteLattice/Basic.lean'), full_name='OrderIso.map_ciSup')
# 2024-06-28 13:30:25.726 | INFO     | search_utils:_best_first_search:447 - Search timed out.
# 2024-06-28 13:30:34.129 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Order/ConditionallyCompleteLattice/Basic.lean'), full_name='OrderIso.map_ciSup'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=156.14266957342625, environment_time=22.986639749258757, total_time=180.4894153214991, num_total_nodes=991, num_searched_nodes=173)
# 2024-06-28 13:30:34.130 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/NumberTheory/LegendreSymbol/JacobiSymbol.lean'), full_name='jacobiSym.eq_zero_iff_not_coprime')
# 2024-06-28 13:36:00.341 | INFO     | search_utils:_best_first_search:447 - Search timed out.
# 2024-06-28 13:36:08.411 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/NumberTheory/LegendreSymbol/JacobiSymbol.lean'), full_name='jacobiSym.eq_zero_iff_not_coprime'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=66.89494024589658, environment_time=121.50723684579134, total_time=189.1826985962689, num_total_nodes=898, num_searched_nodes=91)
# 2024-06-28 13:36:08.414 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Order/Bounds/Basic.lean'), full_name='IsLeast.dual')
# 2024-06-28 13:38:15.083 | INFO     | search_utils:_best_first_search:455 - Found a proof!
# 2024-06-28 13:38:28.204 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Order/Bounds/Basic.lean'), full_name='IsLeast.dual'), status=<Status.PROVED: 'Proved'>, proof=['rcases h with ⟨b, hb⟩', 'exact ⟨b, hb⟩'], actor_time=2.3409090600907803, environment_time=0.20385373011231422, total_time=2.5599901154637337, num_total_nodes=28, num_searched_nodes=3)
# 2024-06-28 13:38:28.206 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Probability/Distributions/Geometric.lean'), full_name='ProbabilityTheory.geometricPMFRealSum')
# 2024-06-28 13:43:30.978 | INFO     | search_utils:_best_first_search:447 - Search timed out.
# 2024-06-28 13:43:39.542 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Probability/Distributions/Geometric.lean'), full_name='ProbabilityTheory.geometricPMFRealSum'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=96.1542668491602, environment_time=83.63474367558956, total_time=180.77846552059054, num_total_nodes=800, num_searched_nodes=126)
# 2024-06-28 13:43:39.545 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Data/List/Sigma.lean'), full_name='List.NodupKeys.sublist')
# 2024-06-28 13:48:49.084 | INFO     | search_utils:_best_first_search:447 - Search timed out.
# 2024-06-28 13:48:57.634 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Data/List/Sigma.lean'), full_name='List.NodupKeys.sublist'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=124.65993433073163, environment_time=54.020254999399185, total_time=180.30423605069518, num_total_nodes=1638, num_searched_nodes=172)
# 2024-06-28 13:48:57.637 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Data/List/BigOperators/Basic.lean'), full_name='Commute.list_prod_right')
# 2024-06-28 13:54:06.948 | INFO     | search_utils:_best_first_search:447 - Search timed out.
# 2024-06-28 13:54:21.383 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Data/List/BigOperators/Basic.lean'), full_name='Commute.list_prod_right'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=139.63871335238218, environment_time=39.30320616811514, total_time=180.32863141223788, num_total_nodes=1593, num_searched_nodes=182)
# 2024-06-28 13:54:21.384 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Order/Hom/Lattice.lean'), full_name='LatticeHom.coe_toSupHom')
# 2024-06-28 13:56:33.042 | INFO     | search_utils:_best_first_search:455 - Found a proof!
# 2024-06-28 13:56:40.089 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Order/Hom/Lattice.lean'), full_name='LatticeHom.coe_toSupHom'), status=<Status.PROVED: 'Proved'>, proof=['constructor'], actor_time=0.6253555789589882, environment_time=0.0027301982045173645, total_time=0.6329745687544346, num_total_nodes=2, num_searched_nodes=1)
# 2024-06-28 13:56:40.090 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/SetTheory/Game/PGame.lean'), full_name='SetTheory.PGame.leftMoves_add_cases')
# 2024-06-28 13:58:55.350 | INFO     | search_utils:_best_first_search:451 - Failed early!
# 2024-06-28 13:59:06.143 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/SetTheory/Game/PGame.lean'), full_name='SetTheory.PGame.leftMoves_add_cases'), status=<Status.FAILED: 'Failed'>, proof=None, actor_time=1.6309299990534782, environment_time=0.3804192878305912, total_time=2.026148408651352, num_total_nodes=35, num_searched_nodes=3)
# 2024-06-28 13:59:06.144 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Data/Finset/Basic.lean'), full_name='Finset.union_subset_left')
# 2024-06-28 14:04:25.542 | INFO     | search_utils:_best_first_search:447 - Search timed out.
# 2024-06-28 14:04:34.182 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Data/Finset/Basic.lean'), full_name='Finset.union_subset_left'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=146.51345724612474, environment_time=32.011651426553726, total_time=180.25872334092855, num_total_nodes=1559, num_searched_nodes=234)
# 2024-06-28 14:04:34.183 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Analysis/Analytic/Basic.lean'), full_name='HasFPowerSeriesOnBall.eventually_eq_zero')
# 2024-06-28 14:06:58.593 | INFO     | search_utils:_best_first_search:451 - Failed early!
# 2024-06-28 14:07:11.363 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Analysis/Analytic/Basic.lean'), full_name='HasFPowerSeriesOnBall.eventually_eq_zero'), status=<Status.FAILED: 'Failed'>, proof=None, actor_time=5.066448379307985, environment_time=0.6165113598108292, total_time=5.709476910531521, num_total_nodes=72, num_searched_nodes=5)
# 2024-06-28 14:07:11.365 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/LinearAlgebra/Matrix/Symmetric.lean'), full_name='Matrix.IsSymm.smul')
# 2024-06-28 14:09:19.727 | INFO     | search_utils:_best_first_search:451 - Failed early!
# 2024-06-28 14:09:27.280 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/LinearAlgebra/Matrix/Symmetric.lean'), full_name='Matrix.IsSymm.smul'), status=<Status.FAILED: 'Failed'>, proof=None, actor_time=0.6510173492133617, environment_time=0.05154787376523018, total_time=0.7076558172702789, num_total_nodes=15, num_searched_nodes=1)
# 2024-06-28 14:09:27.281 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Order/UpperLower/Basic.lean'), full_name='isUpperSet_preimage_toDual_iff')
# 2024-06-28 14:11:42.788 | INFO     | search_utils:_best_first_search:455 - Found a proof!
# 2024-06-28 14:11:49.895 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Order/UpperLower/Basic.lean'), full_name='isUpperSet_preimage_toDual_iff'), status=<Status.PROVED: 'Proved'>, proof=['constructor', 'intro h', 'swap', 'intro h', "assumption'"], actor_time=8.734359927475452, environment_time=1.518167119473219, total_time=10.332432199269533, num_total_nodes=135, num_searched_nodes=14)
# 2024-06-28 14:11:49.897 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Analysis/Calculus/FDeriv/Comp.lean'), full_name='DifferentiableOn.comp')
# 2024-06-28 14:17:02.844 | INFO     | search_utils:_best_first_search:447 - Search timed out.
# 2024-06-28 14:17:16.947 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Analysis/Calculus/FDeriv/Comp.lean'), full_name='DifferentiableOn.comp'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=145.7242393195629, environment_time=34.09865663945675, total_time=180.79296174645424, num_total_nodes=1138, num_searched_nodes=141)
# 2024-06-28 14:17:16.948 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/CategoryTheory/Limits/Shapes/BinaryProducts.lean'), full_name="CategoryTheory.Limits.prod.symmetry'")
# 2024-06-28 14:19:29.530 | INFO     | search_utils:_best_first_search:455 - Found a proof!
# 2024-06-28 14:19:40.604 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/CategoryTheory/Limits/Shapes/BinaryProducts.lean'), full_name="CategoryTheory.Limits.prod.symmetry'"), status=<Status.PROVED: 'Proved'>, proof=['simp'], actor_time=0.8516274876892567, environment_time=0.029168639332056046, total_time=0.8858596719801426, num_total_nodes=2, num_searched_nodes=1)
# 2024-06-28 14:19:40.607 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Geometry/Manifold/ContMDiff/Basic.lean'), full_name='smooth_const')
# 2024-06-28 14:22:25.714 | INFO     | search_utils:_best_first_search:434 - Ran out of nodes to search.
# 2024-06-28 14:22:32.794 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Geometry/Manifold/ContMDiff/Basic.lean'), full_name='smooth_const'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=26.90218797698617, environment_time=3.5540721714496613, total_time=30.564714070409536, num_total_nodes=160, num_searched_nodes=20)
# 2024-06-28 14:22:32.797 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Topology/Algebra/Group/Basic.lean'), full_name='tendsto_inv')
# 2024-06-28 14:24:46.205 | INFO     | search_utils:_best_first_search:451 - Failed early!
# 2024-06-28 14:24:53.509 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Topology/Algebra/Group/Basic.lean'), full_name='tendsto_inv'), status=<Status.FAILED: 'Failed'>, proof=None, actor_time=0.7875512056052685, environment_time=0.1161007210612297, total_time=0.9087693020701408, num_total_nodes=13, num_searched_nodes=1)
# 2024-06-28 14:24:53.510 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Data/Set/Function.lean'), full_name="Set.bijOn_of_subsingleton'")
# 2024-06-28 14:27:33.856 | WARNING  | search_utils:search:404 - Dojo crashed with Unexpected EOF when proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Data/Set/Function.lean'), full_name="Set.bijOn_of_subsingleton'")
# 2024-06-28 14:27:42.107 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Data/Set/Function.lean'), full_name="Set.bijOn_of_subsingleton'"), status=<Status.OPEN: 'Open'>, proof=None, actor_time=16.10841081291437, environment_time=4.3422581143677235, total_time=19.605699870735407, num_total_nodes=257, num_searched_nodes=22)
# 2024-06-28 14:27:42.108 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/MeasureTheory/Integral/Bochner.lean'), full_name='MeasureTheory.integral_map_equiv')
# 2024-06-28 14:30:25.491 | INFO     | search_utils:_best_first_search:451 - Failed early!
# 2024-06-28 14:30:32.548 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/MeasureTheory/Integral/Bochner.lean'), full_name='MeasureTheory.integral_map_equiv'), status=<Status.FAILED: 'Failed'>, proof=None, actor_time=0.8323455527424812, environment_time=0.11972183734178543, total_time=0.9571556262671947, num_total_nodes=17, num_searched_nodes=1)
# 2024-06-28 14:30:32.549 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/MeasureTheory/MeasurableSpace/Defs.lean'), full_name='Set.Finite.measurableSet_biInter')
# 2024-06-28 14:32:34.565 | INFO     | search_utils:_best_first_search:451 - Failed early!
# 2024-06-28 14:32:41.924 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/MeasureTheory/MeasurableSpace/Defs.lean'), full_name='Set.Finite.measurableSet_biInter'), status=<Status.FAILED: 'Failed'>, proof=None, actor_time=1.502071339637041, environment_time=0.337157916277647, total_time=1.8496861830353737, num_total_nodes=25, num_searched_nodes=2)
# 2024-06-28 14:32:41.926 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/LinearAlgebra/QuadraticForm/Prod.lean'), full_name='QuadraticForm.Isometry.snd_comp_inl')
# 2024-06-28 14:34:53.659 | INFO     | search_utils:_best_first_search:451 - Failed early!
# 2024-06-28 14:35:00.800 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/LinearAlgebra/QuadraticForm/Prod.lean'), full_name='QuadraticForm.Isometry.snd_comp_inl'), status=<Status.FAILED: 'Failed'>, proof=None, actor_time=0.7150168158113956, environment_time=0.046861324459314346, total_time=0.7668093331158161, num_total_nodes=7, num_searched_nodes=1)
# 2024-06-28 14:35:00.803 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/MeasureTheory/Measure/Restrict.lean'), full_name='MeasureTheory.NullMeasurable.measure_preimage_eq_measure_restrict_preimage_of_ae_compl_eq_const')
# 2024-06-28 14:37:11.758 | INFO     | search_utils:_best_first_search:451 - Failed early!
# 2024-06-28 14:37:23.650 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/MeasureTheory/Measure/Restrict.lean'), full_name='MeasureTheory.NullMeasurable.measure_preimage_eq_measure_restrict_preimage_of_ae_compl_eq_const'), status=<Status.FAILED: 'Failed'>, proof=None, actor_time=1.3293326273560524, environment_time=0.65071040391922, total_time=1.985022448003292, num_total_nodes=14, num_searched_nodes=1)
# 2024-06-28 14:37:23.651 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Algebra/Module/Submodule/Basic.lean'), full_name='Submodule.mem_carrier')
# 2024-06-28 14:39:28.030 | INFO     | search_utils:_best_first_search:455 - Found a proof!
# 2024-06-28 14:39:35.217 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Algebra/Module/Submodule/Basic.lean'), full_name='Submodule.mem_carrier'), status=<Status.PROVED: 'Proved'>, proof=['simp'], actor_time=0.6424192003905773, environment_time=0.016379565000534058, total_time=0.6636418551206589, num_total_nodes=2, num_searched_nodes=1)
# 2024-06-28 14:39:35.219 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Data/Polynomial/Reverse.lean'), full_name='Polynomial.coeff_one_reverse')
# 2024-06-28 14:44:45.189 | INFO     | search_utils:_best_first_search:447 - Search timed out.
# 2024-06-28 14:44:53.783 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Data/Polynomial/Reverse.lean'), full_name='Polynomial.coeff_one_reverse'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=126.7665272988379, environment_time=52.48287062346935, total_time=180.42014864087105, num_total_nodes=1113, num_searched_nodes=165)
# 2024-06-28 14:44:53.784 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/LinearAlgebra/QuadraticForm/Basic.lean'), full_name='QuadraticForm.associated_left_inverse')
# 2024-06-28 14:50:13.750 | INFO     | search_utils:_best_first_search:447 - Search timed out.
# 2024-06-28 14:50:29.124 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/LinearAlgebra/QuadraticForm/Basic.lean'), full_name='QuadraticForm.associated_left_inverse'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=109.81187877804041, environment_time=70.04018197208643, total_time=180.9581816419959, num_total_nodes=1084, num_searched_nodes=143)
# 2024-06-28 14:50:29.126 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Topology/Algebra/Module/FiniteDimension.lean'), full_name='LinearEquiv.coe_toContinuousLinearEquiv_symm')
# 2024-06-28 14:52:44.553 | INFO     | search_utils:_best_first_search:451 - Failed early!
# 2024-06-28 14:52:52.538 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Topology/Algebra/Module/FiniteDimension.lean'), full_name='LinearEquiv.coe_toContinuousLinearEquiv_symm'), status=<Status.FAILED: 'Failed'>, proof=None, actor_time=0.8052484579384327, environment_time=0.07068212330341339, total_time=0.8808242231607437, num_total_nodes=14, num_searched_nodes=1)
# 2024-06-28 14:52:52.540 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Algebra/BigOperators/Intervals.lean'), full_name='Finset.prod_Ico_reflect')
# 2024-06-28 14:54:54.820 | INFO     | search_utils:_best_first_search:451 - Failed early!
# 2024-06-28 14:55:06.829 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Algebra/BigOperators/Intervals.lean'), full_name='Finset.prod_Ico_reflect'), status=<Status.FAILED: 'Failed'>, proof=None, actor_time=0.8562366031110287, environment_time=0.1379977948963642, total_time=0.999295499175787, num_total_nodes=15, num_searched_nodes=1)
# 2024-06-28 14:55:06.830 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Order/Filter/Basic.lean'), full_name='Filter.Tendsto.neBot')
# 2024-06-28 14:57:42.369 | INFO     | search_utils:_best_first_search:455 - Found a proof!
# 2024-06-28 14:57:49.957 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Order/Filter/Basic.lean'), full_name='Filter.Tendsto.neBot'), status=<Status.PROVED: 'Proved'>, proof=['rw [Filter.neBot_iff] at hx ⊢', 'rintro rfl', 'simp at hx', 'simp [Filter.Tendsto, hx] at h'], actor_time=10.578946571797132, environment_time=4.411555133759975, total_time=15.106467623263597, num_total_nodes=183, num_searched_nodes=17)
# 2024-06-28 14:57:49.958 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Data/List/Dedup.lean'), full_name='List.dedup_subset')
# 2024-06-28 14:59:57.352 | INFO     | search_utils:_best_first_search:455 - Found a proof!
# 2024-06-28 15:00:04.483 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Data/List/Dedup.lean'), full_name='List.dedup_subset'), status=<Status.PROVED: 'Proved'>, proof=['intro l', 'intro x hx', 'simpa using hx'], actor_time=1.5837619677186012, environment_time=0.4001377522945404, total_time=1.9995682835578918, num_total_nodes=24, num_searched_nodes=3)
# 2024-06-28 15:00:04.485 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Algebra/Order/Monovary.lean'), full_name='antivary_iff_forall_mul_nonpos')
# 2024-06-28 15:05:22.082 | INFO     | search_utils:_best_first_search:447 - Search timed out.
# 2024-06-28 15:05:30.688 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Algebra/Order/Monovary.lean'), full_name='antivary_iff_forall_mul_nonpos'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=129.6241793036461, environment_time=49.39082906022668, total_time=180.2697642594576, num_total_nodes=1488, num_searched_nodes=148)
# 2024-06-28 15:05:30.689 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Analysis/SpecialFunctions/Trigonometric/Inverse.lean'), full_name='Real.arccos_of_le_neg_one')
# 2024-06-28 15:07:42.012 | INFO     | search_utils:_best_first_search:455 - Found a proof!
# 2024-06-28 15:07:53.801 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Analysis/SpecialFunctions/Trigonometric/Inverse.lean'), full_name='Real.arccos_of_le_neg_one'), status=<Status.PROVED: 'Proved'>, proof=['simp [hx]'], actor_time=0.7974402382969856, environment_time=0.07349143922328949, total_time=0.8758797869086266, num_total_nodes=4, num_searched_nodes=1)
# 2024-06-28 15:07:53.802 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Data/Finset/Basic.lean'), full_name='Finset.exists_list_nodup_eq')
# 2024-06-28 15:10:19.659 | INFO     | search_utils:_best_first_search:451 - Failed early!
# 2024-06-28 15:10:31.211 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Data/Finset/Basic.lean'), full_name='Finset.exists_list_nodup_eq'), status=<Status.FAILED: 'Failed'>, proof=None, actor_time=0.7718954868614674, environment_time=0.12764055281877518, total_time=0.9044603891670704, num_total_nodes=14, num_searched_nodes=1)
# 2024-06-28 15:10:31.212 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Data/Set/Image.lean'), full_name='Set.range_diff_image_subset')
# 2024-06-28 15:12:47.422 | INFO     | search_utils:_best_first_search:451 - Failed early!
# 2024-06-28 15:12:54.560 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Data/Set/Image.lean'), full_name='Set.range_diff_image_subset'), status=<Status.FAILED: 'Failed'>, proof=None, actor_time=0.5299437828361988, environment_time=0.03437577188014984, total_time=0.5690062865614891, num_total_nodes=14, num_searched_nodes=1)
# 2024-06-28 15:12:54.563 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Algebra/IsPrimePow.lean'), full_name='isPrimePow_nat_iff')
# 2024-06-28 15:17:58.163 | INFO     | search_utils:_best_first_search:447 - Search timed out.
# 2024-06-28 15:18:06.738 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Algebra/IsPrimePow.lean'), full_name='isPrimePow_nat_iff'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=97.55502393469214, environment_time=82.20788944512606, total_time=180.7088677920401, num_total_nodes=889, num_searched_nodes=103)
# 2024-06-28 15:18:06.739 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/MeasureTheory/Measure/Restrict.lean'), full_name='MeasureTheory.Measure.restrict_eq_self')
# 2024-06-28 15:21:14.947 | INFO     | search_utils:_best_first_search:434 - Ran out of nodes to search.
# 2024-06-28 15:21:23.359 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/MeasureTheory/Measure/Restrict.lean'), full_name='MeasureTheory.Measure.restrict_eq_self'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=43.3311644308269, environment_time=8.242484513670206, total_time=51.83669114112854, num_total_nodes=292, num_searched_nodes=35)
# 2024-06-28 15:21:23.360 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Algebra/DirectLimit.lean'), full_name='AddCommGroup.DirectLimit.congr_symm_apply_of')
# 2024-06-28 15:23:45.235 | INFO     | search_utils:_best_first_search:451 - Failed early!
# 2024-06-28 15:23:58.943 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Algebra/DirectLimit.lean'), full_name='AddCommGroup.DirectLimit.congr_symm_apply_of'), status=<Status.FAILED: 'Failed'>, proof=None, actor_time=0.7207786850631237, environment_time=0.18489667028188705, total_time=0.9107782244682312, num_total_nodes=6, num_searched_nodes=1)
# 2024-06-28 15:23:58.944 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Algebra/Order/Ring/WithTop.lean'), full_name="WithTop.distrib'")
# 2024-06-28 15:29:07.816 | INFO     | search_utils:_best_first_search:447 - Search timed out.
# 2024-06-28 15:29:15.000 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Algebra/Order/Ring/WithTop.lean'), full_name="WithTop.distrib'"), status=<Status.OPEN: 'Open'>, proof=None, actor_time=140.97219310328364, environment_time=38.48011730983853, total_time=180.62634463980794, num_total_nodes=1528, num_searched_nodes=213)
# 2024-06-28 15:29:15.001 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Analysis/SpecialFunctions/Log/Basic.lean'), full_name='Real.continuousAt_log_iff')
# 2024-06-28 15:34:26.181 | INFO     | search_utils:_best_first_search:447 - Search timed out.
# 2024-06-28 15:34:34.253 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Analysis/SpecialFunctions/Log/Basic.lean'), full_name='Real.continuousAt_log_iff'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=142.7972605228424, environment_time=36.240748316049576, total_time=180.18159348145127, num_total_nodes=1621, num_searched_nodes=171)
# 2024-06-28 15:34:34.255 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Analysis/Normed/Group/Basic.lean'), full_name="ContinuousWithinAt.nnnorm'")
# 2024-06-28 15:37:03.038 | INFO     | search_utils:_best_first_search:451 - Failed early!
# 2024-06-28 15:37:10.184 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Analysis/Normed/Group/Basic.lean'), full_name="ContinuousWithinAt.nnnorm'"), status=<Status.FAILED: 'Failed'>, proof=None, actor_time=0.8238972723484039, environment_time=0.06585106998682022, total_time=0.894609846174717, num_total_nodes=6, num_searched_nodes=1)
# 2024-06-28 15:37:10.185 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Algebra/GradedMonoid.lean'), full_name='GradedMonoid.mk_zero_pow')
# 2024-06-28 15:39:19.963 | INFO     | search_utils:_best_first_search:451 - Failed early!
# 2024-06-28 15:39:31.716 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Algebra/GradedMonoid.lean'), full_name='GradedMonoid.mk_zero_pow'), status=<Status.FAILED: 'Failed'>, proof=None, actor_time=0.7155452035367489, environment_time=0.06544484570622444, total_time=0.7858570851385593, num_total_nodes=13, num_searched_nodes=1)
# 2024-06-28 15:39:31.717 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Algebra/Homology/HomotopyCategory/HomComplex.lean'), full_name='CochainComplex.HomComplex.Cochain.comp_assoc_of_first_is_zero_cochain')
# 2024-06-28 15:44:43.533 | INFO     | search_utils:_best_first_search:447 - Search timed out.
# 2024-06-28 15:44:51.826 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Algebra/Homology/HomotopyCategory/HomComplex.lean'), full_name='CochainComplex.HomComplex.Cochain.comp_assoc_of_first_is_zero_cochain'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=142.40225522965193, environment_time=37.50205174088478, total_time=180.87742554023862, num_total_nodes=1087, num_searched_nodes=157)
# 2024-06-28 15:44:51.827 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/MeasureTheory/Function/SimpleFunc.lean'), full_name='MeasureTheory.SimpleFunc.approx_apply')
# 2024-06-28 15:50:10.560 | INFO     | search_utils:_best_first_search:447 - Search timed out.
# 2024-06-28 15:50:17.706 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/MeasureTheory/Function/SimpleFunc.lean'), full_name='MeasureTheory.SimpleFunc.approx_apply'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=143.36976024135947, environment_time=35.952237103134394, total_time=180.2529229670763, num_total_nodes=955, num_searched_nodes=155)
# 2024-06-28 15:50:17.707 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Topology/PartialHomeomorph.lean'), full_name='PartialHomeomorph.isOpen_image_symm_of_subset_target')
# 2024-06-28 15:52:37.060 | INFO     | search_utils:_best_first_search:434 - Ran out of nodes to search.
# 2024-06-28 15:52:44.170 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Topology/PartialHomeomorph.lean'), full_name='PartialHomeomorph.isOpen_image_symm_of_subset_target'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=2.5829226411879063, environment_time=0.45706117898225784, total_time=3.0601700730621815, num_total_nodes=55, num_searched_nodes=4)
# 2024-06-28 15:52:44.171 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Computability/TuringMachine.lean'), full_name='Turing.ListBlank.tail_mk')
# 2024-06-28 15:54:58.179 | INFO     | search_utils:_best_first_search:455 - Found a proof!
# 2024-06-28 15:55:05.357 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Computability/TuringMachine.lean'), full_name='Turing.ListBlank.tail_mk'), status=<Status.PROVED: 'Proved'>, proof=['constructor'], actor_time=0.6539279893040657, environment_time=0.006048794835805893, total_time=0.6648650877177715, num_total_nodes=3, num_searched_nodes=1)
# 2024-06-28 15:55:05.360 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/MeasureTheory/Function/L1Space.lean'), full_name='MeasureTheory.L1.dist_def')
# 2024-06-28 15:57:30.454 | INFO     | search_utils:_best_first_search:451 - Failed early!
# 2024-06-28 15:57:40.140 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/MeasureTheory/Function/L1Space.lean'), full_name='MeasureTheory.L1.dist_def'), status=<Status.FAILED: 'Failed'>, proof=None, actor_time=0.6537164710462093, environment_time=0.1521722860634327, total_time=0.8108767531812191, num_total_nodes=9, num_searched_nodes=1)
# 2024-06-28 15:57:40.142 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Algebra/Order/Field/Basic.lean'), full_name='inv_lt_of_inv_lt')
# 2024-06-28 16:02:49.920 | INFO     | search_utils:_best_first_search:447 - Search timed out.
# 2024-06-28 16:02:57.123 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Algebra/Order/Field/Basic.lean'), full_name='inv_lt_of_inv_lt'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=136.4378884099424, environment_time=42.52530888095498, total_time=180.31087348237634, num_total_nodes=2163, num_searched_nodes=234)
# 2024-06-28 16:02:57.126 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Topology/Algebra/InfiniteSum/Basic.lean'), full_name='hasSum_extend_zero')
# 2024-06-28 16:05:09.263 | INFO     | search_utils:_best_first_search:451 - Failed early!
# 2024-06-28 16:05:16.417 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Topology/Algebra/InfiniteSum/Basic.lean'), full_name='hasSum_extend_zero'), status=<Status.FAILED: 'Failed'>, proof=None, actor_time=0.8898201957345009, environment_time=0.06500384211540222, total_time=0.9597940184175968, num_total_nodes=9, num_searched_nodes=1)
# 2024-06-28 16:05:16.418 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/CategoryTheory/MorphismProperty.lean'), full_name='CategoryTheory.MorphismProperty.StableUnderBaseChange.unop')
# 2024-06-28 16:07:27.522 | INFO     | search_utils:_best_first_search:451 - Failed early!
# 2024-06-28 16:07:34.648 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/CategoryTheory/MorphismProperty.lean'), full_name='CategoryTheory.MorphismProperty.StableUnderBaseChange.unop'), status=<Status.FAILED: 'Failed'>, proof=None, actor_time=2.2338311932981014, environment_time=0.00928441435098648, total_time=2.2478879503905773, num_total_nodes=17, num_searched_nodes=1)
# 2024-06-28 16:07:34.649 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Order/SymmDiff.lean'), full_name='symmDiff_left_comm')
# 2024-06-28 16:09:44.424 | INFO     | search_utils:_best_first_search:451 - Failed early!
# ...
# 2024-06-28 17:58:47.753 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/CategoryTheory/Comma/Arrow.lean'), full_name='CategoryTheory.Arrow.isIso_of_isIso_left_of_isIso_right')
# 2024-06-28 18:00:59.625 | WARNING  | search_utils:search:426 - EOF
# 2024-06-28 18:00:59.628 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/RingTheory/DedekindDomain/Ideal.lean'), full_name='irreducible_pow_sup_of_le')
# 2024-06-28 18:07:26.667 | INFO     | search_utils:_best_first_search:447 - Search timed out.
# 2024-06-28 18:07:33.901 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/RingTheory/DedekindDomain/Ideal.lean'), full_name='irreducible_pow_sup_of_le'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=3.482197728008032, environment_time=150.64430417120457, total_time=239.99330620095134, num_total_nodes=62, num_searched_nodes=4)
# 2024-06-28 18:07:33.902 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/GroupTheory/Subgroup/Basic.lean'), full_name='Subgroup.zpow_mem')
# 2024-06-28 18:09:52.234 | INFO     | search_utils:_best_first_search:451 - Failed early!
# 2024-06-28 18:09:59.435 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/GroupTheory/Subgroup/Basic.lean'), full_name='Subgroup.zpow_mem'), status=<Status.FAILED: 'Failed'>, proof=None, actor_time=0.7344608828425407, environment_time=0.06769122555851936, total_time=0.8070046082139015, num_total_nodes=5, num_searched_nodes=1)
# 2024-06-28 18:09:59.436 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Analysis/Normed/Group/Basic.lean'), full_name="pi_nnnorm_const'")
# 2024-06-28 18:13:15.292 | INFO     | search_utils:_best_first_search:434 - Ran out of nodes to search.
# 2024-06-28 18:13:23.305 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Analysis/Normed/Group/Basic.lean'), full_name="pi_nnnorm_const'"), status=<Status.OPEN: 'Open'>, proof=None, actor_time=23.615177243947983, environment_time=24.53253123536706, total_time=48.301643405109644, num_total_nodes=153, num_searched_nodes=23)
# 2024-06-28 18:13:23.307 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Topology/Gluing.lean'), full_name='TopCat.GlueData.rel_equiv')
# 2024-06-28 18:18:30.490 | INFO     | search_utils:_best_first_search:447 - Search timed out.
# 2024-06-28 18:18:44.466 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Topology/Gluing.lean'), full_name='TopCat.GlueData.rel_equiv'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=110.37410524487495, environment_time=68.49980655312538, total_time=180.15184266120195, num_total_nodes=1536, num_searched_nodes=158)
# 2024-06-28 18:18:44.468 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('.lake/packages/std/Std/Data/String/Lemmas.lean'), full_name='Substring.ValidFor.all')
# 2024-06-28 18:21:02.219 | WARNING  | search_utils:search:426 - EOF
# 2024-06-28 18:21:02.229 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Data/Set/Sups.lean'), full_name='Set.infs_subset_right')
# 2024-06-28 18:23:26.938 | INFO     | search_utils:_best_first_search:455 - Found a proof!
# 2024-06-28 18:23:34.197 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Data/Set/Sups.lean'), full_name='Set.infs_subset_right'), status=<Status.PROVED: 'Proved'>, proof=['intro', 'simp_rw [Set.subset_def]', 'aesop'], actor_time=7.884832631796598, environment_time=2.4586047045886517, total_time=10.40637033060193, num_total_nodes=121, num_searched_nodes=11)
# 2024-06-28 18:23:34.199 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/MeasureTheory/MeasurableSpace/Basic.lean'), full_name='MeasurableEquiv.symm_mk')
# 2024-06-28 18:25:49.883 | INFO     | search_utils:_best_first_search:455 - Found a proof!
# 2024-06-28 18:25:56.986 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/MeasureTheory/MeasurableSpace/Basic.lean'), full_name='MeasurableEquiv.symm_mk'), status=<Status.PROVED: 'Proved'>, proof=['rfl'], actor_time=0.4782102629542351, environment_time=0.00595695897936821, total_time=0.4887867458164692, num_total_nodes=2, num_searched_nodes=1)
# 2024-06-28 18:25:56.987 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/LinearAlgebra/Dual.lean'), full_name='Module.forall_dual_apply_eq_zero_iff')
# 2024-06-28 18:31:15.212 | INFO     | search_utils:_best_first_search:447 - Search timed out.
# 2024-06-28 18:31:29.553 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/LinearAlgebra/Dual.lean'), full_name='Module.forall_dual_apply_eq_zero_iff'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=140.51583261042833, environment_time=38.57157564163208, total_time=180.44561709836125, num_total_nodes=1607, num_searched_nodes=248)
# 2024-06-28 18:31:29.555 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Order/Filter/Basic.lean'), full_name='Filter.EventuallyLE.compl')
# 2024-06-28 18:33:59.716 | INFO     | search_utils:_best_first_search:455 - Found a proof!
# 2024-06-28 18:34:08.438 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Order/Filter/Basic.lean'), full_name='Filter.EventuallyLE.compl'), status=<Status.PROVED: 'Proved'>, proof=['rw [Filter.EventuallyLE]', 'filter_upwards [h] with x hx', 'simp', 'intro h', 'exact hx.trans h'], actor_time=7.799775592982769, environment_time=1.7623993828892708, total_time=9.632292997092009, num_total_nodes=153, num_searched_nodes=13)
# 2024-06-28 18:34:08.439 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Algebra/Homology/HomotopyCategory/MappingCone.lean'), full_name='CochainComplex.mappingCone.ext_to')
# 2024-06-28 18:36:19.180 | INFO     | search_utils:_best_first_search:451 - Failed early!
# 2024-06-28 18:36:33.642 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Algebra/Homology/HomotopyCategory/MappingCone.lean'), full_name='CochainComplex.mappingCone.ext_to'), status=<Status.FAILED: 'Failed'>, proof=None, actor_time=0.7128859013319016, environment_time=0.1284128800034523, total_time=0.8463149629533291, num_total_nodes=13, num_searched_nodes=1)
# 2024-06-28 18:36:33.643 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Topology/MetricSpace/Dilation.lean'), full_name='Dilation.ediam_image')
# 2024-06-28 18:41:41.580 | INFO     | search_utils:_best_first_search:447 - Search timed out.
# 2024-06-28 18:41:49.424 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Topology/MetricSpace/Dilation.lean'), full_name='Dilation.ediam_image'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=43.18020823225379, environment_time=137.94668563455343, total_time=181.50930991396308, num_total_nodes=327, num_searched_nodes=46)
# 2024-06-28 18:41:49.427 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Data/Nat/Digits.lean'), full_name='Nat.sum_le_ofDigits')
# 2024-06-28 18:47:08.711 | INFO     | search_utils:_best_first_search:447 - Search timed out.
# 2024-06-28 18:47:15.985 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Data/Nat/Digits.lean'), full_name='Nat.sum_le_ofDigits'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=139.8513032719493, environment_time=38.791876677423716, total_time=180.38551896438003, num_total_nodes=1446, num_searched_nodes=230)
# 2024-06-28 18:47:15.986 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Algebra/ContinuedFractions/Translations.lean'), full_name='GeneralizedContinuedFraction.first_denominator_eq')
# 2024-06-28 18:49:23.719 | INFO     | search_utils:_best_first_search:451 - Failed early!
# 2024-06-28 18:49:30.871 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Algebra/ContinuedFractions/Translations.lean'), full_name='GeneralizedContinuedFraction.first_denominator_eq'), status=<Status.FAILED: 'Failed'>, proof=None, actor_time=0.6269010417163372, environment_time=0.04455191642045975, total_time=0.6764876991510391, num_total_nodes=11, num_searched_nodes=1)
# 2024-06-28 18:49:30.874 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Order/Lattice.lean'), full_name='inf_eq_right')
# 2024-06-28 18:52:18.592 | WARNING  | search_utils:search:404 - Dojo crashed with Unexpected EOF when proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Order/Lattice.lean'), full_name='inf_eq_right')
# 2024-06-28 18:52:25.741 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Order/Lattice.lean'), full_name='inf_eq_right'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=30.07639329507947, environment_time=4.202576156705618, total_time=33.700479835271835, num_total_nodes=412, num_searched_nodes=42)
# 2024-06-28 18:52:25.742 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Analysis/SpecialFunctions/Trigonometric/Deriv.lean'), full_name='Real.sinh_lt_self_iff')
# 2024-06-28 18:57:49.413 | INFO     | search_utils:_best_first_search:447 - Search timed out.
# 2024-06-28 18:57:58.127 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Analysis/SpecialFunctions/Trigonometric/Deriv.lean'), full_name='Real.sinh_lt_self_iff'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=124.77752815932035, environment_time=54.06634192913771, total_time=180.15015706419945, num_total_nodes=1482, num_searched_nodes=160)
# 2024-06-28 18:57:58.129 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Data/Set/UnionLift.lean'), full_name='Set.iUnionLift_const')
# 2024-06-28 19:03:07.991 | INFO     | search_utils:_best_first_search:447 - Search timed out.
# 2024-06-28 19:03:15.761 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Data/Set/UnionLift.lean'), full_name='Set.iUnionLift_const'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=111.02076296880841, environment_time=68.95577302575111, total_time=180.69897014647722, num_total_nodes=1078, num_searched_nodes=99)
# 2024-06-28 19:03:15.762 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/NumberTheory/LucasLehmer.lean'), full_name='LucasLehmer.X.mul_fst')
# 2024-06-28 19:05:33.819 | INFO     | search_utils:_best_first_search:455 - Found a proof!
# 2024-06-28 19:05:40.943 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/NumberTheory/LucasLehmer.lean'), full_name='LucasLehmer.X.mul_fst'), status=<Status.PROVED: 'Proved'>, proof=['rfl'], actor_time=0.4143065959215164, environment_time=0.32155372202396393, total_time=0.7407527752220631, num_total_nodes=5, num_searched_nodes=1)
# Solved 24 out of 100 theorems.

# %%
prover = BestFirstSearchProver(
    tac_gen=RAGTacticGenerator(0),
    timeout=180,
    num_sampled_tactics=16,
    debug=False
)
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# 2024-06-28 19:05:51.773 | INFO     | search_utils:__init__:210 - Building the corpus from leandojo_benchmark_4/corpus.jsonl

# %%
solved_count = 0
for i in range(0, 100):
    result = prover.search(theorems[i].repo, theorems[i], positions[i])
    if result is not None and result.status == Status.PROVED:
        solved_count += 1
print(f"Solved {solved_count} out of 100 theorems.")
# Out:
# 2024-06-28 19:06:11.312 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Order/Bounds/Basic.lean'), full_name='not_bddBelow_iff')
# 2024-06-28 19:08:37.359 | INFO     | search_utils:_best_first_search:455 - Found a proof!
# 2024-06-28 19:08:45.322 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Order/Bounds/Basic.lean'), full_name='not_bddBelow_iff'), status=<Status.PROVED: 'Proved'>, proof=['simp [BddBelow, BddBelow]', 'simp [Set.Nonempty, lowerBounds]'], actor_time=4.397387307137251, environment_time=1.2969773337244987, total_time=5.722466919571161, num_total_nodes=41, num_searched_nodes=5)
# 2024-06-28 19:08:45.323 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/MeasureTheory/Function/SimpleFuncDenseLp.lean'), full_name='MeasureTheory.Lp.simpleFunc.toLp_add')
# 2024-06-28 19:10:58.239 | INFO     | search_utils:_best_first_search:455 - Found a proof!
# 2024-06-28 19:11:05.182 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/MeasureTheory/Function/SimpleFuncDenseLp.lean'), full_name='MeasureTheory.Lp.simpleFunc.toLp_add'), status=<Status.PROVED: 'Proved'>, proof=['rfl'], actor_time=0.4664747752249241, environment_time=0.14206742867827415, total_time=0.6138155162334442, num_total_nodes=6, num_searched_nodes=1)
# 2024-06-28 19:11:05.183 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/SetTheory/Ordinal/Principal.lean'), full_name='Ordinal.mul_omega')
# 2024-06-28 19:13:19.556 | INFO     | search_utils:_best_first_search:434 - Ran out of nodes to search.
# 2024-06-28 19:13:26.664 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/SetTheory/Ordinal/Principal.lean'), full_name='Ordinal.mul_omega'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=1.6870851181447506, environment_time=0.932413388043642, total_time=2.635976281017065, num_total_nodes=43, num_searched_nodes=3)
# 2024-06-28 19:13:26.667 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/LinearAlgebra/Reflection.lean'), full_name='Module.preReflection_preReflection')
# 2024-06-28 19:18:30.650 | INFO     | search_utils:_best_first_search:447 - Search timed out.
# 2024-06-28 19:18:38.938 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/LinearAlgebra/Reflection.lean'), full_name='Module.preReflection_preReflection'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=51.78818720206618, environment_time=128.12273521721363, total_time=180.49295556172729, num_total_nodes=350, num_searched_nodes=70)
# 2024-06-28 19:18:38.939 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Order/ConditionallyCompleteLattice/Basic.lean'), full_name='OrderIso.map_ciSup')
# 2024-06-28 19:20:55.996 | INFO     | search_utils:_best_first_search:451 - Failed early!
# 2024-06-28 19:21:03.229 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Order/ConditionallyCompleteLattice/Basic.lean'), full_name='OrderIso.map_ciSup'), status=<Status.FAILED: 'Failed'>, proof=None, actor_time=0.8819877803325653, environment_time=0.37847789376974106, total_time=1.2706628665328026, num_total_nodes=14, num_searched_nodes=2)
# 2024-06-28 19:21:03.230 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/NumberTheory/LegendreSymbol/JacobiSymbol.lean'), full_name='jacobiSym.eq_zero_iff_not_coprime')
# 2024-06-28 19:26:20.350 | INFO     | search_utils:_best_first_search:447 - Search timed out.
# 2024-06-28 19:26:28.675 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/NumberTheory/LegendreSymbol/JacobiSymbol.lean'), full_name='jacobiSym.eq_zero_iff_not_coprime'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=124.52251059189439, environment_time=55.82774820178747, total_time=181.6823145598173, num_total_nodes=1638, num_searched_nodes=160)
# 2024-06-28 19:26:28.677 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Order/Bounds/Basic.lean'), full_name='IsLeast.dual')
# 2024-06-28 19:28:51.494 | INFO     | search_utils:_best_first_search:455 - Found a proof!
# 2024-06-28 19:28:59.204 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Order/Bounds/Basic.lean'), full_name='IsLeast.dual'), status=<Status.PROVED: 'Proved'>, proof=['constructor', 'simp only [Set.mem_preimage, Set.mem_def]', 'exact h.1', 'intro b hb', 'rw [Set.mem_preimage] at hb', 'exact h.2 hb'], actor_time=10.061093296855688, environment_time=1.1649924963712692, total_time=11.295505836606026, num_total_nodes=117, num_searched_nodes=13)
# 2024-06-28 19:28:59.205 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Probability/Distributions/Geometric.lean'), full_name='ProbabilityTheory.geometricPMFRealSum')
# 2024-06-28 19:34:02.464 | INFO     | search_utils:_best_first_search:447 - Search timed out.
# 2024-06-28 19:34:10.834 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Probability/Distributions/Geometric.lean'), full_name='ProbabilityTheory.geometricPMFRealSum'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=117.83213397860527, environment_time=61.371023032814264, total_time=180.50450483337045, num_total_nodes=1384, num_searched_nodes=156)
# 2024-06-28 19:34:10.835 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Data/List/Sigma.lean'), full_name='List.NodupKeys.sublist')
# 2024-06-28 19:39:22.073 | INFO     | search_utils:_best_first_search:447 - Search timed out.
# 2024-06-28 19:39:30.530 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Data/List/Sigma.lean'), full_name='List.NodupKeys.sublist'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=93.30928258225322, environment_time=87.00797341391444, total_time=181.61396228522062, num_total_nodes=1194, num_searched_nodes=147)
# 2024-06-28 19:39:30.531 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Data/List/BigOperators/Basic.lean'), full_name='Commute.list_prod_right')
# 2024-06-28 19:42:48.062 | INFO     | search_utils:_best_first_search:455 - Found a proof!
# 2024-06-28 19:43:01.937 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Data/List/BigOperators/Basic.lean'), full_name='Commute.list_prod_right'), status=<Status.PROVED: 'Proved'>, proof=["induction' l with y l ihl", 'simpa using h y', 'simp only [List.forall_mem_cons] at h', 'simp [h.1, ihl h.2]'], actor_time=53.843927435576916, environment_time=15.804717425256968, total_time=70.31623343750834, num_total_nodes=621, num_searched_nodes=80)
# 2024-06-28 19:43:01.938 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Order/Hom/Lattice.lean'), full_name='LatticeHom.coe_toSupHom')
# 2024-06-28 19:45:15.849 | INFO     | search_utils:_best_first_search:455 - Found a proof!
# 2024-06-28 19:45:22.891 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Order/Hom/Lattice.lean'), full_name='LatticeHom.coe_toSupHom'), status=<Status.PROVED: 'Proved'>, proof=['rfl'], actor_time=0.24681107699871063, environment_time=0.002661757171154022, total_time=0.25432316586375237, num_total_nodes=2, num_searched_nodes=1)
# 2024-06-28 19:45:22.893 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/SetTheory/Game/PGame.lean'), full_name='SetTheory.PGame.leftMoves_add_cases')
# 2024-06-28 19:47:45.691 | INFO     | search_utils:_best_first_search:451 - Failed early!
# 2024-06-28 19:47:52.752 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/SetTheory/Game/PGame.lean'), full_name='SetTheory.PGame.leftMoves_add_cases'), status=<Status.FAILED: 'Failed'>, proof=None, actor_time=0.3629864752292633, environment_time=0.10514518618583679, total_time=0.47300565242767334, num_total_nodes=8, num_searched_nodes=1)
# 2024-06-28 19:47:52.753 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Data/Finset/Basic.lean'), full_name='Finset.union_subset_left')
# 2024-06-28 19:50:21.429 | INFO     | search_utils:_best_first_search:455 - Found a proof!
# 2024-06-28 19:50:32.824 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Data/Finset/Basic.lean'), full_name='Finset.union_subset_left'), status=<Status.PROVED: 'Proved'>, proof=['intro x hx', 'by_contra H', 'apply H', 'exact h (Finset.mem_union_left _ hx)'], actor_time=3.6048515290021896, environment_time=1.3541344292461872, total_time=5.001010615378618, num_total_nodes=87, num_searched_nodes=8)
# 2024-06-28 19:50:32.825 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Analysis/Analytic/Basic.lean'), full_name='HasFPowerSeriesOnBall.eventually_eq_zero')
# 2024-06-28 19:55:56.547 | INFO     | search_utils:_best_first_search:447 - Search timed out.
# 2024-06-28 19:56:10.179 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Analysis/Analytic/Basic.lean'), full_name='HasFPowerSeriesOnBall.eventually_eq_zero'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=131.45877254754305, environment_time=49.3668566159904, total_time=181.8151253350079, num_total_nodes=1073, num_searched_nodes=121)
# 2024-06-28 19:56:10.180 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/LinearAlgebra/Matrix/Symmetric.lean'), full_name='Matrix.IsSymm.smul')
# 2024-06-28 19:58:22.788 | INFO     | search_utils:_best_first_search:455 - Found a proof!
# 2024-06-28 19:58:29.751 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/LinearAlgebra/Matrix/Symmetric.lean'), full_name='Matrix.IsSymm.smul'), status=<Status.PROVED: 'Proved'>, proof=['simp_rw [Matrix.IsSymm] at h ⊢', 'simp [h]'], actor_time=1.4273431971669197, environment_time=0.49420594051480293, total_time=1.9378679692745209, num_total_nodes=25, num_searched_nodes=3)
# 2024-06-28 19:58:29.753 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Order/UpperLower/Basic.lean'), full_name='isUpperSet_preimage_toDual_iff')
# 2024-06-28 20:00:44.419 | INFO     | search_utils:_best_first_search:455 - Found a proof!
# 2024-06-28 20:00:51.425 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Order/UpperLower/Basic.lean'), full_name='isUpperSet_preimage_toDual_iff'), status=<Status.PROVED: 'Proved'>, proof=['rfl'], actor_time=0.5126439183950424, environment_time=0.005581159144639969, total_time=0.522948358207941, num_total_nodes=2, num_searched_nodes=1)
# 2024-06-28 20:00:51.426 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Analysis/Calculus/FDeriv/Comp.lean'), full_name='DifferentiableOn.comp')
# 2024-06-28 20:03:11.007 | INFO     | search_utils:_best_first_search:451 - Failed early!
# 2024-06-28 20:03:18.032 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Analysis/Calculus/FDeriv/Comp.lean'), full_name='DifferentiableOn.comp'), status=<Status.FAILED: 'Failed'>, proof=None, actor_time=6.634246781468391, environment_time=1.4248168095946312, total_time=8.106258533895016, num_total_nodes=84, num_searched_nodes=9)
# 2024-06-28 20:03:18.033 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/CategoryTheory/Limits/Shapes/BinaryProducts.lean'), full_name="CategoryTheory.Limits.prod.symmetry'")
# 2024-06-28 20:05:36.223 | INFO     | search_utils:_best_first_search:455 - Found a proof!
# 2024-06-28 20:05:43.225 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/CategoryTheory/Limits/Shapes/BinaryProducts.lean'), full_name="CategoryTheory.Limits.prod.symmetry'"), status=<Status.PROVED: 'Proved'>, proof=['simp'], actor_time=0.8482268564403057, environment_time=0.030369702726602554, total_time=0.8833847865462303, num_total_nodes=2, num_searched_nodes=1)
# 2024-06-28 20:05:43.227 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Geometry/Manifold/ContMDiff/Basic.lean'), full_name='smooth_const')
# 2024-06-28 20:07:53.511 | INFO     | search_utils:_best_first_search:455 - Found a proof!
# 2024-06-28 20:08:05.804 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Geometry/Manifold/ContMDiff/Basic.lean'), full_name='smooth_const'), status=<Status.PROVED: 'Proved'>, proof=['simp only [Smooth]', 'exact contMDiff_const'], actor_time=3.083375532180071, environment_time=0.984140656888485, total_time=4.094889421015978, num_total_nodes=42, num_searched_nodes=5)
# 2024-06-28 20:08:05.805 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Topology/Algebra/Group/Basic.lean'), full_name='tendsto_inv')
# 2024-06-28 20:10:31.488 | INFO     | search_utils:_best_first_search:434 - Ran out of nodes to search.
# 2024-06-28 20:10:43.833 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Topology/Algebra/Group/Basic.lean'), full_name='tendsto_inv'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=12.948030687868595, environment_time=1.7442821189761162, total_time=14.797406274825335, num_total_nodes=132, num_searched_nodes=20)
# 2024-06-28 20:10:43.835 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Data/Set/Function.lean'), full_name="Set.bijOn_of_subsingleton'")
# 2024-06-28 20:15:57.629 | INFO     | search_utils:_best_first_search:447 - Search timed out.
# 2024-06-28 20:16:05.886 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Data/Set/Function.lean'), full_name="Set.bijOn_of_subsingleton'"), status=<Status.OPEN: 'Open'>, proof=None, actor_time=126.16992036625743, environment_time=54.80854596197605, total_time=181.76568719372153, num_total_nodes=897, num_searched_nodes=100)
# 2024-06-28 20:16:05.888 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/MeasureTheory/Integral/Bochner.lean'), full_name='MeasureTheory.integral_map_equiv')
# 2024-06-28 20:22:02.434 | INFO     | search_utils:_best_first_search:447 - Search timed out.
# 2024-06-28 20:22:09.568 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/MeasureTheory/Integral/Bochner.lean'), full_name='MeasureTheory.integral_map_equiv'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=143.39441308751702, environment_time=36.00406942516565, total_time=180.0637162514031, num_total_nodes=723, num_searched_nodes=109)
# 2024-06-28 20:22:09.569 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/MeasureTheory/MeasurableSpace/Defs.lean'), full_name='Set.Finite.measurableSet_biInter')
# 2024-06-28 20:24:21.034 | INFO     | search_utils:_best_first_search:455 - Found a proof!
# 2024-06-28 20:24:33.311 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/MeasureTheory/MeasurableSpace/Defs.lean'), full_name='Set.Finite.measurableSet_biInter'), status=<Status.PROVED: 'Proved'>, proof=['haveI := hs.fintype', 'rw [Set.biInter_eq_iInter]', "refine' MeasurableSet.iInter fun b => _", 'exact h b b.2'], actor_time=4.013077042996883, environment_time=0.7992074377834797, total_time=4.843593060970306, num_total_nodes=37, num_searched_nodes=6)
# 2024-06-28 20:24:33.312 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/LinearAlgebra/QuadraticForm/Prod.lean'), full_name='QuadraticForm.Isometry.snd_comp_inl')
# 2024-06-28 20:26:46.942 | INFO     | search_utils:_best_first_search:455 - Found a proof!
# 2024-06-28 20:26:53.912 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/LinearAlgebra/QuadraticForm/Prod.lean'), full_name='QuadraticForm.Isometry.snd_comp_inl'), status=<Status.PROVED: 'Proved'>, proof=['rfl'], actor_time=1.0741110816597939, environment_time=0.01884571835398674, total_time=1.0978763177990913, num_total_nodes=4, num_searched_nodes=1)
# 2024-06-28 20:26:53.914 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/MeasureTheory/Measure/Restrict.lean'), full_name='MeasureTheory.NullMeasurable.measure_preimage_eq_measure_restrict_preimage_of_ae_compl_eq_const')
# 2024-06-28 20:32:15.767 | INFO     | search_utils:_best_first_search:447 - Search timed out.
# 2024-06-28 20:32:23.886 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/MeasureTheory/Measure/Restrict.lean'), full_name='MeasureTheory.NullMeasurable.measure_preimage_eq_measure_restrict_preimage_of_ae_compl_eq_const'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=112.63269483298063, environment_time=72.81210250407457, total_time=187.21849433332682, num_total_nodes=1834, num_searched_nodes=213)
# 2024-06-28 20:32:23.889 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Algebra/Module/Submodule/Basic.lean'), full_name='Submodule.mem_carrier')
# 2024-06-28 20:34:39.195 | INFO     | search_utils:_best_first_search:455 - Found a proof!
# 2024-06-28 20:34:46.168 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Algebra/Module/Submodule/Basic.lean'), full_name='Submodule.mem_carrier'), status=<Status.PROVED: 'Proved'>, proof=['simp'], actor_time=0.6289218179881573, environment_time=0.011974554508924484, total_time=0.6457234434783459, num_total_nodes=2, num_searched_nodes=1)
# 2024-06-28 20:34:46.169 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Data/Polynomial/Reverse.lean'), full_name='Polynomial.coeff_one_reverse')
# 2024-06-28 20:39:55.468 | INFO     | search_utils:_best_first_search:447 - Search timed out.
# 2024-06-28 20:40:04.015 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Data/Polynomial/Reverse.lean'), full_name='Polynomial.coeff_one_reverse'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=112.30474326014519, environment_time=66.8069629855454, total_time=180.15883868560195, num_total_nodes=1034, num_searched_nodes=158)
# 2024-06-28 20:40:04.018 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/LinearAlgebra/QuadraticForm/Basic.lean'), full_name='QuadraticForm.associated_left_inverse')
# 2024-06-28 20:44:51.042 | INFO     | search_utils:_best_first_search:455 - Found a proof!
# 2024-06-28 20:44:58.054 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/LinearAlgebra/QuadraticForm/Basic.lean'), full_name='QuadraticForm.associated_left_inverse'), status=<Status.PROVED: 'Proved'>, proof=['ext', 'simp', 'abel', 'rw [← h]', 'simp', 'abel', 'simp'], actor_time=92.12053215876222, environment_time=45.45639441907406, total_time=138.00020663812757, num_total_nodes=559, num_searched_nodes=69)
# 2024-06-28 20:44:58.056 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Topology/Algebra/Module/FiniteDimension.lean'), full_name='LinearEquiv.coe_toContinuousLinearEquiv_symm')
# 2024-06-28 20:47:12.534 | INFO     | search_utils:_best_first_search:455 - Found a proof!
# 2024-06-28 20:47:19.564 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Topology/Algebra/Module/FiniteDimension.lean'), full_name='LinearEquiv.coe_toContinuousLinearEquiv_symm'), status=<Status.PROVED: 'Proved'>, proof=['rfl'], actor_time=0.6899599954485893, environment_time=0.00978497788310051, total_time=0.7045079991221428, num_total_nodes=2, num_searched_nodes=1)
# 2024-06-28 20:47:19.565 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Algebra/BigOperators/Intervals.lean'), full_name='Finset.prod_Ico_reflect')
# 2024-06-28 20:52:32.331 | INFO     | search_utils:_best_first_search:447 - Search timed out.
# 2024-06-28 20:52:40.881 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Algebra/BigOperators/Intervals.lean'), full_name='Finset.prod_Ico_reflect'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=102.26290363818407, environment_time=77.31546650081873, total_time=181.05840035527945, num_total_nodes=1334, num_searched_nodes=181)
# 2024-06-28 20:52:40.883 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Order/Filter/Basic.lean'), full_name='Filter.Tendsto.neBot')
# 2024-06-28 20:55:59.068 | INFO     | search_utils:_best_first_search:455 - Found a proof!
# 2024-06-28 20:56:06.219 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Order/Filter/Basic.lean'), full_name='Filter.Tendsto.neBot'), status=<Status.PROVED: 'Proved'>, proof=['rw [neBot_iff]', 'contrapose! h', 'simp [h, Filter.Tendsto]', 'exact hx.ne'], actor_time=38.91900051385164, environment_time=12.76781652495265, total_time=52.264636643230915, num_total_nodes=605, num_searched_nodes=73)
# 2024-06-28 20:56:06.220 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Data/List/Dedup.lean'), full_name='List.dedup_subset')
# 2024-06-28 20:58:23.241 | INFO     | search_utils:_best_first_search:455 - Found a proof!
# 2024-06-28 20:58:34.691 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Data/List/Dedup.lean'), full_name='List.dedup_subset'), status=<Status.PROVED: 'Proved'>, proof=['intro l hl', 'simp'], actor_time=1.4085111990571022, environment_time=0.21396981924772263, total_time=1.6381458677351475, num_total_nodes=28, num_searched_nodes=3)
# 2024-06-28 20:58:34.692 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Algebra/Order/Monovary.lean'), full_name='antivary_iff_forall_mul_nonpos')
# 2024-06-28 21:03:52.745 | INFO     | search_utils:_best_first_search:447 - Search timed out.
# 2024-06-28 21:04:07.096 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Algebra/Order/Monovary.lean'), full_name='antivary_iff_forall_mul_nonpos'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=130.29502764716744, environment_time=49.49445282295346, total_time=180.99866150319576, num_total_nodes=1813, num_searched_nodes=212)
# 2024-06-28 21:04:07.097 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Analysis/SpecialFunctions/Trigonometric/Inverse.lean'), full_name='Real.arccos_of_le_neg_one')
# 2024-06-28 21:06:21.543 | INFO     | search_utils:_best_first_search:455 - Found a proof!
# 2024-06-28 21:06:28.532 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Analysis/SpecialFunctions/Trigonometric/Inverse.lean'), full_name='Real.arccos_of_le_neg_one'), status=<Status.PROVED: 'Proved'>, proof=['simp', 'exact hx'], actor_time=0.9367241263389587, environment_time=0.11059251055121422, total_time=1.0571345128118992, num_total_nodes=11, num_searched_nodes=2)
# 2024-06-28 21:06:28.533 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Data/Finset/Basic.lean'), full_name='Finset.exists_list_nodup_eq')
# 2024-06-28 21:09:51.384 | INFO     | search_utils:_best_first_search:455 - Found a proof!
# 2024-06-28 21:10:06.533 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Data/Finset/Basic.lean'), full_name='Finset.exists_list_nodup_eq'), status=<Status.PROVED: 'Proved'>, proof=["refine' ⟨_, _, _⟩", 'swap', 'rotate_left', 'exact s.toList', 'swap', 'simp only [Finset.nodup_toList]', 'simp'], actor_time=40.18389183282852, environment_time=14.110513217747211, total_time=54.74188528582454, num_total_nodes=394, num_searched_nodes=81)
# 2024-06-28 21:10:06.535 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Data/Set/Image.lean'), full_name='Set.range_diff_image_subset')
# 2024-06-28 21:12:24.620 | INFO     | search_utils:_best_first_search:455 - Found a proof!
# 2024-06-28 21:12:36.556 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Data/Set/Image.lean'), full_name='Set.range_diff_image_subset'), status=<Status.PROVED: 'Proved'>, proof=['rw [Set.diff_subset_iff]', 'simp [Set.range_subset_iff]'], actor_time=2.2006648629903793, environment_time=0.5474792942404747, total_time=2.7693284563720226, num_total_nodes=36, num_searched_nodes=4)
# 2024-06-28 21:12:36.559 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Algebra/IsPrimePow.lean'), full_name='isPrimePow_nat_iff')
# 2024-06-28 21:17:50.152 | INFO     | search_utils:_best_first_search:447 - Search timed out.
# 2024-06-28 21:17:57.886 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Algebra/IsPrimePow.lean'), full_name='isPrimePow_nat_iff'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=93.81940460205078, environment_time=85.90703199803829, total_time=180.86282810941339, num_total_nodes=982, num_searched_nodes=134)
# 2024-06-28 21:17:57.887 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/MeasureTheory/Measure/Restrict.lean'), full_name='MeasureTheory.Measure.restrict_eq_self')
# 2024-06-28 21:23:11.554 | INFO     | search_utils:_best_first_search:447 - Search timed out.
# 2024-06-28 21:23:18.731 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/MeasureTheory/Measure/Restrict.lean'), full_name='MeasureTheory.Measure.restrict_eq_self'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=147.95178185030818, environment_time=30.949477642774582, total_time=180.03315400332212, num_total_nodes=1365, num_searched_nodes=201)
# 2024-06-28 21:23:18.733 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Algebra/DirectLimit.lean'), full_name='AddCommGroup.DirectLimit.congr_symm_apply_of')
# 2024-06-28 21:25:45.419 | INFO     | search_utils:_best_first_search:451 - Failed early!
# 2024-06-28 21:25:59.188 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Algebra/DirectLimit.lean'), full_name='AddCommGroup.DirectLimit.congr_symm_apply_of'), status=<Status.FAILED: 'Failed'>, proof=None, actor_time=0.5370588712394238, environment_time=1.6596023328602314, total_time=2.2017341144382954, num_total_nodes=11, num_searched_nodes=1)
# 2024-06-28 21:25:59.189 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Algebra/Order/Ring/WithTop.lean'), full_name="WithTop.distrib'")
# 2024-06-28 21:28:10.827 | INFO     | search_utils:_best_first_search:451 - Failed early!
# 2024-06-28 21:28:18.054 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Algebra/Order/Ring/WithTop.lean'), full_name="WithTop.distrib'"), status=<Status.FAILED: 'Failed'>, proof=None, actor_time=0.7663275524973869, environment_time=0.05917034298181534, total_time=0.8305582478642464, num_total_nodes=14, num_searched_nodes=1)
# 2024-06-28 21:28:18.056 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Analysis/SpecialFunctions/Log/Basic.lean'), full_name='Real.continuousAt_log_iff')
# 2024-06-28 21:33:29.701 | INFO     | search_utils:_best_first_search:447 - Search timed out.
# 2024-06-28 21:33:38.384 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Analysis/SpecialFunctions/Log/Basic.lean'), full_name='Real.continuousAt_log_iff'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=138.22190012037754, environment_time=40.49816416949034, total_time=180.2437931932509, num_total_nodes=1733, num_searched_nodes=177)
# 2024-06-28 21:33:38.386 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Analysis/Normed/Group/Basic.lean'), full_name="ContinuousWithinAt.nnnorm'")
# 2024-06-28 21:36:07.530 | INFO     | search_utils:_best_first_search:451 - Failed early!
# 2024-06-28 21:36:15.979 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Analysis/Normed/Group/Basic.lean'), full_name="ContinuousWithinAt.nnnorm'"), status=<Status.FAILED: 'Failed'>, proof=None, actor_time=2.39701833948493, environment_time=0.8525591939687729, total_time=3.2710661366581917, num_total_nodes=46, num_searched_nodes=4)
# 2024-06-28 21:36:15.979 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Algebra/GradedMonoid.lean'), full_name='GradedMonoid.mk_zero_pow')
# 2024-06-28 21:41:20.552 | INFO     | search_utils:_best_first_search:447 - Search timed out.
# 2024-06-28 21:41:28.316 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Algebra/GradedMonoid.lean'), full_name='GradedMonoid.mk_zero_pow'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=115.17129666730762, environment_time=63.60100917890668, total_time=180.74096308648586, num_total_nodes=1725, num_searched_nodes=225)
# 2024-06-28 21:41:28.319 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Algebra/Homology/HomotopyCategory/HomComplex.lean'), full_name='CochainComplex.HomComplex.Cochain.comp_assoc_of_first_is_zero_cochain')
# 2024-06-28 21:45:51.350 | INFO     | search_utils:_best_first_search:455 - Found a proof!
# 2024-06-28 21:45:59.254 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Algebra/Homology/HomotopyCategory/HomComplex.lean'), full_name='CochainComplex.HomComplex.Cochain.comp_assoc_of_first_is_zero_cochain'), status=<Status.PROVED: 'Proved'>, proof=['ext p q hpq', 'simp [CochainComplex.HomComplex.Cochain.comp]', 'congr 3', 'all_goals aesop'], actor_time=88.54883747175336, environment_time=39.84114866703749, total_time=129.07852724567056, num_total_nodes=699, num_searched_nodes=98)
# 2024-06-28 21:45:59.256 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/MeasureTheory/Function/SimpleFunc.lean'), full_name='MeasureTheory.SimpleFunc.approx_apply')
# 2024-06-28 21:48:18.130 | INFO     | search_utils:_best_first_search:451 - Failed early!
# 2024-06-28 21:48:25.255 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/MeasureTheory/Function/SimpleFunc.lean'), full_name='MeasureTheory.SimpleFunc.approx_apply'), status=<Status.FAILED: 'Failed'>, proof=None, actor_time=0.6474015191197395, environment_time=0.08594253659248352, total_time=0.7383619844913483, num_total_nodes=8, num_searched_nodes=1)
# 2024-06-28 21:48:25.257 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Topology/PartialHomeomorph.lean'), full_name='PartialHomeomorph.isOpen_image_symm_of_subset_target')
# 2024-06-28 21:53:37.819 | INFO     | search_utils:_best_first_search:447 - Search timed out.
# 2024-06-28 21:53:46.437 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Topology/PartialHomeomorph.lean'), full_name='PartialHomeomorph.isOpen_image_symm_of_subset_target'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=149.7306035347283, environment_time=29.050364144146442, total_time=180.16018686071038, num_total_nodes=1495, num_searched_nodes=177)
# 2024-06-28 21:53:46.439 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Computability/TuringMachine.lean'), full_name='Turing.ListBlank.tail_mk')
# 2024-06-28 21:55:59.395 | INFO     | search_utils:_best_first_search:455 - Found a proof!
# 2024-06-28 21:56:06.530 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Computability/TuringMachine.lean'), full_name='Turing.ListBlank.tail_mk'), status=<Status.PROVED: 'Proved'>, proof=['rfl'], actor_time=0.3750200867652893, environment_time=0.004091817885637283, total_time=0.3838198371231556, num_total_nodes=2, num_searched_nodes=1)
# 2024-06-28 21:56:06.531 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/MeasureTheory/Function/L1Space.lean'), full_name='MeasureTheory.L1.dist_def')
# 2024-06-28 22:00:46.321 | INFO     | search_utils:_best_first_search:455 - Found a proof!
# 2024-06-28 22:00:54.246 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/MeasureTheory/Function/L1Space.lean'), full_name='MeasureTheory.L1.dist_def'), status=<Status.PROVED: 'Proved'>, proof=['simp [dist_edist]', 'congr 1', 'rw [MeasureTheory.Lp.edist_def]', 'simp [MeasureTheory.snorm]', "simp [MeasureTheory.snorm']", 'congr with a', 'rw [edist_eq_coe_nnnorm_sub]'], actor_time=105.47609693929553, environment_time=33.89922619983554, total_time=140.423923779279, num_total_nodes=841, num_searched_nodes=121)
# 2024-06-28 22:00:54.248 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Algebra/Order/Field/Basic.lean'), full_name='inv_lt_of_inv_lt')
# 2024-06-28 22:06:07.842 | INFO     | search_utils:_best_first_search:447 - Search timed out.
# 2024-06-28 22:06:21.818 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Algebra/Order/Field/Basic.lean'), full_name='inv_lt_of_inv_lt'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=133.6521218009293, environment_time=44.03536517173052, total_time=180.09950754791498, num_total_nodes=1934, num_searched_nodes=290)
# 2024-06-28 22:06:21.820 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Topology/Algebra/InfiniteSum/Basic.lean'), full_name='hasSum_extend_zero')
# 2024-06-28 22:08:38.469 | INFO     | search_utils:_best_first_search:434 - Ran out of nodes to search.
# 2024-06-28 22:08:46.283 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Topology/Algebra/InfiniteSum/Basic.lean'), full_name='hasSum_extend_zero'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=6.085280705243349, environment_time=1.2122481502592564, total_time=7.342882834374905, num_total_nodes=102, num_searched_nodes=9)
# 2024-06-28 22:08:46.284 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/CategoryTheory/MorphismProperty.lean'), full_name='CategoryTheory.MorphismProperty.StableUnderBaseChange.unop')
# 2024-06-28 22:13:59.591 | INFO     | search_utils:_best_first_search:447 - Search timed out.
# ...
# 2024-06-29 00:14:22.556 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Algebra/Group/Aut.lean'), full_name='MulAut.smul_def'), status=<Status.PROVED: 'Proved'>, proof=['rfl'], actor_time=0.5331518575549126, environment_time=0.006840784102678299, total_time=0.5448707453906536, num_total_nodes=3, num_searched_nodes=1)
# 2024-06-29 00:14:22.557 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/CategoryTheory/Comma/Arrow.lean'), full_name='CategoryTheory.Arrow.isIso_of_isIso_left_of_isIso_right')
# 2024-06-29 00:16:36.220 | WARNING  | search_utils:search:426 - EOF
# 2024-06-29 00:16:36.222 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/RingTheory/DedekindDomain/Ideal.lean'), full_name='irreducible_pow_sup_of_le')
# 2024-06-29 00:22:55.333 | INFO     | search_utils:_best_first_search:447 - Search timed out.
# 2024-06-29 00:23:10.422 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/RingTheory/DedekindDomain/Ideal.lean'), full_name='irreducible_pow_sup_of_le'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=9.920375164598227, environment_time=124.42115763947368, total_time=239.99121744185686, num_total_nodes=200, num_searched_nodes=16)
# 2024-06-29 00:23:10.424 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/GroupTheory/Subgroup/Basic.lean'), full_name='Subgroup.zpow_mem')
# 2024-06-29 00:25:38.483 | INFO     | search_utils:_best_first_search:455 - Found a proof!
# 2024-06-29 00:25:49.677 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/GroupTheory/Subgroup/Basic.lean'), full_name='Subgroup.zpow_mem'), status=<Status.PROVED: 'Proved'>, proof=['intro n', "induction' n with n ih", 'cases n', 'all_goals aesop'], actor_time=7.565733127295971, environment_time=1.888862170279026, total_time=9.53623178973794, num_total_nodes=125, num_searched_nodes=15)
# 2024-06-29 00:25:49.678 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Analysis/Normed/Group/Basic.lean'), full_name="pi_nnnorm_const'")
# 2024-06-29 00:28:18.055 | INFO     | search_utils:_best_first_search:455 - Found a proof!
# 2024-06-29 00:28:25.895 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Analysis/Normed/Group/Basic.lean'), full_name="pi_nnnorm_const'"), status=<Status.PROVED: 'Proved'>, proof=['ext i', 'simp'], actor_time=1.263373650610447, environment_time=0.07204193994402885, total_time=1.345612347126007, num_total_nodes=13, num_searched_nodes=2)
# 2024-06-29 00:28:25.896 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Topology/Gluing.lean'), full_name='TopCat.GlueData.rel_equiv')
# 2024-06-29 00:30:38.735 | INFO     | search_utils:_best_first_search:434 - Ran out of nodes to search.
# 2024-06-29 00:30:46.023 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Topology/Gluing.lean'), full_name='TopCat.GlueData.rel_equiv'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=3.48058994486928, environment_time=0.5184625536203384, total_time=4.029692232608795, num_total_nodes=73, num_searched_nodes=6)
# 2024-06-29 00:30:46.026 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('.lake/packages/std/Std/Data/String/Lemmas.lean'), full_name='Substring.ValidFor.all')
# 2024-06-29 00:33:06.696 | WARNING  | search_utils:search:426 - EOF
# 2024-06-29 00:33:06.707 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Data/Set/Sups.lean'), full_name='Set.infs_subset_right')
# 2024-06-29 00:35:20.140 | INFO     | search_utils:_best_first_search:455 - Found a proof!
# 2024-06-29 00:35:32.650 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Data/Set/Sups.lean'), full_name='Set.infs_subset_right'), status=<Status.PROVED: 'Proved'>, proof=['simp_rw [Set.subset_def]', 'aesop'], actor_time=1.4408819042146206, environment_time=1.69342140853405, total_time=3.150494199246168, num_total_nodes=26, num_searched_nodes=3)
# 2024-06-29 00:35:32.652 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/MeasureTheory/MeasurableSpace/Basic.lean'), full_name='MeasurableEquiv.symm_mk')
# 2024-06-29 00:37:51.133 | INFO     | search_utils:_best_first_search:455 - Found a proof!
# 2024-06-29 00:38:01.993 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/MeasureTheory/MeasurableSpace/Basic.lean'), full_name='MeasurableEquiv.symm_mk'), status=<Status.PROVED: 'Proved'>, proof=['rfl'], actor_time=0.2652471959590912, environment_time=0.004451684653759003, total_time=0.2743809223175049, num_total_nodes=2, num_searched_nodes=1)
# 2024-06-29 00:38:01.994 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/LinearAlgebra/Dual.lean'), full_name='Module.forall_dual_apply_eq_zero_iff')
# 2024-06-29 00:43:20.615 | INFO     | search_utils:_best_first_search:447 - Search timed out.
# 2024-06-29 00:43:36.885 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/LinearAlgebra/Dual.lean'), full_name='Module.forall_dual_apply_eq_zero_iff'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=130.00786877050996, environment_time=48.814771354198456, total_time=180.7914121337235, num_total_nodes=1312, num_searched_nodes=257)
# 2024-06-29 00:43:36.887 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Order/Filter/Basic.lean'), full_name='Filter.EventuallyLE.compl')
# 2024-06-29 00:46:06.573 | INFO     | search_utils:_best_first_search:455 - Found a proof!
# 2024-06-29 00:46:13.834 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Order/Filter/Basic.lean'), full_name='Filter.EventuallyLE.compl'), status=<Status.PROVED: 'Proved'>, proof=['apply h.mono', 'exact fun x hx => hx.trans'], actor_time=1.2492574825882912, environment_time=0.4920438230037689, total_time=1.7579046078026295, num_total_nodes=29, num_searched_nodes=3)
# 2024-06-29 00:46:13.835 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Algebra/Homology/HomotopyCategory/MappingCone.lean'), full_name='CochainComplex.mappingCone.ext_to')
# 2024-06-29 00:48:25.227 | INFO     | search_utils:_best_first_search:451 - Failed early!
# 2024-06-29 00:48:32.563 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Algebra/Homology/HomotopyCategory/MappingCone.lean'), full_name='CochainComplex.mappingCone.ext_to'), status=<Status.FAILED: 'Failed'>, proof=None, actor_time=1.1599571332335472, environment_time=0.1721598356962204, total_time=1.3374680057168007, num_total_nodes=14, num_searched_nodes=1)
# 2024-06-29 00:48:32.564 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Topology/MetricSpace/Dilation.lean'), full_name='Dilation.ediam_image')
# 2024-06-29 00:53:51.369 | INFO     | search_utils:_best_first_search:447 - Search timed out.
# 2024-06-29 00:53:59.914 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Topology/MetricSpace/Dilation.lean'), full_name='Dilation.ediam_image'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=84.74186425283551, environment_time=96.08932147175074, total_time=181.6119109876454, num_total_nodes=423, num_searched_nodes=96)
# 2024-06-29 00:53:59.915 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Data/Nat/Digits.lean'), full_name='Nat.sum_le_ofDigits')
# 2024-06-29 00:59:16.795 | INFO     | search_utils:_best_first_search:447 - Search timed out.
# 2024-06-29 00:59:25.596 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Data/Nat/Digits.lean'), full_name='Nat.sum_le_ofDigits'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=127.91679359972477, environment_time=51.330674923956394, total_time=180.70290280133486, num_total_nodes=1546, num_searched_nodes=213)
# 2024-06-29 00:59:25.598 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Algebra/ContinuedFractions/Translations.lean'), full_name='GeneralizedContinuedFraction.first_denominator_eq')
# 2024-06-29 01:01:39.350 | INFO     | search_utils:_best_first_search:451 - Failed early!
# 2024-06-29 01:01:49.902 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Algebra/ContinuedFractions/Translations.lean'), full_name='GeneralizedContinuedFraction.first_denominator_eq'), status=<Status.FAILED: 'Failed'>, proof=None, actor_time=4.8063011690974236, environment_time=0.4325350187718868, total_time=5.259263876825571, num_total_nodes=26, num_searched_nodes=4)
# 2024-06-29 01:01:49.903 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Order/Lattice.lean'), full_name='inf_eq_right')
# 2024-06-29 01:07:06.658 | INFO     | search_utils:_best_first_search:447 - Search timed out.
# 2024-06-29 01:07:15.640 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Order/Lattice.lean'), full_name='inf_eq_right'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=145.76021897047758, environment_time=32.40390256047249, total_time=180.3072944097221, num_total_nodes=2217, num_searched_nodes=274)
# 2024-06-29 01:07:15.642 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Analysis/SpecialFunctions/Trigonometric/Deriv.lean'), full_name='Real.sinh_lt_self_iff')
# 2024-06-29 01:09:45.579 | INFO     | search_utils:_best_first_search:434 - Ran out of nodes to search.
# 2024-06-29 01:09:52.715 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Analysis/SpecialFunctions/Trigonometric/Deriv.lean'), full_name='Real.sinh_lt_self_iff'), status=<Status.OPEN: 'Open'>, proof=None, actor_time=0.6203841157257557, environment_time=0.042709700763225555, total_time=0.6678939759731293, num_total_nodes=16, num_searched_nodes=1)
# 2024-06-29 01:09:52.716 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Data/Set/UnionLift.lean'), full_name='Set.iUnionLift_const')
# 2024-06-29 01:12:36.150 | INFO     | search_utils:_best_first_search:455 - Found a proof!
# 2024-06-29 01:12:43.581 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Data/Set/UnionLift.lean'), full_name='Set.iUnionLift_const'), status=<Status.PROVED: 'Proved'>, proof=['simp [Set.iUnionLift, h]', 'rw [← h]', 'congr 1', 'ext i', 'simp [hci]'], actor_time=20.312241442501545, environment_time=9.741916742175817, total_time=30.238030530512333, num_total_nodes=251, num_searched_nodes=31)
# 2024-06-29 01:12:43.582 | INFO     | search_utils:search:378 - Proving Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/NumberTheory/LucasLehmer.lean'), full_name='LucasLehmer.X.mul_fst')
# 2024-06-29 01:14:55.720 | INFO     | search_utils:_best_first_search:455 - Found a proof!
# 2024-06-29 01:15:03.797 | INFO     | search_utils:search:422 - SearchResult(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/NumberTheory/LucasLehmer.lean'), full_name='LucasLehmer.X.mul_fst'), status=<Status.PROVED: 'Proved'>, proof=['rfl'], actor_time=0.3632466681301594, environment_time=0.06892891228199005, total_time=0.437152985483408, num_total_nodes=6, num_searched_nodes=1)
# Solved 40 out of 100 theorems.
